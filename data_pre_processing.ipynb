# %%
# Merge csv Posting and Votes
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
df = pd.read_csv(r'./data/raw_csv/Postings_01052019_31052019.csv')

# Display the first 10 rows
print(df.head(10).to_string())

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import json
import pickle

class DataPreprocessor:
    """
    A class to preprocess the raw comment data.
    """

    def __init__(self, file_path):
        """
        Initialize the DataPreprocessor with the path to the raw data file.
        
        :param file_path: str, path to the raw CSV file
        """
        self.file_path = file_path
        self.df = None

    def load_data(self):
        """Load the raw data from CSV file."""
        self.df = pd.read_csv(self.file_path)

    def preprocess(self):
        """Apply all preprocessing steps to the data."""
        self._convert_dates()
        self._handle_missing_values()
        self._convert_id_columns()
        self._create_new_features()

    def _convert_dates(self):
        """Convert date columns to datetime format."""
        date_columns = ['PostingCreatedAt', 'ArticlePublishingDate', 'UserCreatedAt']
        for col in date_columns:
            self.df[col] = pd.to_datetime(self.df[col])

    def _handle_missing_values(self):
        """Handle missing values in the dataset."""
        self.df['PostingHeadline'] = self.df['PostingHeadline'].fillna('No Headline')
        self.df['PostingComment'] = self.df['PostingComment'].fillna('No Comment')
        self.df['UserGender'] = self.df['UserGender'].fillna('Unknown')
        self.df['UserCommunityName'] = self.df['UserCommunityName'].fillna('Unknown')

    def _convert_id_columns(self):
        """Convert ID columns to integers."""
        id_columns = ['ID_Posting', 'ID_Posting_Parent', 'ID_CommunityIdentity', 'ID_Article']
        for col in id_columns:
            self.df[col] = self.df[col].fillna(0).astype(int)

    def _create_new_features(self):
        """Create new features from existing data."""
        self.df['CommentLength'] = self.df['PostingComment'].str.len()
        self.df['DaysSinceUserCreation'] = (self.df['PostingCreatedAt'] - self.df['UserCreatedAt']).dt.days
        self.df['IsReply'] = self.df['ID_Posting_Parent'] != 0
        self.df['PostingHour'] = self.df['PostingCreatedAt'].dt.hour
        self.df['PostingDayOfWeek'] = self.df['PostingCreatedAt'].dt.dayofweek

    def save_preprocessed_data(self, output_path):
        """
        Save the preprocessed data to a CSV file.
        
        :param output_path: str, path to save the preprocessed CSV file
        """
        self.df.to_csv(output_path, index=False)

        def save_preprocessed_data(self, output_path):
            """
            Save the preprocessed data to a pickle file.
            
            :param output_path: str, path to save the preprocessed pickle file
            """
        with open(output_path, 'wb') as f:
            pickle.dump(self.df, f)
        print(f"Preprocessed data saved to {output_path}")

    @classmethod
    def load_preprocessed_data(cls, input_path):
        """
        Load preprocessed data from a pickle file.
        
        :param input_path: str, path to the preprocessed pickle file
        :return: DataPreprocessor instance with loaded data
        """
        with open(input_path, 'rb') as f:
            df = pickle.load(f)

        preprocessor = cls(None)  # Create instance without file path
        preprocessor.df = df
        print(f"Preprocessed data loaded from {input_path}")
        return preprocessor

class CommentThreadManager:
    """
    A class to manage and structure comment threads for articles.
    """

    def __init__(self, df):
        """
        Initialize the CommentThreadManager with a preprocessed DataFrame.
        
        :param df: pandas DataFrame, preprocessed comment data
        """
        self.article_comments = {article_id: group for article_id, group in df.groupby('ID_Article')}

    def build_comment_thread(self, comments, parent_id, depth=0):
        thread = []
        replies = comments[comments['ID_Posting_Parent'] == parent_id]
        for _, reply in replies.iterrows():
            sub_thread = self.build_comment_thread(comments, int(reply['ID_Posting']), depth + 1)
            thread_item = {
                'id': int(reply['ID_Posting']),
                'parent_id': int(reply['ID_Posting_Parent']) if pd.notnull(reply['ID_Posting_Parent']) else None,
                'user_id': int(reply['ID_CommunityIdentity']),
                'user_name': reply['UserCommunityName'],
                'user_gender': reply['UserGender'],
                'user_created_at': reply['UserCreatedAt'].isoformat() if pd.notnull(reply['UserCreatedAt']) else None,
                'comment_headline': reply['PostingHeadline'],
                'comment_text': reply['PostingComment'],
                'comment_created_at': reply['PostingCreatedAt'].isoformat() if pd.notnull(reply['PostingCreatedAt']) else None,
                'comment_length': int(reply['CommentLength']),
                'depth': depth,
                'replies': sub_thread,
                'thread_stats': {
                    'total_comments': 1 + sum(r['thread_stats']['total_comments'] for r in sub_thread),
                    'max_depth': depth + max([r['thread_stats']['max_depth'] for r in sub_thread] + [0]),
                }
            }
            thread.append(thread_item)
        return thread

    def get_article_threads(self, article_id):
        """
        Get the structured comment threads for a specific article.
        
        :param article_id: int, ID of the article
        :return: dict, structured article data with comment threads
        """
        if article_id not in self.article_comments:
            return None

        article_df = self.article_comments[article_id]
        root_comments = article_df[article_df['ID_Posting_Parent'].isnull() | (article_df['ID_Posting_Parent'] == 0)]

        threads = []
        for _, comment in root_comments.iterrows():
            thread = {
                'id': int(comment['ID_Posting']),
                'parent_id': None,
                'user_id': int(comment['ID_CommunityIdentity']),
                'user_name': comment['UserCommunityName'],
                'user_gender': comment['UserGender'],
                'user_created_at': comment['UserCreatedAt'].isoformat() if pd.notnull(comment['UserCreatedAt']) else None,
                'comment_headline': comment['PostingHeadline'],
                'comment_text': comment['PostingComment'],
                'comment_created_at': comment['PostingCreatedAt'].isoformat() if pd.notnull(comment['PostingCreatedAt']) else None,
                'comment_length': int(comment['CommentLength']),
                'depth': 0,
                'replies': self.build_comment_thread(article_df, int(comment['ID_Posting']), 1)
            }
            threads.append(thread)

        article_meta = article_df.iloc[0]

        return {
            'article_id': int(article_id),
            'article_title': article_meta['ArticleTitle'],
            'article_publish_date': article_meta['ArticlePublishingDate'].isoformat() if pd.notnull(article_meta['ArticlePublishingDate']) else None,
            'article_channel': article_meta['ArticleChannel'],
            'article_ressort_name': article_meta['ArticleRessortName'],
            'total_comments': len(article_df),
            'root_comments': len(root_comments),
            'comment_threads': threads
        }

    def get_article_ids(self):
        """
        Get a list of all article IDs in the dataset.
        
        :return: list of int, article IDs
        """
        return list(self.article_comments.keys())
    
    def get_user_ids(self):
        """
        Get a list of all user IDs in the dataset.
        
        :return: list of int, user IDs
        """
        return self.df['ID_CommunityIdentity'].unique().tolist()

# %%
# Usage example
if __name__ == "__main__":
    # Preprocess the data
    preprocessor = DataPreprocessor('./data/raw_csv/Postings_01052019_31052019.csv')
    preprocessor.load_data()
    preprocessor.preprocess()
    preprocessor.save_preprocessed_data('preprocessed_data.csv')

    # Create comment thread manager
    manager = CommentThreadManager(preprocessor.df)

    # Get threads for a specific article
    article_id = 2000102330973  # Example article ID
    result = manager.get_article_threads(article_id)

    # Pretty print the result
    print(json.dumps(result, indent=2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 5
#       2 if __name__ == "__main__":
#       3     # Preprocess the data
#       4     preprocessor = DataPreprocessor('./data/raw_csv/Postings_01052019_31052019.csv')
# ----> 5     preprocessor.load_data()
#       6     preprocessor.preprocess()
#       7     preprocessor.save_preprocessed_data('preprocessed_data.csv')
#
# Cell In[24], line 23, in DataPreprocessor.load_data(self)
#      21 def load_data(self):
#      22     """Load the raw data from CSV file."""
# ---> 23     self.df = pd.read_csv(self.file_path)
#
# File ~/Documents/GitHub/Emotion-Classification-Langgraph/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/GitHub/Emotion-Classification-Langgraph/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/Documents/GitHub/Emotion-Classification-Langgraph/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/Documents/GitHub/Emotion-Classification-Langgraph/venv/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:331, in getstate(self)
#
# KeyboardInterrupt:

# %% [markdown]
# # Now lets start building the context sphere
# I understand your point. You're looking to create a more comprehensive view of a user's activity and interactions within the comment threads. Instead of just seeing isolated comments made by a user, you want to see the full context of their engagement. This includes:
#
# 1. All comments made by the user across different articles.
# 2. For each comment, you want to see the entire thread it belongs to, not just the user's comment in isolation.
# 3. This will show what the user was responding to and how their comment fits into the larger conversation.
# 4. It will also reveal any subsequent responses to the user's comments.
#
# The goal is to build a "context sphere" around each user, showing their complete interaction history within the comment ecosystem. This approach will provide a more nuanced understanding of the user's behavior, opinions, and how they engage with others in discussions.
#
# Is this interpretation correct? If so, I can suggest how to modify your existing code to achieve this goal.

# %%
class UserContextSphere:
    def __init__(self, df, thread_manager):
        self.df = df
        self.thread_manager = thread_manager
        self.user_comments = {user_id: group for user_id, group in df.groupby('ID_CommunityIdentity')}

    def get_user_context(self, user_id):
        if user_id not in self.user_comments:
            return None

        user_df = self.user_comments[user_id]

        # Calculate user statistics
        total_comments = len(user_df)
        total_replies = len(user_df[user_df['ID_Posting_Parent'].notnull()])

        user_context = {
            'user_id': int(user_id),
            'user_name': user_df['UserCommunityName'].iloc[0],
            'user_gender': user_df['UserGender'].iloc[0],
            'user_created_at': user_df['UserCreatedAt'].iloc[0].isoformat(),
            'total_comments': total_comments,
            'total_replies': total_replies,
            'articles': {}
        }

        # Group comments by article
        for article_id, article_comments in user_df.groupby('ID_Article'):
            article_id = int(article_id)
            article_thread = self.thread_manager.get_article_threads(article_id)

            if article_thread:
                user_context['articles'][article_id] = {
                    'article_title': article_thread['article_title'],
                    'article_publish_date': article_thread['article_publish_date'],
                    'user_comments_count': len(article_comments),
                    'user_replies_count': len(article_comments[article_comments['ID_Posting_Parent'].notnull()]),
                    'threads': []
                }

                for _, comment in article_comments.iterrows():
                    thread = self.find_thread_for_comment(article_thread['comment_threads'], int(comment['ID_Posting']))
                    if thread:
                        user_context['articles'][article_id]['threads'].append(thread)

        return user_context

    def find_thread_for_comment(self, threads, comment_id):
        for thread in threads:
            if thread['id'] == comment_id:
                return thread
            if thread['replies']:
                result = self.find_thread_for_comment(thread['replies'], comment_id)
                if result:
                    return thread  # Return the whole thread, not just the subthread
        return None

    def generate_user_report(self, user_id):
        user_context = self.get_user_context(user_id)
        if not user_context:
            return f"No data found for user ID {user_id}"
    
        report = f"User Report for ID: {user_context['user_id']}\n"
        report += f"Name: {user_context['user_name']}\n"
        report += f"Gender: {user_context['user_gender']}\n"
        report += f"Created At: {user_context['user_created_at']}\n"
        report += f"Total Comments: {user_context['total_comments']}\n"
        report += f"Total Replies: {user_context['total_replies']}\n\n"
    
        for article_id, article_data in user_context['articles'].items():
            report += f"Article: {article_data['article_title']}\n"
            report += f"Published: {article_data['article_publish_date']}\n"
            report += f"User Comments on this Article: {article_data['user_comments_count']}\n"
            report += f"User Replies on this Article: {article_data['user_replies_count']}\n\n"
    
            for thread in article_data['threads']:
                report += self.format_thread(thread, user_id, 0)
                report += "\n"
    
        return report

    def format_thread(self, thread, user_id, depth):
        indent = "  " * depth
        is_user = thread['user_id'] == user_id
        user_indicator = " (USER)" if is_user else ""
    
        formatted = f"{indent}[{thread['user_name']}]{user_indicator}: {thread['comment_text']}\n"
    
        for reply in thread['replies']:
            formatted += self.format_thread(reply, user_id, depth + 1)
    
        return formatted

# %%
import os

if __name__ == "__main__":
    preprocessed_file = "data/preprocessed/preprocessed_data.pkl"

    if not os.path.exists(preprocessed_file):
        print("Preprocessed data not found. Preprocessing...")
        preprocessor = DataPreprocessor('./data/raw_csv/Postings_01052019_31052019.csv')
        preprocessor.load_data()
        preprocessor.preprocess()
        preprocessor.save_preprocessed_data(preprocessed_file)
    else:
        print("Loading preprocessed data...")
        preprocessor = DataPreprocessor.load_preprocessed_data(preprocessed_file)

    # Create CommentThreadManager
    thread_manager = CommentThreadManager(preprocessor.df)

    # Create UserContextSphere
    user_context_sphere = UserContextSphere(preprocessor.df, thread_manager)

    # Example: Generate report for a specific user
    user_id = 671476  # Replace with the desired user ID
    user_report = user_context_sphere.generate_user_report(user_id)

    print(user_report)
# Out:
# Loading preprocessed data...
# Preprocessed data loaded from data/preprocessed/preprocessed_data.pkl
# User Report for ID: 671476
# Name: Ravenspower
# Gender: Unknown
# Created At: 2018-04-14T13:42:28.470000
# Total Comments: 431
# Total Replies: 431
#
# Article: Anna Gasser: "Das ist meine erste eigene Wohnung"
# Published: 2019-05-08T06:00:00
# User Comments on this Article: 1
# User Replies on this Article: 1
#
# [Ravenspower] (USER): ....wird nicht drumherumkommen in zukunft wieder das "italienische modell" zu bewerben. also mehrere generationen unter einen dach!
#
# Article: Österreichische Streamerinnen: "Als Frau kämpft man mit Vorurteilen"
# Published: 2019-05-05T10:00:00
# User Comments on this Article: 6
# User Replies on this Article: 6
#
# [AlBundyFan]: ich kann doch selbst speilen - warum soll ich meine zeit damit verplempern anderen beim spielen zuzusehen. ich mein zwischendurch mal....aber mehrere millionen streamer gibt es anscheinend. da könnte man auch 24/7 am tag zusehen und manche sind da vermutlcih garnicht weit davon entfernt.
#   [TheBirdOfHermes]: Streams gucke ich auch nicht.. Aber auf YouTube geschnittene Letsplay schon.. Mich interessiert ja genug nicht.  Wenn das sauber gekürzt ist, ist es toll. Überhaupt um manchmal in ein Spiel "reinzuschnuppern".  Aber jemanden 1:1 zuschauen.. Würde ja gerne wissen, wieviele Twitch einfach im Hintergrund laufen haben und sowieso nicht hinsehen..
#   [And now... this:]: Es ist schön und gut, dass die Faszination daran anderen bei etwas zuzusehen für dich auf ewig ein Rätsel bleibt.  Aber bitte, bitte, schreib nicht auf ewig ein und denselben Kommentar unter jeden Artikel, in dem das Wort "Streaming" vorkommt...
#   [HasmotWerpfon]: Ich hab das auch nie verstanden, wie Leute geradezu fanatisch jede einzelne Übertragung eines Sportevents im TV mitverfolgen und sogar ziemlich verärgert reagieren, wenn durch irgendwas daran gehindert werden. Aber ich schätze mal, ich bin einfach nicht der Typ für sowas.  Twitch hat halt im Gegensatz zu den herkömmlichen Sportübertragungen den Vorteil der Interaktivität. Man kann Live mit dem Spieler kommunizieren und sein Handeln beeinflussen.  Ich persönlich schaue aber auf Twitch auch eher keine reinen Spiele Streams an. Mich interessieren mehr Diskussionen und solche Spieler, die lustig sind, Dinge Erzählen und kommentieren und nicht nur einfach stumm irgendwas runterspielen das gerade aktuell ist.
#   [funnyl]: Und jetzt die - ich kanns eh auch nimmer hören - Antwort:  Wo ist der Unterschied zu Fussball. Die Menschen könnten doch rausgehen und selber spielen. Nein - sie sitzen zu Hause und schauen es sich im TV an.
#   [TheInvisible]: Man kann auch selber Fußball/Tennis spielen und Ski fahren, trotzdem gibt es genug Zuseher. ; )
#     [Ravenspower] (USER): No Comment
#   [Attitude Adjuster]: dafür wie oft du das fragst und welch umfassende antworten du immer wieder bekommst, überrascht es doch, dass du immer noch nicht nachvollziehen kannst, warum andere daran spaß haben.
#     [AlBundyFan]: wenn ein anderer sagt, daß er nicht versteht warum man fußballspiele ansieht, nützt es auch nichts, wenn man ihm erzählt wie spannend man es selbst findet.
#       [Attitude Adjuster]: eigentlich schon. die leute antworten dir immer sehr ausführlich, was ihnen gefällt und warum.  ich kann ja auch nachvollziehen, warum leute marvel-filme schauen, obwohl ich sie selbst uninteressant finde. meine perspektive ist nicht die einzige auf der welt.
#       [And now... this:]: Ich habe noch nie gehört, dass jemand behauptet er versteht nicht, wieso sich jemand Sportveranstaltungen ansieht. Vielleicht interessieren einen gewisse Veranstaltungen nicht, aber das Grundverständnis ist dann doch da, schließlich hat jeder irgendwas, das er sich gerne ansieht.  Aber nur weil dir nicht passt, dass etwas das dich nicht interessiert andere schon interessiert, wird kein Rätsel draus, das man immer wieder niederschreiben muss ;-)
#   [Ravenspower] (USER): die haben eine grosse reichweite und erreichen gewisse zielgruppen sehr präzise...also werden sie als werbeplattform genutzt und ausgeschlachtet...im grunde für wenig geld! natürlich können sie davon leben...aber andere werbeplattformen kosten ein vielfaches.
#     [AlBundyFan]: ich kapiere ja die zuseher nicht die sich das tat für tag ansehen.
#       [funnyl]: Wenn Sie das nicht verstehen - dann können Sie auch nicht verstehen, dass es Menschen gibt, die sich Sport im TV anschauen anstatt es selber zu praktizieren.   Aber ich kann Sie beruhigen. Mann muss nicht immer alles verstehen im Leben. Mir ist bis heute Schleierhaft wie andere Menschen gerne Kümmel essen. Widerlich das Zeug.
#   [Da Harry]: Naja, so ein schwieriges Rätsel ist es nicht. Ich schaue so gut wie nie streams, aber schwer zu verstehen ist es nicht.  1. Man schaut guten Spielern zu. Vergleichbar mit Sportübertragungen. 2. im Vergleich zu anderen Übertragungen im Fernsehen, ist das ganze Interaktiv. Während dem Spiel kann man gleichzeitig mit der Community chatten und der Streamer gibt auch seinen Senf dazu.  Im Endeffekt nicht mehr oder weniger Zeitverschwendung als jedes andere Medium.
#
# [Ravenspower] (USER): nichts gegen streamen. nichts gegen leute die gerne öffentlich spielen.  aber daraus ein geschäftsmodell zu machen...nicht meine welt. youtube sehe ich gerne den einen oder anderen kanal...aber wenn leute dann geld betteln die fliegen...kann er oder sie doch gleich auf der strasse leute anschnorren.  gibt genug youtuber die bieten echten mehrwert und nehmen dafür aber nichts...die lieben es einfach ihr wissen zu teilen.  die damen streamen übrigens beide auf englisch...von dem her ist es völlig egal das österreicherinnen sind.
#   [Copeylius]: Nur weil du es lächerlich nennst, heißt das nicht, dass auch alle anderen das so sehen müssen. Es ist aber natürlich dein gutes Recht, es nicht zu mögen. Keiner wird dazu gezwungen.  Beide Streamerinnen haben einen mehr oder weniger bilingualen Stream. Es ist auch okay, Deutsch zu schreiben. Es ist immer die Frage "woher man kommt" (im Videogame-Bereich) und in welchem Umfeld man sich bewegt. Aus streamtaktischer Sicht macht es durchaus aus Sinn auf Englisch zu streamen, wenn man über den deutschsprachigen Tellerrand blicken will. Willkommen im 21. Jahrhundert ;)
#     [Ravenspower] (USER): nein es ist nicht interessant, wichtig, sinnvoll...seine primark schrotteinkäufe vor der kamera auszupacken...nein es erzeugt keinen mehrwert! nein primark ist kein nachhaltiges geschäft wo man einkaufen sollte. dennoch hat man damit einen primark hype ausgelöst und junge kundinnen herangezüchtet welche bei Primark ausflippen als wäre es ein superstar. youtube "sternchen" haben hier mitgeholfen.
#
# [Copeylius]: ...zwei Jahre lang mit einem englischen Kanal (teils im drei und vierstelligen Zuseherbereich), nun seit ca. 8 Monaten mit dem deutschsprachigen Kanal. Gleich vorweg: bin männlich und demnächst 30. Ich hab viel Mist miterlebt in den letzten drei Jahren. Was mir am meisten dabei aufgefallen ist: Dass Leute unbedingt was sagen müssen, obwohl sie da keinen Einblick in die Materie haben. So anscheinend auch die Poster in dieser Sektion hier. Ja, es gibt Streamerinnen die ihre Weiblichkeit voll ausnutzen. Ja, es gibt auch Streamerinnen die das nicht machen. Streamerinnen die ihren Stream auf ihr Können ausrichten. Problem ist: Erstere machen das Leben für Zweitere schwierig. Wie oft durfte ich schon lesen "ey, zeig mal Titten".
#   [Orgonaut79]: link wär cool
#     [Copeylius]: Das Forum soll nicht für Eigenwerbung oder Promotion genutzt werden. Aber wer suchet, der findet ;)
#   [schneiderlein streck dich]: Dann wissen Sie sicher auch, dass die Zahl der Streamerinnen die nicht, wie Sie es ausdrücken "ihre Weiblichkeit voll ausnutzen" leider relativ gering ist. Ich beziehe mich hier gar nicht auf die Beiden Frauen die im Artikel behandelt werden. Auch wenn ihr Aussehen ihnen sicherlich alles andere als abträglich ist auf dieser Plattform. Sie werden sicher auch wissen, zumindest lassen Ihre beiden letzten Sätze dies vermuten, dass der echte Rubel dort nicht von "normalen" Streamern gemacht wird. "just dance", "just chatting" und Namen wie "Amouranth" (um nur eine von der Sorte zu nennen) sind ein Begriff?  Frauen die "normal" spielen & streamen sind nicht gerade das weibliche Gesicht von Twitch. Leider
#     [Copeylius]: Ich widerspreche Ihrem Posting nur in einer Hinsicht: es gibt mehr Streamerinnen die sich nicht wie z.B. die von Ihnen genannte Amouranth verhalten. Aber sie haben schon recht, jene Streamerinnen sind auch gerade deswegen weniger medial vertreten, weil sie sich eben nicht so vertreten. Der (in Gesamtsumme betrachtete) Rubel rollt wo anders, ja.
#     [DasBug]: Und ihr Problem damit ist was? Sie müssen's ja nicht schauen. Ist ja noch nicht mal wie im Fernsehen, wo es nur begrenzte Sendeplätze gibt.  Die sind erfolgreich und sichtbar, weil es genug Leute gibt, wahrscheinlich Männer, die das sehen wollen. Wenn, dann müssen Sie dem Publikum einen Vorwurf machen...
#       [schneiderlein streck dich]: Sie hätten vollkommen recht, wäre da nicht...  https://www.twitch.tv/p/legal/community-guidelines/sexualcontent/  Darüber hinaus: Twitch vermarktet sich als ein Streaming Service für Spiele, drückt aber bei Porno-light Kanälen die Kohle bringen beide Augen zu. Ich haben überhaupt kein Problem mit derartigem Inhalt, da ich, wie Sie richtig bemerken, es mir ja nicht anshen muss. Mein Problem ist, dass Twitch die eigenen Regeln nicht befolgt. Würden die Betreffenden ihren Inhalt auf den dafür vorgesehenen Plattformen verbreiten wäre mir das vollkommen egal.
#         [DasBug]: Aha. Na da freue ich mich, dass Sie sicherlich noch mehr Energie auf Kritik an Amazons Steuersparpraktiken oder auf den Krieg im Jemen aufwenden.   Weil da geht es ja um wirklich was und nicht nur darum, dass irgendjemand irgendwo Sachen aufschreibt und dann nicht beachtet, ohne dass es tatsächlich jmd. zum Nachteil gereicht.
#           [schneiderlein streck dich]: Ist alles ok zu Hause? Was haben diese Problem jetzt genau mit diesem hier zu tun???
#   [Copeylius]: Das muss unglaublich lustig sein für eine Streamerin. Stell ich mir richtig prickelnd vor. Das sind dann die Zuschauer, die anfangen die Streamerinnen zu beleidigen und ihren Stream als langweilig bezeichnen, nur weil jene Streamerinnen eben nicht auf die „Sex Sells“ Schiene aufspringen. Es ist also ein Problem in zweifacher Hinsicht: Streamerinnen die das Problem in/direkt fördern und dann unreflektierte Zuseher, die oft in der Pubertät stecken (geblieben sind) oder sich bei der Plattform vertan haben. Wer sich die Streams von Miss_Rage und StefaniaHades ansieht, wird erkennen, dass die beiden eben nicht zur ersten Kategorie zählen, sondern auf ihre spielerischen Talente setzen.
#     [Copeylius]: Aber das ist natürlich nur etwas, was man wissen kann, wenn man den beiden auch mal zugesehen hat. Also mein Aufruf: schaut bei ihnen vorbei und betrachtet das Gesehen aus einer zuerst objektiven, im Anschluss subjektiven Sichtweise.  Ich persönlich kenne eine ähnliche Situation und weiß daher, wie lästig ein solcher Umstand sein kann. Zu den Zeiten als Outdoor-Streams bekannt wurden, produzierte ich auch selbst solche Streams. Allerdings hörte ich damit auch schnell wieder auf.
#       [Copeylius]: Der Grund ist einfach erklärt: andere Streamer machten ziemlich viel Unfug, was einen gewissen Schlag von Zusehern in ihre Kanäle spülte. Dies zog umso mehr Leute an und wurde zum „Standard“ der IRL-Outdoorstreams. War ich nun live, bekam ich Zuseher von diesem Schlag zu mir in den Kanal und musste mir anhören wie „langweilig doch mein Stream sei“, weil ich keine Gesetze breche, keine Leute belästige oder mich generell dumm aufführe. Als Streamer und Streamerin kämpft man daher immer mit dem, was als Standard für eine Kategorie gesehen wird. An dieser Stelle muss man auch Twitch mit in die Pflicht nehmen.
#         [Copeylius]: Aber zurück zum eigentlichen Thema: Es gibt zahlreiche männliche Streamer, die sich über die weiblichen „Sex-Sells“ Streamerinnen aufregen, weil „die. allein weil sie Frauen sind und es auch zeigen, die Zuseher“ einem wegnehmen. Oft schon gehört, oft schon darüber den Kopf geschüttelt. Das sind zwei unterschiedliche Zuschauerkategorien. Zuseher, die auf sowas abfahren, werden höchstwahrscheinlich ohnehin nicht Teil deiner eigenen Community oder Zuseherschaft. Aber Streamer lassen sich halt sehr von Zahlen beeinflussen, jemand hat mehr Zuseher als man selbst und schon ist der Neid vorhanden.
#           [Copeylius]: Ich leite Österreichs größte Community für österreichische Streamer. Wir haben 50 volle MitgliederInnen, im gesamten Umfang erreichen wir aber um die 250 Streamerinnen und Streamer aus Österreich. Davon sind einige auch weiblich. Alle von Ihnen bauen entweder auf ihre „Skills“ oder auf ihren Unterhaltungswert, respektive auf beidem auf. Bitte unterschätzt nicht die Anzahl der Streamerinnen die ihren Stream eben nicht durch Sex-Sells definieren.  Abschließend: Habt Spaß auf Twitch, unterstützt eure Leute und bitte schert nicht alle über einen Kamm - danke!
#             [kifferboy]: danke für die postings... so geht sachlich und informativ, danke dafür :) daumen nach oben
#             [ChiaraOfDoom]: Ich darf mich hier als Mitglied, dieser oben genannten Community, outen. Kann hier nur copeylius zustimmen! Die Frauen überzeugen mit ihren individuellen Talenten und sind sehr sympathisch bzw. werden als ein gleichberechtigter Teil der Community angesehen. Ich selbst, schaue ihnen oft zu und empfehle euch allen dies mal zu tun.  Auch verfolge ich gelegen die Streams von StefaniaHades, ja sie schmickt sich, was für ein Verbrechen, und dennoch schaue ich nicht zu, weil sie eine Frau ist, sondern Talent hat und sie einfach gute Entertainerin ist!
#             [Naridulu]: danke für die einsicht, kann vielen diese video-serie empfehlen "omg a girl" https://www.youtube.com/watch?v=jL0aVqVslSE
#     [Max Mustardman 999]: Die Userbase richtet sich logischerweise nach dem Auftreten der Streamerin bzw. Youtuberin aus. Aber ich verfolge 3-5 Damen auf Youtube bzw. Twitch, und habe dergleichen eigentlich noch nie gelesen.
#       [Copeylius]: Natürlich zieht man durch die eigene Persönlichkeit und Skills einen gewissen "Durchschnittszuseher" an. In diesen Kategorieren denken aber nicht alle Zuseher. Da reicht zum Teil einfach schon das Geschlecht des Streamers bzw. der Streamerin. Das ist das Erste was die Leute bei einem Kanal sehen/hören/mitbekommen, danach erst Persönlichkeit und Skill. Das spielt sich also auf mehreren Ebenen ab. Das schlimmste ist das steckenbleiben in der ersten Ebene, ein klassisches Reduzieren auf das Geschlecht.
#     [Daniel Koller]: No Comment
#   [Orgonaut79]: No Comment
#     [Copeylius]: No Comment
#   [a song vom Schweiß der Eier]: Glaub ich gern. Aber braucht die Menschheit wirklich so viel von noch mehr? Wir palavern immer von „Rettet das Klima“ bis „Ressourcen schonen“ etc und produzieren dabei Daten(müll), um die Reichweite zu erhöhen. Kann man nicht auch bloß spielen, ohne auf Zuschauerapplaus angewiesen zu sein?
#     [Copeylius]: Du missverstehst das Geschäftsmodell von Personen, die ihren Lebensunerhalt damit verdienen wollen.
#       [Ravenspower] (USER): die meisten streamer (dazu zähle ich auch youtube) bringen durch ihre oberflächlichen darstellungen falsche oder ungute ideen in die köpfe der jungen.  beispiel: nein - es ist nicht wichtig, interessant oder der lebensmittelpunkt wenn jemand seine Primark schrotteinkäufe vor der kamera präsentiert und auspackt. nein - die dame ist auch keine heldin oder ein star deswegen. Nein - ich spende für einnen nullmehrwert nichts.
#         [Copeylius]: Wenn wir bei dieser Basis für eine Fragestellung anfangen, dann kann man alles in Frage stellen. Warum produziert man Videos auf youtube? Warum nutze ich Instagram? Warum bin ich überhaupt im Internet unterwegs? Warum ist ein FPÖ Politiker ein solcher Politiker geworden?  Wer nicht streamt, kann die Faszination dahinter nicht verstehen. Dass es Leute gibt, die ihre Reichweite dann auch nutzen (teils positiv, teils negativ) ist Fakt - das ist ein Thema der derzeit allseits bekannten "Influencer". Ich selbst halte wenig davon, ist aber ein Trend und das Ergebnis der letzten Jahrzehnte. Ich vermeide es auch so gut es geht, beeinflusst zu wirken - ganz vermeiden lässt sich das aber nicht.
#           [Ravenspower] (USER): gutes beispiel: youtube - "neulichimgarten" der selbstversorgerkanal! der typ gibt sein wissen preis...das hat mehrwert. wenn jemand dafür freiwillig spendet - vollstes verständnis! Der könnte 30 bücher füllen! aber: noch nie hab ich diesen menschen um geld oder spenden betteln gehört. sie verstehen?  gegenbeispiel: ich spiele ein videogame, streame es...mehrwert defakto null. ersuche dabei um spenden für was genau?
#             [Copeylius]: Sie messen das mit unterschiedlichen Messlatten, bzw. vergleichen Birnen mit Äpfel. Was ist der Mehrwert von sämtlichen Unterhatlungsmedien dann? Was ist der Mehrwert von Fußball-Übertragungen im Fernsehen?  Es geht hier um den Unterhatlungswert. Jeder Mensch wird durch Unterschiedliches unterhalten, was für den einen unterhaltsam wirkt, ist für den anderen langweilig. Das ist auch das Prinzip auf Twitch, YouTube, etc.Der Mehrwert ist die Unterhaltung der Personen. Das ist vielleicht etwas, was sie nicht nachvollziehen können, für anderen ist das aber eine Art "Abschalten" oder einfach eine Freizeitbeschäftigung. Betteln um Spenden funktioniert ohnehin nicht, denn es gibt nur derjenige, der auch geben will.
#             [KawauTV]: Twitch ist inzwischen sehr viel mehr als nur Gaming. Es gibt Bastel-, Koch- und Musik-Streams ebenso wie Talk-Shows und vieles mehr.
#         [Tristan Prince]: Wow, da ist ja wer frustriert.
#         [And now... this:]: Wovon lebst du, wenn ich fragen darf?
#
# [Copeylius]: ...zwei Jahre lang mit einem englischen Kanal (teils im drei und vierstelligen Zuseherbereich), nun seit ca. 8 Monaten mit dem deutschsprachigen Kanal. Gleich vorweg: bin männlich und demnächst 30. Ich hab viel Mist miterlebt in den letzten drei Jahren. Was mir am meisten dabei aufgefallen ist: Dass Leute unbedingt was sagen müssen, obwohl sie da keinen Einblick in die Materie haben. So anscheinend auch die Poster in dieser Sektion hier. Ja, es gibt Streamerinnen die ihre Weiblichkeit voll ausnutzen. Ja, es gibt auch Streamerinnen die das nicht machen. Streamerinnen die ihren Stream auf ihr Können ausrichten. Problem ist: Erstere machen das Leben für Zweitere schwierig. Wie oft durfte ich schon lesen "ey, zeig mal Titten".
#   [Orgonaut79]: link wär cool
#     [Copeylius]: Das Forum soll nicht für Eigenwerbung oder Promotion genutzt werden. Aber wer suchet, der findet ;)
#   [schneiderlein streck dich]: Dann wissen Sie sicher auch, dass die Zahl der Streamerinnen die nicht, wie Sie es ausdrücken "ihre Weiblichkeit voll ausnutzen" leider relativ gering ist. Ich beziehe mich hier gar nicht auf die Beiden Frauen die im Artikel behandelt werden. Auch wenn ihr Aussehen ihnen sicherlich alles andere als abträglich ist auf dieser Plattform. Sie werden sicher auch wissen, zumindest lassen Ihre beiden letzten Sätze dies vermuten, dass der echte Rubel dort nicht von "normalen" Streamern gemacht wird. "just dance", "just chatting" und Namen wie "Amouranth" (um nur eine von der Sorte zu nennen) sind ein Begriff?  Frauen die "normal" spielen & streamen sind nicht gerade das weibliche Gesicht von Twitch. Leider
#     [Copeylius]: Ich widerspreche Ihrem Posting nur in einer Hinsicht: es gibt mehr Streamerinnen die sich nicht wie z.B. die von Ihnen genannte Amouranth verhalten. Aber sie haben schon recht, jene Streamerinnen sind auch gerade deswegen weniger medial vertreten, weil sie sich eben nicht so vertreten. Der (in Gesamtsumme betrachtete) Rubel rollt wo anders, ja.
#     [DasBug]: Und ihr Problem damit ist was? Sie müssen's ja nicht schauen. Ist ja noch nicht mal wie im Fernsehen, wo es nur begrenzte Sendeplätze gibt.  Die sind erfolgreich und sichtbar, weil es genug Leute gibt, wahrscheinlich Männer, die das sehen wollen. Wenn, dann müssen Sie dem Publikum einen Vorwurf machen...
#       [schneiderlein streck dich]: Sie hätten vollkommen recht, wäre da nicht...  https://www.twitch.tv/p/legal/community-guidelines/sexualcontent/  Darüber hinaus: Twitch vermarktet sich als ein Streaming Service für Spiele, drückt aber bei Porno-light Kanälen die Kohle bringen beide Augen zu. Ich haben überhaupt kein Problem mit derartigem Inhalt, da ich, wie Sie richtig bemerken, es mir ja nicht anshen muss. Mein Problem ist, dass Twitch die eigenen Regeln nicht befolgt. Würden die Betreffenden ihren Inhalt auf den dafür vorgesehenen Plattformen verbreiten wäre mir das vollkommen egal.
#         [DasBug]: Aha. Na da freue ich mich, dass Sie sicherlich noch mehr Energie auf Kritik an Amazons Steuersparpraktiken oder auf den Krieg im Jemen aufwenden.   Weil da geht es ja um wirklich was und nicht nur darum, dass irgendjemand irgendwo Sachen aufschreibt und dann nicht beachtet, ohne dass es tatsächlich jmd. zum Nachteil gereicht.
#           [schneiderlein streck dich]: Ist alles ok zu Hause? Was haben diese Problem jetzt genau mit diesem hier zu tun???
#   [Copeylius]: Das muss unglaublich lustig sein für eine Streamerin. Stell ich mir richtig prickelnd vor. Das sind dann die Zuschauer, die anfangen die Streamerinnen zu beleidigen und ihren Stream als langweilig bezeichnen, nur weil jene Streamerinnen eben nicht auf die „Sex Sells“ Schiene aufspringen. Es ist also ein Problem in zweifacher Hinsicht: Streamerinnen die das Problem in/direkt fördern und dann unreflektierte Zuseher, die oft in der Pubertät stecken (geblieben sind) oder sich bei der Plattform vertan haben. Wer sich die Streams von Miss_Rage und StefaniaHades ansieht, wird erkennen, dass die beiden eben nicht zur ersten Kategorie zählen, sondern auf ihre spielerischen Talente setzen.
#     [Copeylius]: Aber das ist natürlich nur etwas, was man wissen kann, wenn man den beiden auch mal zugesehen hat. Also mein Aufruf: schaut bei ihnen vorbei und betrachtet das Gesehen aus einer zuerst objektiven, im Anschluss subjektiven Sichtweise.  Ich persönlich kenne eine ähnliche Situation und weiß daher, wie lästig ein solcher Umstand sein kann. Zu den Zeiten als Outdoor-Streams bekannt wurden, produzierte ich auch selbst solche Streams. Allerdings hörte ich damit auch schnell wieder auf.
#       [Copeylius]: Der Grund ist einfach erklärt: andere Streamer machten ziemlich viel Unfug, was einen gewissen Schlag von Zusehern in ihre Kanäle spülte. Dies zog umso mehr Leute an und wurde zum „Standard“ der IRL-Outdoorstreams. War ich nun live, bekam ich Zuseher von diesem Schlag zu mir in den Kanal und musste mir anhören wie „langweilig doch mein Stream sei“, weil ich keine Gesetze breche, keine Leute belästige oder mich generell dumm aufführe. Als Streamer und Streamerin kämpft man daher immer mit dem, was als Standard für eine Kategorie gesehen wird. An dieser Stelle muss man auch Twitch mit in die Pflicht nehmen.
#         [Copeylius]: Aber zurück zum eigentlichen Thema: Es gibt zahlreiche männliche Streamer, die sich über die weiblichen „Sex-Sells“ Streamerinnen aufregen, weil „die. allein weil sie Frauen sind und es auch zeigen, die Zuseher“ einem wegnehmen. Oft schon gehört, oft schon darüber den Kopf geschüttelt. Das sind zwei unterschiedliche Zuschauerkategorien. Zuseher, die auf sowas abfahren, werden höchstwahrscheinlich ohnehin nicht Teil deiner eigenen Community oder Zuseherschaft. Aber Streamer lassen sich halt sehr von Zahlen beeinflussen, jemand hat mehr Zuseher als man selbst und schon ist der Neid vorhanden.
#           [Copeylius]: Ich leite Österreichs größte Community für österreichische Streamer. Wir haben 50 volle MitgliederInnen, im gesamten Umfang erreichen wir aber um die 250 Streamerinnen und Streamer aus Österreich. Davon sind einige auch weiblich. Alle von Ihnen bauen entweder auf ihre „Skills“ oder auf ihren Unterhaltungswert, respektive auf beidem auf. Bitte unterschätzt nicht die Anzahl der Streamerinnen die ihren Stream eben nicht durch Sex-Sells definieren.  Abschließend: Habt Spaß auf Twitch, unterstützt eure Leute und bitte schert nicht alle über einen Kamm - danke!
#             [kifferboy]: danke für die postings... so geht sachlich und informativ, danke dafür :) daumen nach oben
#             [ChiaraOfDoom]: Ich darf mich hier als Mitglied, dieser oben genannten Community, outen. Kann hier nur copeylius zustimmen! Die Frauen überzeugen mit ihren individuellen Talenten und sind sehr sympathisch bzw. werden als ein gleichberechtigter Teil der Community angesehen. Ich selbst, schaue ihnen oft zu und empfehle euch allen dies mal zu tun.  Auch verfolge ich gelegen die Streams von StefaniaHades, ja sie schmickt sich, was für ein Verbrechen, und dennoch schaue ich nicht zu, weil sie eine Frau ist, sondern Talent hat und sie einfach gute Entertainerin ist!
#             [Naridulu]: danke für die einsicht, kann vielen diese video-serie empfehlen "omg a girl" https://www.youtube.com/watch?v=jL0aVqVslSE
#     [Max Mustardman 999]: Die Userbase richtet sich logischerweise nach dem Auftreten der Streamerin bzw. Youtuberin aus. Aber ich verfolge 3-5 Damen auf Youtube bzw. Twitch, und habe dergleichen eigentlich noch nie gelesen.
#       [Copeylius]: Natürlich zieht man durch die eigene Persönlichkeit und Skills einen gewissen "Durchschnittszuseher" an. In diesen Kategorieren denken aber nicht alle Zuseher. Da reicht zum Teil einfach schon das Geschlecht des Streamers bzw. der Streamerin. Das ist das Erste was die Leute bei einem Kanal sehen/hören/mitbekommen, danach erst Persönlichkeit und Skill. Das spielt sich also auf mehreren Ebenen ab. Das schlimmste ist das steckenbleiben in der ersten Ebene, ein klassisches Reduzieren auf das Geschlecht.
#     [Daniel Koller]: No Comment
#   [Orgonaut79]: No Comment
#     [Copeylius]: No Comment
#   [a song vom Schweiß der Eier]: Glaub ich gern. Aber braucht die Menschheit wirklich so viel von noch mehr? Wir palavern immer von „Rettet das Klima“ bis „Ressourcen schonen“ etc und produzieren dabei Daten(müll), um die Reichweite zu erhöhen. Kann man nicht auch bloß spielen, ohne auf Zuschauerapplaus angewiesen zu sein?
#     [Copeylius]: Du missverstehst das Geschäftsmodell von Personen, die ihren Lebensunerhalt damit verdienen wollen.
#       [Ravenspower] (USER): die meisten streamer (dazu zähle ich auch youtube) bringen durch ihre oberflächlichen darstellungen falsche oder ungute ideen in die köpfe der jungen.  beispiel: nein - es ist nicht wichtig, interessant oder der lebensmittelpunkt wenn jemand seine Primark schrotteinkäufe vor der kamera präsentiert und auspackt. nein - die dame ist auch keine heldin oder ein star deswegen. Nein - ich spende für einnen nullmehrwert nichts.
#         [Copeylius]: Wenn wir bei dieser Basis für eine Fragestellung anfangen, dann kann man alles in Frage stellen. Warum produziert man Videos auf youtube? Warum nutze ich Instagram? Warum bin ich überhaupt im Internet unterwegs? Warum ist ein FPÖ Politiker ein solcher Politiker geworden?  Wer nicht streamt, kann die Faszination dahinter nicht verstehen. Dass es Leute gibt, die ihre Reichweite dann auch nutzen (teils positiv, teils negativ) ist Fakt - das ist ein Thema der derzeit allseits bekannten "Influencer". Ich selbst halte wenig davon, ist aber ein Trend und das Ergebnis der letzten Jahrzehnte. Ich vermeide es auch so gut es geht, beeinflusst zu wirken - ganz vermeiden lässt sich das aber nicht.
#           [Ravenspower] (USER): gutes beispiel: youtube - "neulichimgarten" der selbstversorgerkanal! der typ gibt sein wissen preis...das hat mehrwert. wenn jemand dafür freiwillig spendet - vollstes verständnis! Der könnte 30 bücher füllen! aber: noch nie hab ich diesen menschen um geld oder spenden betteln gehört. sie verstehen?  gegenbeispiel: ich spiele ein videogame, streame es...mehrwert defakto null. ersuche dabei um spenden für was genau?
#             [Copeylius]: Sie messen das mit unterschiedlichen Messlatten, bzw. vergleichen Birnen mit Äpfel. Was ist der Mehrwert von sämtlichen Unterhatlungsmedien dann? Was ist der Mehrwert von Fußball-Übertragungen im Fernsehen?  Es geht hier um den Unterhatlungswert. Jeder Mensch wird durch Unterschiedliches unterhalten, was für den einen unterhaltsam wirkt, ist für den anderen langweilig. Das ist auch das Prinzip auf Twitch, YouTube, etc.Der Mehrwert ist die Unterhaltung der Personen. Das ist vielleicht etwas, was sie nicht nachvollziehen können, für anderen ist das aber eine Art "Abschalten" oder einfach eine Freizeitbeschäftigung. Betteln um Spenden funktioniert ohnehin nicht, denn es gibt nur derjenige, der auch geben will.
#             [KawauTV]: Twitch ist inzwischen sehr viel mehr als nur Gaming. Es gibt Bastel-, Koch- und Musik-Streams ebenso wie Talk-Shows und vieles mehr.
#         [Tristan Prince]: Wow, da ist ja wer frustriert.
#         [And now... this:]: Wovon lebst du, wenn ich fragen darf?
#
# [Ravenspower] (USER): nichts gegen streamen. nichts gegen leute die gerne öffentlich spielen.  aber daraus ein geschäftsmodell zu machen...nicht meine welt. youtube sehe ich gerne den einen oder anderen kanal...aber wenn leute dann geld betteln die fliegen...kann er oder sie doch gleich auf der strasse leute anschnorren.  gibt genug youtuber die bieten echten mehrwert und nehmen dafür aber nichts...die lieben es einfach ihr wissen zu teilen.  die damen streamen übrigens beide auf englisch...von dem her ist es völlig egal das österreicherinnen sind.
#   [Copeylius]: Nur weil du es lächerlich nennst, heißt das nicht, dass auch alle anderen das so sehen müssen. Es ist aber natürlich dein gutes Recht, es nicht zu mögen. Keiner wird dazu gezwungen.  Beide Streamerinnen haben einen mehr oder weniger bilingualen Stream. Es ist auch okay, Deutsch zu schreiben. Es ist immer die Frage "woher man kommt" (im Videogame-Bereich) und in welchem Umfeld man sich bewegt. Aus streamtaktischer Sicht macht es durchaus aus Sinn auf Englisch zu streamen, wenn man über den deutschsprachigen Tellerrand blicken will. Willkommen im 21. Jahrhundert ;)
#     [Ravenspower] (USER): nein es ist nicht interessant, wichtig, sinnvoll...seine primark schrotteinkäufe vor der kamera auszupacken...nein es erzeugt keinen mehrwert! nein primark ist kein nachhaltiges geschäft wo man einkaufen sollte. dennoch hat man damit einen primark hype ausgelöst und junge kundinnen herangezüchtet welche bei Primark ausflippen als wäre es ein superstar. youtube "sternchen" haben hier mitgeholfen.
#
# [AlBundyFan]: ich kann doch selbst speilen - warum soll ich meine zeit damit verplempern anderen beim spielen zuzusehen. ich mein zwischendurch mal....aber mehrere millionen streamer gibt es anscheinend. da könnte man auch 24/7 am tag zusehen und manche sind da vermutlcih garnicht weit davon entfernt.
#   [TheBirdOfHermes]: Streams gucke ich auch nicht.. Aber auf YouTube geschnittene Letsplay schon.. Mich interessiert ja genug nicht.  Wenn das sauber gekürzt ist, ist es toll. Überhaupt um manchmal in ein Spiel "reinzuschnuppern".  Aber jemanden 1:1 zuschauen.. Würde ja gerne wissen, wieviele Twitch einfach im Hintergrund laufen haben und sowieso nicht hinsehen..
#   [And now... this:]: Es ist schön und gut, dass die Faszination daran anderen bei etwas zuzusehen für dich auf ewig ein Rätsel bleibt.  Aber bitte, bitte, schreib nicht auf ewig ein und denselben Kommentar unter jeden Artikel, in dem das Wort "Streaming" vorkommt...
#   [HasmotWerpfon]: Ich hab das auch nie verstanden, wie Leute geradezu fanatisch jede einzelne Übertragung eines Sportevents im TV mitverfolgen und sogar ziemlich verärgert reagieren, wenn durch irgendwas daran gehindert werden. Aber ich schätze mal, ich bin einfach nicht der Typ für sowas.  Twitch hat halt im Gegensatz zu den herkömmlichen Sportübertragungen den Vorteil der Interaktivität. Man kann Live mit dem Spieler kommunizieren und sein Handeln beeinflussen.  Ich persönlich schaue aber auf Twitch auch eher keine reinen Spiele Streams an. Mich interessieren mehr Diskussionen und solche Spieler, die lustig sind, Dinge Erzählen und kommentieren und nicht nur einfach stumm irgendwas runterspielen das gerade aktuell ist.
#   [funnyl]: Und jetzt die - ich kanns eh auch nimmer hören - Antwort:  Wo ist der Unterschied zu Fussball. Die Menschen könnten doch rausgehen und selber spielen. Nein - sie sitzen zu Hause und schauen es sich im TV an.
#   [TheInvisible]: Man kann auch selber Fußball/Tennis spielen und Ski fahren, trotzdem gibt es genug Zuseher. ; )
#     [Ravenspower] (USER): No Comment
#   [Attitude Adjuster]: dafür wie oft du das fragst und welch umfassende antworten du immer wieder bekommst, überrascht es doch, dass du immer noch nicht nachvollziehen kannst, warum andere daran spaß haben.
#     [AlBundyFan]: wenn ein anderer sagt, daß er nicht versteht warum man fußballspiele ansieht, nützt es auch nichts, wenn man ihm erzählt wie spannend man es selbst findet.
#       [Attitude Adjuster]: eigentlich schon. die leute antworten dir immer sehr ausführlich, was ihnen gefällt und warum.  ich kann ja auch nachvollziehen, warum leute marvel-filme schauen, obwohl ich sie selbst uninteressant finde. meine perspektive ist nicht die einzige auf der welt.
#       [And now... this:]: Ich habe noch nie gehört, dass jemand behauptet er versteht nicht, wieso sich jemand Sportveranstaltungen ansieht. Vielleicht interessieren einen gewisse Veranstaltungen nicht, aber das Grundverständnis ist dann doch da, schließlich hat jeder irgendwas, das er sich gerne ansieht.  Aber nur weil dir nicht passt, dass etwas das dich nicht interessiert andere schon interessiert, wird kein Rätsel draus, das man immer wieder niederschreiben muss ;-)
#   [Ravenspower] (USER): die haben eine grosse reichweite und erreichen gewisse zielgruppen sehr präzise...also werden sie als werbeplattform genutzt und ausgeschlachtet...im grunde für wenig geld! natürlich können sie davon leben...aber andere werbeplattformen kosten ein vielfaches.
#     [AlBundyFan]: ich kapiere ja die zuseher nicht die sich das tat für tag ansehen.
#       [funnyl]: Wenn Sie das nicht verstehen - dann können Sie auch nicht verstehen, dass es Menschen gibt, die sich Sport im TV anschauen anstatt es selber zu praktizieren.   Aber ich kann Sie beruhigen. Mann muss nicht immer alles verstehen im Leben. Mir ist bis heute Schleierhaft wie andere Menschen gerne Kümmel essen. Widerlich das Zeug.
#   [Da Harry]: Naja, so ein schwieriges Rätsel ist es nicht. Ich schaue so gut wie nie streams, aber schwer zu verstehen ist es nicht.  1. Man schaut guten Spielern zu. Vergleichbar mit Sportübertragungen. 2. im Vergleich zu anderen Übertragungen im Fernsehen, ist das ganze Interaktiv. Während dem Spiel kann man gleichzeitig mit der Community chatten und der Streamer gibt auch seinen Senf dazu.  Im Endeffekt nicht mehr oder weniger Zeitverschwendung als jedes andere Medium.
#
# Article: Roter Weltrevolutionär trifft Pragmatiker: "In der SPÖ stimmt etwas nicht"
# Published: 2019-05-01T08:00:00
# User Comments on this Article: 1
# User Replies on this Article: 1
#
# [Ravenspower] (USER): No Comment
#   [6398e46e-a6a5-4757-8ee1-b66325cd0516]: Ja. Er hat dabei gemeint er würde ja eh 24/7 für Traiskirchen arbeiten. Wo er dann noch seine Freizeitaktivitäten untergebracht hat - Heurigenwirt, viel in der SP unterwegs. ist mir zwar unerklärlich. Aber wie sagt man so schön. Der Tag hat 24 Stunden und in der Nacht kann man auch noch a bisserl was tun
#
# Article: 1. Mai in Wien: SPÖ fordert von Strache Rücktritt
# Published: 2019-05-01T10:28:57.490000
# User Comments on this Article: 63
# User Replies on this Article: 63
#
# [Tellur]: Hinweis auf eigene SPÖ Leistungen gegeben? Zukunftspläne, Konzepte?? Im Prinzip war es ein Schüren von diffusen Ängsten und ein Verächtlichmachung der Regierung. Peinlich für die größte Oppositionspartei...
#   [wolfgangwanicek]: Ich war dort. 1) die Reden waren gut - durchwegs gerechtfertigte und gute Kritik an türkis blau 2) Leider haben Sie recht - es fehlte an dem attraktiven antineoliberalen Projekt. Leider haben die Sozialdemokraten da offensichtlich keine Idee. Das ist es was den Erfolg von ÖVP/FPÖ ermöglicht.   Nur sinngemäß zu sagen, "wir würden einen sanfteren Neoliberalismus machen!" ist zu wenig.   Dabei wäre es nicht so schwer: etwa: https://makroskop.eu/2019/04/wo-bleibt-die-neue-wirtschaftspolitik/  oder auch: https://stephanschulmeister.wifo-pens.at/fileadmin/homepage_schulmeister/files/Schulmeister_Prosperitaet_Einl_14_17_20.pdf
#     [Ravenspower] (USER): schieder hatte dem inhaltlich nichts entgegenzusetzen. https://www.youtube.com/watch?v=yiJ-sdjn2Zg
#     [GuteNachtSchaukel]: Gerade Andreas Schieder und Marina Hanke zeigen deutlich, dass sie das verstanden haben - ich denke da findet gerade ein Wechsel statt, der unterstützenswert ist.
#       [wolfgangwanicek]: Schieder hat den neoliberalen Vranitzky hervorgehoben. Das ist eine doch sehr missverständliche Botschaft.  Ich habe nix dagegen den Antifaschisten Vranitzky zu würdigen. Wenn man zugleich auch inhaltlich klar sich positioniert gegen neoliberale Wirtschaftspolitik.  Die ganz Sozialdemokratie - auch Schieder - kann das nicht. Das Plakat mit einer jungen AmazonKonsumentin drückt dieses weltanschauliche Durcheinander leider sehr gut aus.   Ich bedauere all das und hoffe dass sich das irgendwann ändern wird. Eine gedeihliche Entwicklung Österreichs und Europas braucht die Sozialdemokratie.
#         [GuteNachtSchaukel]: dazugelernt hat.  Ich sehe die Sozialdemokratie da in einem Lernprozess und die Ablehnung der neoliberalen Konzepte ist dabei im starken Aufwind - Leute wie Marina Hanke und Julia Herr sind da wohltuend federführend - Schieder ist ebenfalls auf einem guten Weg.  Und ja, auch ich wünsche mir eine längst fällige offizielle Abkehr vom 3. Weg Schröder und Blairs und insbesondere auch eine ehrliche Analyse der Griechenlandkrise um klar zu machen, dass man sich auch vom damaligen Weg der Konservativen distanziert.  Schließlich ist die damalige Grichenlandpolitik hauptverantwortlich für die tiefe Vertrauenskrise der Menschen in die EU (die Flüchtlingskrise nur von den Rechtsrechten propagandistisch aufgeblasen)
#         [GuteNachtSchaukel]: Der Kurier fühlt sich hier zwar bemüssigt die guten und wichtigen Ideen der aktuellen Sozialdemokratie zu verhöhnen - dennoch zeigt der Kommentar, dass die Sozialdemokratie tatsächlich den Schwenk weg vom Neoliberalismus vollzieht https://kurier.at/meinung/die-seltsame-welt-der-bobo-sozis/400482427
#         [Bberg]: Vranitzky und Lacina haben 1993 das Privatstiftungsgesetz eingeführt und damit den reichsten Familien Österreichs die Möglichkeit gegeben ihr Vermögen steuergünstig über Generationen zu sichern.  Dieser Verrat an den Ideen der Sozialdemokratie wurde als Maßnahme gegen  den Kapitalabfluss ins Ausland argumentiert.  Die Sozialdemokraten, insbesondere unter Renner, haben sich von 1919 bis 1938 vergeblich bemüht die Familienfideikommisse (stiftungsähnliche Einrichtungen) des Adels zu beseitigen. Erst 1938 unter Hitler wurden die Familienfideikommisse dann abgeschafft. Das als kritische Ergänzung zu Vranitzky.
#
# [foristi]: Lasst sie doch fordern, es ist doch der 1. Mai. Das bedeutet nichts.
#   [Ravenspower] (USER): sie haben nur die regierung kritisiert. das die roten nicht in der lage zu guter oppositionspolitik sind und waren war schon damals bei schwarz/blau I und II ersichtlich.  im ausland das eigene land anschwärzen wenn sie nicht mehr weiter wissen. oder penetrantes herumgeplärre.  nichts davon ist brauchbar. wie man eine regierung "vor sich hertreibt" müssten sie mal von der FPÖ lernen und abschauen.
#
# [Ravenspower] (USER): ihr noch nicht erfülltes versprechen, den silberstein-vertrag vorzulegen, einzulösen! denn immer noch interessiert es den einen oder anderen wähler, auch nichtwähler, wer den schandvertrag tatsächlich unterschrieben hat! wer auch immer es war... hier müssen noch diverse "köpfe rollen" und die SPÖ muss ordnung machen im eigenen haus.
#   [wederlechtsnochrinks]: "Im Jänner 2018 bot die ÖVP „ewiges Ruhen“ der zivilrechtlichen Verfahren..." Warum wohl?
#   [fersuchung]: mich würde brennend interessieren, warum die vp dann doch nicht geklagt hat und was bei so einem verfahren ans licht gekommen wäre. :-)
#     [Ravenspower] (USER): es war der SPÖ politiker matznetter der sich vor die kamera stellte und eine offenlegung des vertrages ankündigte und versprach! was gibts da blöd herumzuschreiben?
#     [Filippos Bzahlnixos]: Im Abtausch mit eigenen Wahlsünden. Die Sieger können großzügig sein.
#
# [Problemelch, liebesbedürftig am Durchzug]: Wegen der permanenten Einzelfälle, wegen der Angriffe auf Demokratie und Rechtsstaat, die Versuche Grund-, Menschen- und Freiheitsrechte zu schwächen/auszuhebeln, wegen der "Darstellung einer Regierung" statt konkreter Arbeit, wegen lust'ger Beziehungen und schöner Auslandsreisen nach Russland/Kambodscha, wegen dem Schüren vor Vorurteilen, Hass, Neid, wegen dem Ausschweigen Kurz's von eh allem, wegen dem inhaltlichen Gleichstand zwischen IBÖ, FPÖ und TBSK, wegen der kompletten Ignoranz aller ökologischer Herausforderungen.  Kurz und MitarbeiterInnen, Strache und Konsorten - tretet zurück!
#   [Ravenspower] (USER): die SPÖ ist derzeit weder regierungsfähig, noch hätte sie ein programm anzubieten. auch sind ihre "internen flügelkämpfe" immer noch aktuell (doskozil / schieder). linke gegen rechte. wollen sie die SPÖ so in eine regierung schicken (mit wem als partner?) wenn die SPÖ dann ohne programm, ohne gesicht regiert ("stillsteht") fällt sie unter 20%.
#     [Atalante]: wiederherstellen. Sie kann eine vernünftige Steuerreform mit Abschaffung der kalten Prog durchziehen und vieles mehr.
#       [Ravenspower] (USER): welches programm bietet die SPÖ an? kann sie es umsetzen? die SPÖ wäre derzeit, falls überhaupt, nur Juniorpartner. ihr habt 50% eurer wähler vergrault seit 1989'.
#     [pur]: Das stimmt doch nicht, warum ist die SPÖ nicht regierungsfähig - und sicher hat sie ein Programm, das hatte sie ja auch vor der Wahl - wer wirklich kein Programm hat ist die FPÖ.
#       [Ravenspower] (USER): FPÖ schliesst sie aus, Türkis (Kurz) ist ihnen ebenfalls zu rechts.
#
# [Hausverstand55]: ...denn richtig müsste es heisen: SPÖler fördern den Rücktritt vom Drozda. Die SPÖ-Basis hat offensichtlich genug von Bobos und Eliten. Die Basis will wieder sozialdemokratische Politik. Und die macht schon der Kurz. Der entlastet nämlich die "Kleinen Leute" und die wählen jetzt Türkis.
#   [Ravenspower] (USER): gäbe es eine, hätte sich diese längst gegen die partei gestellt bzw. an einer alternative neben der SPÖ gearbeitet!  wo sind denn seit 1989' die politischen erfolge einer SPÖ geblieben? wo ist denn die erfolgsgeschichte? wo hat die SPÖ denn den sozialstaat weiterentwickelt? wo in europa dafür gekämpft eine sozialunion zu etabilieren?  die SPÖ kann seit 1989' nur eines feststellen: 50% wählerverlust!  warum, weshalb, strategien dagegen.... fehl am platz. interessiert weder die parteibonzen noch die basis.  als antwort schimpft man gegen die anderen. bei sich selber fehlen die konsequenzen!
#   [fersuchung]: netter witz, beinah gut.
#
# [Ravenspower] (USER): wenn ich an ihre politiker denke welche sie nach europa transportierten wird mir heute noch flau im magen. hannes swoboda (seine ehefrau ist die 1000 schilling gitti), eugen freund, jetzt der schieder. nicht zu vergessen das sich zunächst der scheiternde kern selbst aufstellte!  aber völlig egal wer hingeschickt wurde, die europäische sozialdemokratie hat dort ohnehin immer das geschäft der neoliberalen kräfte erledigt und abgewickelt. wer regelmässig mit leeren händen zurückkommt und nichts umsetzen kann, nichts sozialdemokratisches, der macht sich unglaubwürdig.  wir kennen das ja von österreich. auch hier, seit vranitzky, nur noch machterhalt, nichts mehr neues gebracht.  dann lieber eine rechtskonservative regierung als zahnlose SPÖ.
#   [stretfordender]: super!!!
#   [Gott erhalte, Gott beschütze unsere Große Koalitio]: "dann lieber eine rechtskonservative regierung"  Echt jetzt? Sie stehen auf einen Wehrsportminister? Sie stehen auf einen 'Konzentrierer' Kickl?
#     [Ravenspower] (USER): was genau hat ein österreichischer arbeiter/angestellter/EPU/alleinerzieherin/pensionist usw. davon wenn man viele migranten/asylsuchende ins "sozialsystem" zuwandern lässt? solch eine ausländerpolitik können sie bitte den grünen überlassen!  die mehrheit der bevölkerung vergraulen sie damit eher und die SPÖ sollte ihren "linken träumerflügel" loswerden, sonst werden die verluste weiter steigen!  derzeit ist die SPÖ jedenfalls keine "grosse volkspartei" mehr...die stagniert, schrumpft vielleicht sogar. 50% wählerverlust die letzten 30 jahre sprechen eine eindeutige sprache.
#       [Gott erhalte, Gott beschütze unsere Große Koalitio]: "Die Ausländerpolitik der Regierung stört mich noch am wenigsten!"  Ich habe nichts über die Politik dieser Regierung geschrieben, lediglich über die Propagandasprache einiger Minister.  Das scheinen Sie aber nicht zur Kenntnis nehmen zu wollen.
#     [Magister Calamitatis]: was soll der unterschied sein? dass manche leute sonst ein bisserl hysterisch sind? wissens eh, ängste schüren ist merlmal der rechtsextremen und so einer wollen sie ja ganz sicher nicht sein, oder?
#       [Gott erhalte, Gott beschütze unsere Große Koalitio]: Ich hoffe doch, Sie haben einen Ahnenpass, nicht dass sich die 'Rechtskonservativen' etwa ausgetauscht vorkommen.
#   [nathan calcio]: Zur Ergänzung. Svobodas Gattin hat 5Mio Abfertigung kassiert von einem der K8nzerne gegen den die spö wettert!! Diese 5 Mio fehlen natürlich nicht bei der Pflege. Wo arbeitet übrigens die Tochter vom Svoboda? Ein Tipp: der Konzername beginnt mit S
#   [viridisdens]: legt sich mit den nazis ins bett. warum? NUR wegen der macht!  es geht gar nicht so sehr um die spö, aber: wer sich mit den .. der fpö ins bett legt, ist selber nicht regierungsfähig. abgesehen von den "normalen" rassisten, sind da jede woche die einzelfälle am werk, die demokratie weder verstehen noch unterstützen!  versager unter politikern gab's und gibt's in jeder partei. demokratiefeindlich, rassistisch, nazidreckverherrlichend... alles das macht vorwiegend die fpö und der kurz gibt ihnen das bettchen. wegen seiner macht!
#     [itta]: Burgenland. Oberösterreich. Linz. Von wegen ins Bett legen warats
#       [viridisdens]: und was genau macht's besser, nur weil der doskozil genauso ... ist.  wegen der argumentation warat's!
#
# [frecher Tobi, besondere Krautsorte]: Naja, 1943 Yalta wurden wir Stalin und der Roten Armee zugesprochen, die USA und GB wollten nicht hier einrücken wegen der Alpenfestung. Dann sind Österreicher nach Deutschland gefahren und haben die Amerikaner gebeten Österreich zu besetzen und  haben den US Streitkräften gesagt es gibt keine Alpenfestung. Die Rote Armee hat kein Land wieder verlassen, nur durch die, die die USA Armee nach Österreich brachten haben Österreich gerettet.
#   [Ravenspower] (USER): er war halt der burli und wurde "versorgt". ende der geschichte.
#   [itta]: nicht die SPÖ. keine Partei hat Ö wieder aufgebaut. Sondern die Menschen des Landes haben Ö wieder aufgebaut, unabhängig von Parteifarben.
#     [Antun Petrunkovic]: Ist zum Teil leider auch eine Mär, aber das ist ein anderes Kapitel.   (Die sog. Trümmerfrauen, deren Leistung heute stark verklärt dargestellt wird, waren mehrheitlich ehemalige Nationalsozialistinnen, die aufgrund ihrer Vergangenheit unter Aufsicht zu Arbeiten wie Schutt wegräumen etc. gezwungen wurden).  https://www.geschichtewiki.wien.gv.at/Tr%C3%BCmmerfrauen
#
# [Cornus 67]: will die SPÖ die FPÖ wieder aus der Regierung wegmobben, damit sie selber wieder an die Macht kommen. Aber in einer Demokratie braucht man dazu halt Wahlen...
#   [frecher Tobi, besondere Krautsorte]: ES REICHT :)
# ...
#   [Frank Nitti]: Eh. Der Exkanzler und sein Adlatus mit den türkisen Socken sind Musterexemplare dieser Snobs.
#     [skatebanana]: die waren schon immer so.  zumindest mich selbst irritierts bei jenen, die aus einfachen verhältnissen kommen, einfach wesentlich mehr. ein gusenbauer wirkte in radlerhose authentischer als im maßanzug.
#
# [Ravenspower] (USER): was ärgere ich mich wenn ich einen wie den kern sehe, oder eine glawischnig...die einerseits damit warben aus einen arbeiterhaushalt/wirtshaus zu stammen, andererseits sich dann später wenns fertig studiert haben plötzlich eine andere sprache/verhaltensweisen zulegen!  das verstehe ich im beruf, unter ihresgleichen... ja! jedoch "privat" und wenns darum geht authentisch aufzutreten...da sollten sie so sein und bleiben wie sie immer waren! das käme auch an!  aber nein...der kern wurde ein eitler pimpf, schminkte sich, war modisch eitel, sprach abgehoben, trank gerne teuren wein, wollte von seinen wurzeln nichts mehr wissen!  solche sind für mich uninteressant. Ich will bodenständige politiker...keine abgehobenen snobs
#   [Zilsels Sachlichkeit]: Es ist kaum ein größerer Widerspruch zu den Idealen der Sozialdemokratie denkbar als der Blödsinn, den Sie da oben absondern. Ein ganz primitives Festlegen eines Menschen auf seine Herkunft. Welche Politik hat Kern gefordert? Parvenü-artigen Neoliberalismus für Großspender wie Kurz oder klassisch sozialdemokratische Positionen vertreten?  Wenn ihnen das natürlich weniger wichtig ist als die Passform des Anzugs - Anzüge dürfen ja anscheinend nur Großbürger wie Kreisky tragen - dann sind sie einer von denen, die dazu beitragen, dass Figuren wie Kurz Erfolg haben, die nur aus Oberflächen bestehen.  Überlegens mal, welche Komplexe sie da auf soziale Aufsteiger projizieren. Relevant wären die politischen Positionen.
#     [Zilsels Sachlichkeit]: Und Thema authentisch: es ist eben NICHT authentisch, wenn ein studierter Multimillionär und Konzernmanager wie Kern daherredet wie der Hausmeister ums Eck. So hat er sein Leben nicht geführt, sich nicht in diesen Milieus bewegt.
#       [Ravenspower] (USER): dann braucht er aber 01.) nicht erwähnen ein arbeiterkind zu sein! 02.) nicht für die SPÖ aufgestellt zu werden!  ein "Multimillionär und Konzernmanager Kern" ist für eine arbeiterpartei weder interessant noch zugkräftig. so einer hat innerhalb der SPÖ im grunde nichts verloren.
#       [wolfklang4]: Also bitte, das klingt jetzt aber schon sehr klug. sie wissen wohl nicht in welchem forum sie sich bewegen. sfg. das ideal der sozialdemokratie war chancengleichheit. jedem seine schnöselkarriere, egal welcher herkunft und familiärem umfeld. wollten sie das ausdrücken? nein, ich kann weder ihnen noch ihrem vorposter zustimmen. Hand aufs Herz, die Partei hat Kern zu dem stilisiert was er nie war. Sie hat ihn aus einer verlegenheit geholt, und gab ihm eine astreine sozialdemokratische "geschichte", die bereits nach den ersten Tagen als solche zweiflern den wind aus den segeln nehmen sollte. Wie die sache endete, war wiederum "Partei". Mir scheint die Partei das Problem zu sein. Auch wenn man es versucht an Personen festzumachen.
#       [wolfklang4]: Schade wenn nicht mal der Intellektuelle "Zilsels sachlichkeit" merkt, wenn man ihn eigentlich bestätigt. Ich gebe zu etwas provokant bestätigt. Das Problem der "Partei", sehe ich darin dass sie eben nur Sozialdemokratische Geschichten propagiert. Dass auch ein etwas eitler Konzernmanager wie Kern ein vernünftiges Parteiprogramm erstellen kann, und das hatte er wahrscheinlich in Kürze in nächtlichen Sitzungen zu wege gebracht, verstehen die Genossen nicht zu nützen. Dass Österreich wirtschaftlich, wie sozial davon profitierte, und die Auswirkungen mitten im ersten Jahr der Regierung Kurz erst zur Blüte kamen, übersieht man gerne. Denn die Geschichte liest sich seit Kurz ja ganz anders.  Aber Kern war eben nicht die Partei.
#     [Ravenspower] (USER): .... er sollter aber wieder lernen "die sprache der leute" zu sprechen wenn er vor sie tritt! das ist weder eine grosse kunst noch ist es etwas unerreichbares..populisten machen und machten es stets vor!  er sollte in der lage sein, seinen publikum entsprechend, die richtigen worte für seine botschaften zu wählen. das schaut im bierzelt, in der disko, am marktplatz, an der universität, vor industriellen usw. stets etwas unterschiedlich aus.  wenn er die sprache seiner herkunft verlernt hat (was ich nicht glauben kann!) dann soll er sie wieder lernen...als politiker braucht man das!
#   [WilWil]: der größte fehler liegt darin, daß das kreuzerl von sympathiewerten abhängig ist. im endeffekt geht es ums was und nicht um durch wen das was umgesetzt wird.  es geht nur noch um emotion, programme sind wurscht geworden, so wurscht, daß die lackaffen aller farben tun und lassen können, was sie wollen, hauptsach sie werden sympathisch inszeniert.  es kotzt mich nur noch an. und schuld sind dazu nicht "die da oben,", sondern wir, das volk. weil man muss sich ja auch erst mal auf den kopf scheissen lassen.
#   [bouncing balls]: ich verstehe sehr gut was sie meinen.  gleichzeitig muss man aber auch sehen, dass das bild von "bodenständig" sich verändert hat.  wer die meisten stimmen in den ballungszentren erhält, der muss nicht auftreten wie ein landwirt nach der ernte.   die zentrale frage, die ich mir stelle ist, könnte ich mit der person auf ein bier gehen, könnte ich mir ein gespräch überhaupt vorstellen ...  mit einem kogler ja, mit einer glawischnigg no way  mit einem mitterlehner sofort, mit einem kurz no way  mit einer rendi wagner ich weiß es noch nicht um ehrlich zu sein   mögen andere natürlich anders sehen ...
#   [Frank Nitti]: Eh. Der Exkanzler und sein Adlatus mit den türkisen Socken sind Musterexemplare dieser Snobs.
#     [skatebanana]: die waren schon immer so.  zumindest mich selbst irritierts bei jenen, die aus einfachen verhältnissen kommen, einfach wesentlich mehr. ein gusenbauer wirkte in radlerhose authentischer als im maßanzug.
#
# [Ravenspower] (USER): was ärgere ich mich wenn ich einen wie den kern sehe, oder eine glawischnig...die einerseits damit warben aus einen arbeiterhaushalt/wirtshaus zu stammen, andererseits sich dann später wenns fertig studiert haben plötzlich eine andere sprache/verhaltensweisen zulegen!  das verstehe ich im beruf, unter ihresgleichen... ja! jedoch "privat" und wenns darum geht authentisch aufzutreten...da sollten sie so sein und bleiben wie sie immer waren! das käme auch an!  aber nein...der kern wurde ein eitler pimpf, schminkte sich, war modisch eitel, sprach abgehoben, trank gerne teuren wein, wollte von seinen wurzeln nichts mehr wissen!  solche sind für mich uninteressant. Ich will bodenständige politiker...keine abgehobenen snobs
#   [Zilsels Sachlichkeit]: Es ist kaum ein größerer Widerspruch zu den Idealen der Sozialdemokratie denkbar als der Blödsinn, den Sie da oben absondern. Ein ganz primitives Festlegen eines Menschen auf seine Herkunft. Welche Politik hat Kern gefordert? Parvenü-artigen Neoliberalismus für Großspender wie Kurz oder klassisch sozialdemokratische Positionen vertreten?  Wenn ihnen das natürlich weniger wichtig ist als die Passform des Anzugs - Anzüge dürfen ja anscheinend nur Großbürger wie Kreisky tragen - dann sind sie einer von denen, die dazu beitragen, dass Figuren wie Kurz Erfolg haben, die nur aus Oberflächen bestehen.  Überlegens mal, welche Komplexe sie da auf soziale Aufsteiger projizieren. Relevant wären die politischen Positionen.
#     [Zilsels Sachlichkeit]: Und Thema authentisch: es ist eben NICHT authentisch, wenn ein studierter Multimillionär und Konzernmanager wie Kern daherredet wie der Hausmeister ums Eck. So hat er sein Leben nicht geführt, sich nicht in diesen Milieus bewegt.
#       [Ravenspower] (USER): dann braucht er aber 01.) nicht erwähnen ein arbeiterkind zu sein! 02.) nicht für die SPÖ aufgestellt zu werden!  ein "Multimillionär und Konzernmanager Kern" ist für eine arbeiterpartei weder interessant noch zugkräftig. so einer hat innerhalb der SPÖ im grunde nichts verloren.
#       [wolfklang4]: Also bitte, das klingt jetzt aber schon sehr klug. sie wissen wohl nicht in welchem forum sie sich bewegen. sfg. das ideal der sozialdemokratie war chancengleichheit. jedem seine schnöselkarriere, egal welcher herkunft und familiärem umfeld. wollten sie das ausdrücken? nein, ich kann weder ihnen noch ihrem vorposter zustimmen. Hand aufs Herz, die Partei hat Kern zu dem stilisiert was er nie war. Sie hat ihn aus einer verlegenheit geholt, und gab ihm eine astreine sozialdemokratische "geschichte", die bereits nach den ersten Tagen als solche zweiflern den wind aus den segeln nehmen sollte. Wie die sache endete, war wiederum "Partei". Mir scheint die Partei das Problem zu sein. Auch wenn man es versucht an Personen festzumachen.
#       [wolfklang4]: Schade wenn nicht mal der Intellektuelle "Zilsels sachlichkeit" merkt, wenn man ihn eigentlich bestätigt. Ich gebe zu etwas provokant bestätigt. Das Problem der "Partei", sehe ich darin dass sie eben nur Sozialdemokratische Geschichten propagiert. Dass auch ein etwas eitler Konzernmanager wie Kern ein vernünftiges Parteiprogramm erstellen kann, und das hatte er wahrscheinlich in Kürze in nächtlichen Sitzungen zu wege gebracht, verstehen die Genossen nicht zu nützen. Dass Österreich wirtschaftlich, wie sozial davon profitierte, und die Auswirkungen mitten im ersten Jahr der Regierung Kurz erst zur Blüte kamen, übersieht man gerne. Denn die Geschichte liest sich seit Kurz ja ganz anders.  Aber Kern war eben nicht die Partei.
#     [Ravenspower] (USER): .... er sollter aber wieder lernen "die sprache der leute" zu sprechen wenn er vor sie tritt! das ist weder eine grosse kunst noch ist es etwas unerreichbares..populisten machen und machten es stets vor!  er sollte in der lage sein, seinen publikum entsprechend, die richtigen worte für seine botschaften zu wählen. das schaut im bierzelt, in der disko, am marktplatz, an der universität, vor industriellen usw. stets etwas unterschiedlich aus.  wenn er die sprache seiner herkunft verlernt hat (was ich nicht glauben kann!) dann soll er sie wieder lernen...als politiker braucht man das!
#   [WilWil]: der größte fehler liegt darin, daß das kreuzerl von sympathiewerten abhängig ist. im endeffekt geht es ums was und nicht um durch wen das was umgesetzt wird.  es geht nur noch um emotion, programme sind wurscht geworden, so wurscht, daß die lackaffen aller farben tun und lassen können, was sie wollen, hauptsach sie werden sympathisch inszeniert.  es kotzt mich nur noch an. und schuld sind dazu nicht "die da oben,", sondern wir, das volk. weil man muss sich ja auch erst mal auf den kopf scheissen lassen.
#   [bouncing balls]: ich verstehe sehr gut was sie meinen.  gleichzeitig muss man aber auch sehen, dass das bild von "bodenständig" sich verändert hat.  wer die meisten stimmen in den ballungszentren erhält, der muss nicht auftreten wie ein landwirt nach der ernte.   die zentrale frage, die ich mir stelle ist, könnte ich mit der person auf ein bier gehen, könnte ich mir ein gespräch überhaupt vorstellen ...  mit einem kogler ja, mit einer glawischnigg no way  mit einem mitterlehner sofort, mit einem kurz no way  mit einer rendi wagner ich weiß es noch nicht um ehrlich zu sein   mögen andere natürlich anders sehen ...
#   [Frank Nitti]: Eh. Der Exkanzler und sein Adlatus mit den türkisen Socken sind Musterexemplare dieser Snobs.
#     [skatebanana]: die waren schon immer so.  zumindest mich selbst irritierts bei jenen, die aus einfachen verhältnissen kommen, einfach wesentlich mehr. ein gusenbauer wirkte in radlerhose authentischer als im maßanzug.
#
# Article: Suche nach Übergangsbundeskanzler vor dem Abschluss
# Published: 2019-05-30T08:00:01.130000
# User Comments on this Article: 2
# User Replies on this Article: 2
#
# [my two or three cents]: Bin ich froh, dass wir unseren Bundespräsidenten haben. Gab doch immer Stimmen, die das Amt als überflüssig ansahen. Diese Stimmen sind verstummt. Hängt allerdings auch von den handelnden Personen ab. Danke VdB!
#   [Ravenspower] (USER): VdB macht seinen job gut, aber er ist auch alt.  eine amtszeit reicht...besonders weil er auch noch etwas von der pension haben soll!
#     [Lucia Dorn]: Sorry, verklickt.... das Grün war keine Absicht, denn ich würde es sehr begrüßen, wenn sich VdB noch eine zweite Amtszeit antun würde.
#     [SagServus]: Und trotzdem hätte unter Hofer das "Ergebnis" komplet anders aussehen können.  Glauben sie z.B. wirklich, dass mit einem BP Hofer die Entmachtung von Kickl als IM so "einfach" gegangen wäre?
#       [Ravenspower] (USER): im grunde hat er sich nichts zu schulden kommen lassen und wurde von VdB auch angelobt!  Jetzt ist es aber sowieso egal, denn jetzt herrscht bis zur neuwahl stillstand.  wie gesagt VdB macht seinen job seht gut und angemessen.  hofer hätte möglicherweise den kurz etwas eingebremst denn kurz sein allgemeines verhalten war auch nicht das gelbe vom ei.
#       [Mariarty]: Verdrückt - Grün!
#     [Johannes Söllner]: Er hätte sich aber auch z.B. weigern können den Minister Kickl auf Vorschlag des Kanzlers zu entlassen. Arbeitet weiter, dafür wurdet ihr gewählt, oder so. War ein Ermessensentscheidung, denke ich. Nur weil das Amt ausgefüllt wir wie jetzt ist das keine Garantie dafür.
#       [Ich sag dazu nur....]: am kicklabgang wird wohl nicht nur kurz alleine gearbeitet haben.
#     [my two or three cents]: schon, aber wir hätten auch einen Minister names Gudenus gehabt und möglicherweise etliche andere Grausligkeiten erlebt. Nach dem Motto: ihr werdet euch noch wundern, .....
#       [Therimon]: Also nur jetzt und ganz nachträglich mit Blick auf Ibiza: wär "witzig" gewesen  :-)  wie's die Koalition dann zerrissen hätt'
#   [Buzwell]: Damit ist diese Diskussion wenigstens für längere Zeit vom Tisch - das Präsidentenamt ist wirklich gut investiertes Geld
#
# [my two or three cents]: Bin ich froh, dass wir unseren Bundespräsidenten haben. Gab doch immer Stimmen, die das Amt als überflüssig ansahen. Diese Stimmen sind verstummt. Hängt allerdings auch von den handelnden Personen ab. Danke VdB!
#   [Ravenspower] (USER): VdB macht seinen job gut, aber er ist auch alt.  eine amtszeit reicht...besonders weil er auch noch etwas von der pension haben soll!
#     [Lucia Dorn]: Sorry, verklickt.... das Grün war keine Absicht, denn ich würde es sehr begrüßen, wenn sich VdB noch eine zweite Amtszeit antun würde.
#     [SagServus]: Und trotzdem hätte unter Hofer das "Ergebnis" komplet anders aussehen können.  Glauben sie z.B. wirklich, dass mit einem BP Hofer die Entmachtung von Kickl als IM so "einfach" gegangen wäre?
#       [Ravenspower] (USER): im grunde hat er sich nichts zu schulden kommen lassen und wurde von VdB auch angelobt!  Jetzt ist es aber sowieso egal, denn jetzt herrscht bis zur neuwahl stillstand.  wie gesagt VdB macht seinen job seht gut und angemessen.  hofer hätte möglicherweise den kurz etwas eingebremst denn kurz sein allgemeines verhalten war auch nicht das gelbe vom ei.
#       [Mariarty]: Verdrückt - Grün!
#     [Johannes Söllner]: Er hätte sich aber auch z.B. weigern können den Minister Kickl auf Vorschlag des Kanzlers zu entlassen. Arbeitet weiter, dafür wurdet ihr gewählt, oder so. War ein Ermessensentscheidung, denke ich. Nur weil das Amt ausgefüllt wir wie jetzt ist das keine Garantie dafür.
#       [Ich sag dazu nur....]: am kicklabgang wird wohl nicht nur kurz alleine gearbeitet haben.
#     [my two or three cents]: schon, aber wir hätten auch einen Minister names Gudenus gehabt und möglicherweise etliche andere Grausligkeiten erlebt. Nach dem Motto: ihr werdet euch noch wundern, .....
#       [Therimon]: Also nur jetzt und ganz nachträglich mit Blick auf Ibiza: wär "witzig" gewesen  :-)  wie's die Koalition dann zerrissen hätt'
#   [Buzwell]: Damit ist diese Diskussion wenigstens für längere Zeit vom Tisch - das Präsidentenamt ist wirklich gut investiertes Geld
