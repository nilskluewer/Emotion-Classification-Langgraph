# %%
# Merge csv Posting and Votes
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
df = pd.read_csv(r'./data/raw_csv/Postings_01052019_31052019.csv')

# Display the first 10 rows
print(df.head(10).to_string())

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import json

class DataPreprocessor:
    """
    A class to preprocess the raw comment data.
    """

    def __init__(self, file_path):
        """
        Initialize the DataPreprocessor with the path to the raw data file.
        
        :param file_path: str, path to the raw CSV file
        """
        self.file_path = file_path
        self.df = None

    def load_data(self):
        """Load the raw data from CSV file."""
        self.df = pd.read_csv(self.file_path)

    def preprocess(self):
        """Apply all preprocessing steps to the data."""
        self._convert_dates()
        self._handle_missing_values()
        self._convert_id_columns()
        self._create_new_features()

    def _convert_dates(self):
        """Convert date columns to datetime format."""
        date_columns = ['PostingCreatedAt', 'ArticlePublishingDate', 'UserCreatedAt']
        for col in date_columns:
            self.df[col] = pd.to_datetime(self.df[col])

    def _handle_missing_values(self):
        """Handle missing values in the dataset."""
        self.df['PostingHeadline'] = self.df['PostingHeadline'].fillna('No Headline')
        self.df['PostingComment'] = self.df['PostingComment'].fillna('No Comment')
        self.df['UserGender'] = self.df['UserGender'].fillna('Unknown')
        self.df['UserCommunityName'] = self.df['UserCommunityName'].fillna('Unknown')

    def _convert_id_columns(self):
        """Convert ID columns to integers."""
        id_columns = ['ID_Posting', 'ID_Posting_Parent', 'ID_CommunityIdentity', 'ID_Article']
        for col in id_columns:
            self.df[col] = self.df[col].fillna(0).astype(int)

    def _create_new_features(self):
        """Create new features from existing data."""
        self.df['CommentLength'] = self.df['PostingComment'].str.len()
        self.df['DaysSinceUserCreation'] = (self.df['PostingCreatedAt'] - self.df['UserCreatedAt']).dt.days
        self.df['IsReply'] = self.df['ID_Posting_Parent'] != 0
        self.df['PostingHour'] = self.df['PostingCreatedAt'].dt.hour
        self.df['PostingDayOfWeek'] = self.df['PostingCreatedAt'].dt.dayofweek

    def save_preprocessed_data(self, output_path):
        """
        Save the preprocessed data to a CSV file.
        
        :param output_path: str, path to save the preprocessed CSV file
        """
        self.df.to_csv(output_path, index=False)

class CommentThreadManager:
    """
    A class to manage and structure comment threads for articles.
    """

    def __init__(self, df):
        """
        Initialize the CommentThreadManager with a preprocessed DataFrame.
        
        :param df: pandas DataFrame, preprocessed comment data
        """
        self.article_comments = {article_id: group for article_id, group in df.groupby('ID_Article')}

    def build_comment_thread(self, comments, parent_id, depth=0):
        """
        Recursively build a comment thread structure.
        
        :param comments: pandas DataFrame, comments for a specific article
        :param parent_id: int, ID of the parent comment
        :param depth: int, current depth in the comment thread
        :return: list of dict, structured comment thread
        """
        thread = []
        replies = comments[comments['ID_Posting_Parent'] == parent_id]
        for _, reply in replies.iterrows():
            thread.append({
                'id': int(reply['ID_Posting']),
                'parent_id': int(reply['ID_Posting_Parent']) if pd.notnull(reply['ID_Posting_Parent']) else None,
                'user_id': int(reply['ID_CommunityIdentity']),
                'user_name': reply['UserCommunityName'],
                'user_gender': reply['UserGender'],
                'user_created_at': reply['UserCreatedAt'].isoformat() if pd.notnull(reply['UserCreatedAt']) else None,
                'comment_headline': reply['PostingHeadline'],
                'comment_text': reply['PostingComment'],
                'comment_created_at': reply['PostingCreatedAt'].isoformat() if pd.notnull(reply['PostingCreatedAt']) else None,
                'comment_length': int(reply['CommentLength']),
                'depth': depth,
                'replies': self.build_comment_thread(comments, int(reply['ID_Posting']), depth + 1)
            })
        return thread

    def get_article_threads(self, article_id):
        """
        Get the structured comment threads for a specific article.
        
        :param article_id: int, ID of the article
        :return: dict, structured article data with comment threads
        """
        if article_id not in self.article_comments:
            return None

        article_df = self.article_comments[article_id]
        root_comments = article_df[article_df['ID_Posting_Parent'].isnull() | (article_df['ID_Posting_Parent'] == 0)]

        threads = []
        for _, comment in root_comments.iterrows():
            thread = {
                'id': int(comment['ID_Posting']),
                'parent_id': None,
                'user_id': int(comment['ID_CommunityIdentity']),
                'user_name': comment['UserCommunityName'],
                'user_gender': comment['UserGender'],
                'user_created_at': comment['UserCreatedAt'].isoformat() if pd.notnull(comment['UserCreatedAt']) else None,
                'comment_headline': comment['PostingHeadline'],
                'comment_text': comment['PostingComment'],
                'comment_created_at': comment['PostingCreatedAt'].isoformat() if pd.notnull(comment['PostingCreatedAt']) else None,
                'comment_length': int(comment['CommentLength']),
                'depth': 0,
                'replies': self.build_comment_thread(article_df, int(comment['ID_Posting']), 1)
            }
            threads.append(thread)

        article_meta = article_df.iloc[0]

        return {
            'article_id': int(article_id),
            'article_title': article_meta['ArticleTitle'],
            'article_publish_date': article_meta['ArticlePublishingDate'].isoformat() if pd.notnull(article_meta['ArticlePublishingDate']) else None,
            'article_channel': article_meta['ArticleChannel'],
            'article_ressort_name': article_meta['ArticleRessortName'],
            'total_comments': len(article_df),
            'root_comments': len(root_comments),
            'comment_threads': threads
        }

    def get_article_ids(self):
        """
        Get a list of all article IDs in the dataset.
        
        :return: list of int, article IDs
        """
        return list(self.article_comments.keys())
    
    def get_user_ids(self):
        """
        Get a list of all user IDs in the dataset.
        
        :return: list of int, user IDs
        """
        return self.df['ID_CommunityIdentity'].unique().tolist()

# %%
# Usage example
if __name__ == "__main__":
    # Preprocess the data
    preprocessor = DataPreprocessor('./data/raw_csv/Postings_01052019_31052019.csv')
    preprocessor.load_data()
    preprocessor.preprocess()
    preprocessor.save_preprocessed_data('preprocessed_data.csv')

    # Create comment thread manager
    manager = CommentThreadManager(preprocessor.df)

    # Get threads for a specific article
    article_id = 2000102330973  # Example article ID
    result = manager.get_article_threads(article_id)

    # Pretty print the result
    print(json.dumps(result, indent=2))
# Out:
# {
#   "article_id": 2000102330973,
#   "article_title": "1. Mai in Wien: SP\u00d6 fordert von Strache R\u00fccktritt",
#   "article_publish_date": "2019-05-01T10:28:57.490000",
#   "article_channel": "Inland",
#   "article_ressort_name": "Parteien",
#   "total_comments": 2712,
#   "root_comments": 628,
#   "comment_threads": [
#     {
#       "id": 1041080828,
#       "parent_id": null,
#       "user_id": 671476,
#       "user_name": "Ravenspower",
#       "user_gender": "Unknown",
#       "user_created_at": "2018-04-14T13:42:28.470000",
#       "comment_headline": "Heute w\u00e4re der perfekte Tag f\u00fcr die SP\u00d6 gewesen....",
#       "comment_text": "ihr noch nicht erf\u00fclltes versprechen, den silberstein-vertrag vorzulegen, einzul\u00f6sen! denn immer noch interessiert es den einen oder anderen w\u00e4hler, auch nichtw\u00e4hler, wer den schandvertrag tats\u00e4chlich unterschrieben hat! wer auch immer es war... hier m\u00fcssen noch diverse \"k\u00f6pfe rollen\" und die SP\u00d6 muss ordnung machen im eigenen haus.",
#       "comment_created_at": "2019-05-01T22:42:06.310000",
#       "comment_length": 334,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041082179,
#           "parent_id": 1041080828,
#           "user_id": 608398,
#           "user_name": "wederlechtsnochrinks",
#           "user_gender": "m",
#           "user_created_at": "2017-02-18T16:05:32.167000",
#           "comment_headline": "No Headline",
#           "comment_text": "\"Im J\u00e4nner 2018 bot die \u00d6VP \u201eewiges Ruhen\u201c der zivilrechtlichen Verfahren...\" Warum wohl?",
#           "comment_created_at": "2019-05-02T00:05:45.700000",
#           "comment_length": 89,
#           "depth": 1,
#           "replies": []
#         },
#         {
#           "id": 1041081565,
#           "parent_id": 1041080828,
#           "user_id": 59327,
#           "user_name": "fersuchung",
#           "user_gender": "w",
#           "user_created_at": "2004-01-22T23:05:13.163000",
#           "comment_headline": "No Headline",
#           "comment_text": "mich w\u00fcrde brennend interessieren, warum die vp dann doch nicht geklagt hat und was bei so einem verfahren ans licht gekommen w\u00e4re. :-)",
#           "comment_created_at": "2019-05-01T23:16:37.240000",
#           "comment_length": 135,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041082011,
#               "parent_id": 1041081565,
#               "user_id": 671476,
#               "user_name": "Ravenspower",
#               "user_gender": "Unknown",
#               "user_created_at": "2018-04-14T13:42:28.470000",
#               "comment_headline": "Wozu sollte die \u00d6VP klagen?",
#               "comment_text": "es war der SP\u00d6 politiker matznetter der sich vor die kamera stellte und eine offenlegung des vertrages ank\u00fcndigte und versprach! was gibts da bl\u00f6d herumzuschreiben?",
#               "comment_created_at": "2019-05-01T23:50:04.850000",
#               "comment_length": 164,
#               "depth": 2,
#               "replies": []
#             },
#             {
#               "id": 1041081999,
#               "parent_id": 1041081565,
#               "user_id": 502216,
#               "user_name": "Filippos Bzahlnixos",
#               "user_gender": "m",
#               "user_created_at": "2006-08-02T10:34:20.413000",
#               "comment_headline": "No Headline",
#               "comment_text": "Im Abtausch mit eigenen Wahls\u00fcnden. Die Sieger k\u00f6nnen gro\u00dfz\u00fcgig sein.",
#               "comment_created_at": "2019-05-01T23:49:09.390000",
#               "comment_length": 69,
#               "depth": 2,
#               "replies": []
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": 1041073991,
#       "parent_id": null,
#       "user_id": 81444,
#       "user_name": "Hausverstand55",
#       "user_gender": "m",
#       "user_created_at": "2011-01-02T21:33:17.030000",
#       "comment_headline": "Wie viele GenossInnen waren es wirklich?",
#       "comment_text": "Die SP\u00d6 sagt 120.000, die Polizei hat gez\u00e4hlt und sagt 12.000. Irgendwer hat da offensichtlich Probleme beim Z\u00e4hlen. Kann es sein, dass es in Wien nur mehr so wenige GenossInnen gibt? Haben sich die anderen vor dem Bundeskanleramt versammelt, um vom Kanzler zu erfahren wieviel sie sich an Steuer ersparen werden?",
#       "comment_created_at": "2019-05-01T18:31:34.057000",
#       "comment_length": 313,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041074292,
#           "parent_id": 1041073991,
#           "user_id": 673904,
#           "user_name": "Pfade",
#           "user_gender": "Unknown",
#           "user_created_at": "2018-05-12T17:56:49.567000",
#           "comment_headline": "No Headline",
#           "comment_text": "Die Polizei sagt immer weniger...",
#           "comment_created_at": "2019-05-01T18:39:00.857000",
#           "comment_length": 33,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041074725,
#               "parent_id": 1041074292,
#               "user_id": 562278,
#               "user_name": "V2Versus",
#               "user_gender": "m",
#               "user_created_at": "2015-05-26T08:04:20.983000",
#               "comment_headline": "Aber nicht 1/10 von dem was behauptet wird... ;)",
#               "comment_text": "No Comment",
#               "comment_created_at": "2019-05-01T18:52:25.053000",
#               "comment_length": 10,
#               "depth": 2,
#               "replies": []
#             },
#             {
#               "id": 1041074710,
#               "parent_id": 1041074292,
#               "user_id": 18563,
#               "user_name": ".:Kopernikus:.",
#               "user_gender": "m",
#               "user_created_at": "2005-07-14T09:31:19.137000",
#               "comment_headline": "No Headline",
#               "comment_text": "Warum sollten sie? Welchen Anreiz hat der Veranstalter die Wahrheit zu sagen (und im Vergleich dazu - wie wichtig ist die Info f\u00fcr die Polizei)?  Genau. Deshalb waren es 12.000.",
#               "comment_created_at": "2019-05-01T18:51:40.380000",
#               "comment_length": 177,
#               "depth": 2,
#               "replies": []
#             },
#             {
#               "id": 1041074845,
#               "parent_id": 1041074292,
#               "user_id": 654128,
#               "user_name": "Star Shower",
#               "user_gender": "Unknown",
#               "user_created_at": "2017-12-11T06:53:16.607000",
#               "comment_headline": "No Headline",
#               "comment_text": "Naja, des is jetz aber schon ein eklatanter Unterschied (12k oder 120k)...",
#               "comment_created_at": "2019-05-01T18:55:35.393000",
#               "comment_length": 74,
#               "depth": 2,
#               "replies": []
#             },
#             {
#               "id": 1041075685,
#               "parent_id": 1041074292,
#               "user_id": 563778,
#               "user_name": "Glumanda",
#               "user_gender": "m",
#               "user_created_at": "2015-06-26T07:21:53.540000",
#               "comment_headline": "No Headline",
#               "comment_text": "Das w\u00e4re aber sehr gef\u00e4hrlich (bei starker Versch\u00e4tzung), da ja die Sicherheitsma\u00dfnahmen darauf aufbauen.",
#               "comment_created_at": "2019-05-01T19:25:34.457000",
#               "comment_length": 105,
#               "depth": 2,
#               "replies": [
#                 {
#                   "id": 1041076251,
#                   "parent_id": 1041075685,
#                   "user_id": 673904,
#                   "user_name": "Pfade",
#                   "user_gender": "Unknown",
#                   "user_created_at": "2018-05-12T17:56:49.567000",
#                   "comment_headline": "No Headline",
#                   "comment_text": "Mir gings nicht ums Rechnen sondern ums Verlautbaren.",
#                   "comment_created_at": "2019-05-01T19:48:50.783000",
#                   "comment_length": 53,
#                   "depth": 3,
#                   "replies": []
#                 }
#               ]
#             },
#             {
#               "id": 1041074902,
#               "parent_id": 1041074292,
#               "user_id": 634841,
#               "user_name": "triple-t",
#               "user_gender": "Unknown",
#               "user_created_at": "2017-06-26T19:54:33.543000",
#               "comment_headline": "No Headline",
#               "comment_text": "sicher rechtsradikal und zu bl\u00f6d zu z\u00e4hlen..",
#               "comment_created_at": "2019-05-01T18:57:42.680000",
#               "comment_length": 44,
#               "depth": 2,
#               "replies": [
#                 {
#                   "id": 1041076304,
#                   "parent_id": 1041074902,
#                   "user_id": 673904,
#                   "user_name": "Pfade",
#                   "user_gender": "Unknown",
#                   "user_created_at": "2018-05-12T17:56:49.567000",
#                   "comment_headline": "No Headline",
#                   "comment_text": "Ich geh davon aus, dass jeder in \u00d6 z\u00e4hlen kann. Die Frage is welche Zahlen geb ich raus. Bitte keine bl\u00f6den Unterstellungen.",
#                   "comment_created_at": "2019-05-01T19:50:43.857000",
#                   "comment_length": 124,
#                   "depth": 3,
#                   "replies": []
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "id": 1041074866,
#           "parent_id": 1041073991,
#           "user_id": 16044,
#           "user_name": "anton anton",
#           "user_gender": "m",
#           "user_created_at": "2000-11-26T12:09:15",
#           "comment_headline": "da is auch noch ein teil aus deutschland dabei",
#           "comment_text": "weils selber keine leute mehr auf die strasse bringen",
#           "comment_created_at": "2019-05-01T18:56:22.783000",
#           "comment_length": 53,
#           "depth": 1,
#           "replies": []
#         },
#         {
#           "id": 1041074666,
#           "parent_id": 1041073991,
#           "user_id": 18563,
#           "user_name": ".:Kopernikus:.",
#           "user_gender": "m",
#           "user_created_at": "2005-07-14T09:31:19.137000",
#           "comment_headline": "No Headline",
#           "comment_text": "Es ist recht einfach. Die Polizei z\u00e4hlt selbst, weil sie ja auf die Anzahl entsprechend reagieren muss - z.B. wenn danach der Verkehr wieder in Gang gebracht werden muss, beim Sichern des Marsches, potenziellen Gegendemos, etc. Die Veranstalter haben das Motto - je mehr desto gut.  Ok, so dreist vervielfachen schafft ansonsten nur Trump...",
#           "comment_created_at": "2019-05-01T18:50:25.033000",
#           "comment_length": 341,
#           "depth": 1,
#           "replies": []
#         },
#         {
#           "id": 1041074759,
#           "parent_id": 1041073991,
#           "user_id": 602349,
#           "user_name": "cpt. bligh",
#           "user_gender": "w",
#           "user_created_at": "2016-10-13T19:12:15.803000",
#           "comment_headline": "No Headline",
#           "comment_text": "also wenn es 120.000 waren, dann waren ca. 12.000 ohne rollator...",
#           "comment_created_at": "2019-05-01T18:53:18.830000",
#           "comment_length": 66,
#           "depth": 1,
#           "replies": []
#         },
#         {
#           "id": 1041074433,
#           "parent_id": 1041073991,
#           "user_id": 561762,
#           "user_name": "pantaRhei77",
#           "user_gender": "m",
#           "user_created_at": "2015-05-19T16:45:50.067000",
#           "comment_headline": "No Headline",
#           "comment_text": "I love the paddei",
#           "comment_created_at": "2019-05-01T18:42:49.710000",
#           "comment_length": 17,
#           "depth": 1,
#           "replies": []
#         }
#       ]
#     },
#     {
#       "id": 1041080903,
#       "parent_id": null,
#       "user_id": 81444,
#       "user_name": "Hausverstand55",
#       "user_gender": "m",
#       "user_created_at": "2011-01-02T21:33:17.030000",
#       "comment_headline": "Falsche \u00dcberschrift...",
#       "comment_text": "...denn richtig m\u00fcsste es heisen: SP\u00d6ler f\u00f6rdern den R\u00fccktritt vom Drozda. Die SP\u00d6-Basis hat offensichtlich genug von Bobos und Eliten. Die Basis will wieder sozialdemokratische Politik. Und die macht schon der Kurz. Der entlastet n\u00e4mlich die \"Kleinen Leute\" und die w\u00e4hlen jetzt T\u00fcrkis.",
#       "comment_created_at": "2019-05-01T22:45:02.803000",
#       "comment_length": 287,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041081133,
#           "parent_id": 1041080903,
#           "user_id": 671476,
#           "user_name": "Ravenspower",
#           "user_gender": "Unknown",
#           "user_created_at": "2018-04-14T13:42:28.470000",
#           "comment_headline": "An eine \"SP\u00d6 Basis\" glaube ich nicht mehr!",
#           "comment_text": "g\u00e4be es eine, h\u00e4tte sich diese l\u00e4ngst gegen die partei gestellt bzw. an einer alternative neben der SP\u00d6 gearbeitet!  wo sind denn seit 1989' die politischen erfolge einer SP\u00d6 geblieben? wo ist denn die erfolgsgeschichte? wo hat die SP\u00d6 denn den sozialstaat weiterentwickelt? wo in europa daf\u00fcr gek\u00e4mpft eine sozialunion zu etabilieren?  die SP\u00d6 kann seit 1989' nur eines feststellen: 50% w\u00e4hlerverlust!  warum, weshalb, strategien dagegen.... fehl am platz. interessiert weder die parteibonzen noch die basis.  als antwort schimpft man gegen die anderen. bei sich selber fehlen die konsequenzen!",
#           "comment_created_at": "2019-05-01T22:53:54.293000",
#           "comment_length": 595,
#           "depth": 1,
#           "replies": []
#         },
#         {
#           "id": 1041081540,
#           "parent_id": 1041080903,
#           "user_id": 59327,
#           "user_name": "fersuchung",
#           "user_gender": "w",
#           "user_created_at": "2004-01-22T23:05:13.163000",
#           "comment_headline": "No Headline",
#           "comment_text": "netter witz, beinah gut.",
#           "comment_created_at": "2019-05-01T23:15:12.350000",
#           "comment_length": 24,
#           "depth": 1,
#           "replies": []
#         }
#       ]
#     },
#     {
#       "id": 1041074285,
#       "parent_id": null,
#       "user_id": 170364,
#       "user_name": "Polk Salad",
#       "user_gender": "m",
#       "user_created_at": "2010-06-30T17:50:58.130000",
#       "comment_headline": "Kurz & Strache",
#       "comment_text": "Wie dreist und skrupellos muss man eigentlich sein, um sich praktisch jede Woche hinzustellen und gro\u00df Ma\u00dfnahmen anzuk\u00fcndigen, die zum Teil erst in Jahren umgesetzt werden sollen und die in ihrer konkreten Ausgestaltung nicht einmal ann\u00e4hernd feststehen? Wir reden hier \u00fcber Ma\u00dfnahmen, die in ihrer Gesamtheit  erst 2022 voll zum Tragen kommen sollen. Bis dahin kann so viel passieren. Wie seri\u00f6s ist eine Vorgehensweise, bei der man sich f\u00fcr quasi auf Luft gebaute Ank\u00fcndigungen bejubeln l\u00e4sst? Wie gro\u00df muss der Respekt dieser Herrschaften vor uns W\u00e4hlern sein, wenn wir t\u00e4glich aufs Neue derartig f\u00fcr dumm verkauft werden?",
#       "comment_created_at": "2019-05-01T18:38:54.713000",
#       "comment_length": 625,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041074441,
#           "parent_id": 1041074285,
#           "user_id": 25580,
#           "user_name": "CEEIT",
#           "user_gender": "m",
#           "user_created_at": "2006-04-30T20:57:45.160000",
#           "comment_headline": "das haben Gesetze und Reformen so an sich. Nur Hauptsache sie werden auf den Weg gebracht.",
#           "comment_text": "No Comment",
#           "comment_created_at": "2019-05-01T18:43:04.317000",
#           "comment_length": 10,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041075054,
#               "parent_id": 1041074441,
#               "user_id": 170364,
#               "user_name": "Polk Salad",
#               "user_gender": "m",
#               "user_created_at": "2010-06-30T17:50:58.130000",
#               "comment_headline": "No Headline",
#               "comment_text": "Reformen haben es \u201eso an sich\u201c, dass sie alle paar Wochen angek\u00fcndigt werden  und dann - vielleicht - in drei Jahren tats\u00e4chlich umgesetzt werden?   Ja, die Reformen von Kurz und Strache haben das tats\u00e4chlich so an sich.",
#               "comment_created_at": "2019-05-01T19:02:31.223000",
#               "comment_length": 220,
#               "depth": 2,
#               "replies": []
#             },
#             {
#               "id": 1041074831,
#               "parent_id": 1041074441,
#               "user_id": 554822,
#               "user_name": "ollasawaunsinn",
#               "user_gender": "m",
#               "user_created_at": "2015-01-07T16:00:03.650000",
#               "comment_headline": "No Headline",
#               "comment_text": "nur mit ank\u00fcndigungen bringt man nichts auf den weg",
#               "comment_created_at": "2019-05-01T18:55:07.810000",
#               "comment_length": 51,
#               "depth": 2,
#               "replies": []
#             }
#           ]
#         },
#         {
#           "id": 1041075017,
#           "parent_id": 1041074285,
#           "user_id": 519140,
#           "user_name": "Frohbotschafter",
#           "user_gender": "m",
#           "user_created_at": "2013-07-03T17:09:07.457000",
#           "comment_headline": "No Headline",
#           "comment_text": "Vielleicht haben Sie in Ihrem Eifer nicht bedacht, dass der Nationalrat Gesetze beschlie\u00dfen kann, die zum Teil erst zu einem sp\u00e4teren Zeitpunkt in Kraft treten. Das nennt man Legisvakanz und ist in \u00d6sterreich ein ganz normaler gesetzgeberischer Vorgang.  Beispielsweise kann der Gesetzgeber ein Gesetz beschlie\u00dfen, dessen Paragraf 1 (Senkung der niedrigsten Steuerstufe) bereits am 1. J\u00e4nner 2020, dessen Paragraf 2 (Senkung der zweitniedrigsten Stufe) aber erst am 1. J\u00e4nner 2021 in Geltung gesetzt wird.",
#           "comment_created_at": "2019-05-01T19:00:57.090000",
#           "comment_length": 505,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041075694,
#               "parent_id": 1041075017,
#               "user_id": 170364,
#               "user_name": "Polk Salad",
#               "user_gender": "m",
#               "user_created_at": "2010-06-30T17:50:58.130000",
#               "comment_headline": "No Headline",
#               "comment_text": "M\u00f6glicherweise haben Sie trotz Ihrer Scharfsichtigkeit \u00fcbersehen, dass diese Regierung ihre Vorhaben - wie in diesem Fall - Jahre vorher in regelm\u00e4\u00dfigen Abst\u00e4nden pomp\u00f6s ank\u00fcndigt, noch lange bevor irgendein Gesetz zur Beurteilung vorliegt. Sich jetzt herzustellen und das mit Legisvakanz zu erkl\u00e4ren, ist genau jene Dreistigkeit, die auch diese Regierung im \u00dcberma\u00df auszeichnet.",
#               "comment_created_at": "2019-05-01T19:25:47.170000",
#               "comment_length": 379,
#               "depth": 2,
#               "replies": []
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": 1041061113,
#       "parent_id": null,
#       "user_id": 676452,
#       "user_name": "Der weise Uhu",
#       "user_gender": "Unknown",
#       "user_created_at": "2017-03-03T07:54:12.730000",
#       "comment_headline": "Das ist mal innovativ",
#       "comment_text": "von der APA gleich doppelt abschreiben. Die letzten beiden Abs\u00e4tze sind doppelt im Text.",
#       "comment_created_at": "2019-05-01T10:43:07.423000",
#       "comment_length": 88,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041061168,
#           "parent_id": 1041061113,
#           "user_id": 507379,
#           "user_name": "Miner",
#           "user_gender": "m",
#           "user_created_at": "2012-01-31T18:04:52.047000",
#           "comment_headline": "No Headline",
#           "comment_text": "Genau so innovativ wie der Mai Aufmarsch der SP\u00d6.",
#           "comment_created_at": "2019-05-01T10:45:20.527000",
#           "comment_length": 49,
#           "depth": 1,
#           "replies": []
#         }
#       ]
#     },
#     {
#       "id": 1041073555,
#       "parent_id": null,
#       "user_id": 605784,
#       "user_name": "Posting Bull",
#       "user_gender": "m",
#       "user_created_at": "2016-12-21T22:34:17.367000",
#       "comment_headline": "...mein Gott, meine Zettel, Drozda, was soll ich sagen?...",
#       "comment_text": "'Es macht einen Unterschied, wer regiert\", sagte Rendi-Wagner, als sie ihre Zettel wieder beisammen hatte",
#       "comment_created_at": "2019-05-01T18:20:39.920000",
#       "comment_length": 105,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041075640,
#           "parent_id": 1041073555,
#           "user_id": 607127,
#           "user_name": "at1234567",
#           "user_gender": "w",
#           "user_created_at": "2017-01-23T14:30:49.173000",
#           "comment_headline": "No Headline",
#           "comment_text": "Am\u00fcsieren Sie immer auf Kosten anderer?",
#           "comment_created_at": "2019-05-01T19:24:20.213000",
#           "comment_length": 39,
#           "depth": 1,
#           "replies": []
#         }
#       ]
#     },
#     {
#       "id": 1041074272,
#       "parent_id": null,
#       "user_id": 333436,
#       "user_name": "nick G.",
#       "user_gender": "m",
#       "user_created_at": "2000-02-10T21:38:01.360000",
#       "comment_headline": "Der neue Stil den er versprochen hat",
#       "comment_text": "Um die rechtsextremen Verbindungen und quasi t\u00e4glichen Einzelf\u00e4lle seines Koalitionspartners zu legitimieren und zu relativieren erfindet Kurz nun laufend irgendwelche kruden Anschuldigungen.... Lenin, Papst, PKK.   https://twitter.com/fpoefails/status/1123622302179053569?s=19  \"Zum gro\u00dfen B\u00f6sen kamen die Menschen nie mit einem Schritt, sondern mit vielen kleinen, von denen jeder zu klein schien f\u00fcr eine gro\u00dfe Emp\u00f6rung. Erst wird gesagt, dann wird getan.\"   Wobei... Mit kleinen Schritten gibt man sich nicht mehr ab. Nun ist die Legitimierung ud Reinwaschung des Rechtsextremismus am Plan.",
#       "comment_created_at": "2019-05-01T18:38:32.967000",
#       "comment_length": 594,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041074566,
#           "parent_id": 1041074272,
#           "user_id": 25580,
#           "user_name": "CEEIT",
#           "user_gender": "m",
#           "user_created_at": "2006-04-30T20:57:45.160000",
#           "comment_headline": "F\u00fcr Sie mal ganz langsam:",
#           "comment_text": "Bild vom Aufmarsch: https://pbs.twimg.com/media/D5eJpfIWkAEWyOc?format=jpg&name=small  Anbei die verbotenen Symbole: https://www.ris.bka.gv.at/Dokumente/Begut/BEGUT_COO_2026_100_2_1611984/Anlage-COO_2026_100_2_1612005_Tempc5f987b1-65db-4fc0-af31-aaa430b784b4.0004.gif",
#           "comment_created_at": "2019-05-01T18:47:15.650000",
#           "comment_length": 267,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041075701,
#               "parent_id": 1041074566,
#               "user_id": 1493,
#               "user_name": "Alexander75",
#               "user_gender": "m",
#               "user_created_at": "2005-02-07T12:25:26.077000",
#               "comment_headline": "No Headline",
#               "comment_text": "Es gibt auch Aufm\u00e4rsche anderer Gruppen am Ring am 1. Mai. - Kurz \u00fcberimmt die Realit\u00e4tsverzerrung durch Oe24",
#               "comment_created_at": "2019-05-01T19:26:05.720000",
#               "comment_length": 109,
#               "depth": 2,
#               "replies": []
#             },
#             {
#               "id": 1041075757,
#               "parent_id": 1041074566,
#               "user_id": 686050,
#               "user_name": "Wiesel?",
#               "user_gender": "m",
#               "user_created_at": "2019-01-13T21:37:17.837000",
#               "comment_headline": "No Headline",
#               "comment_text": "Auch f\u00fcr sie: Es ist best\u00e4tigt dass die Kurdendemo mit dem Maiaufmarsch nichts zu tun hatte und dass diese sp\u00e4ter, in Polizeibegleitung, gef\u00fchrt wurde.",
#               "comment_created_at": "2019-05-01T19:27:55.157000",
#               "comment_length": 151,
#               "depth": 2,
#               "replies": []
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": 1041061086,
#       "parent_id": null,
#       "user_id": 563778,
#       "user_name": "Glumanda",
#       "user_gender": "m",
#       "user_created_at": "2015-06-26T07:21:53.540000",
#       "comment_headline": "No Headline",
#       "comment_text": "Liebe Red, ihr habt den Artikel fast doppelt geschrieben (10:41).",
#       "comment_created_at": "2019-05-01T10:41:39.640000",
#       "comment_length": 65,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041061434,
#           "parent_id": 1041061086,
#           "user_id": 102046,
#           "user_name": "icke",
#           "user_gender": "m",
#           "user_created_at": "2000-08-29T13:49:43",
#           "comment_headline": "No Headline",
#           "comment_text": "Zeilenhonorar   ;p",
#           "comment_created_at": "2019-05-01T10:57:29.660000",
#           "comment_length": 18,
#           "depth": 1,
#           "replies": []
#         }
#       ]
#     },
#     {
#       "id": 1041061356,
#       "parent_id": null,
#       "user_id": 499751,
#       "user_name": "libertella",
#       "user_gender": "w",
#       "user_created_at": "2002-11-02T12:18:33",
#       "comment_headline": "\"Schwarz-Blau\" war eindeutig als erkl\u00e4rter Lieblingsgegner auszumachen \u2013 dass sich die \u00d6VP j\u00fcngst einen t\u00fcrkisen Anstrich gegeben hat, wurde oft ignoriert",
#       "comment_text": "Solange Regierungsmitglieder noch immer von den Sozialisten sprechen und Kurz die neue Volkspartei auch nur bei Eigenlob dezidiert betont, ist es unerheblich.  Eigentlich ist es mittlerweile ohnehin Blau-Blau. T\u00fcrkis wird wieder verschwinden. Kenne keine Ortsgruppenfeiern mit dieser Farbe.",
#       "comment_created_at": "2019-05-01T10:53:42.007000",
#       "comment_length": 290,
#       "depth": 0,
#       "replies": []
#     },
#     {
#       "id": 1041074204,
#       "parent_id": null,
#       "user_id": 571532,
#       "user_name": "VonSchiller",
#       "user_gender": "w",
#       "user_created_at": "2015-11-05T11:37:39.077000",
#       "comment_headline": "No Headline",
#       "comment_text": "Pam war wirklich gut heute! Bitte Fu\u00df am Gaspedal lassen, Drozda hinauswerfen und Fu\u00df aufs Gaspedal!",
#       "comment_created_at": "2019-05-01T18:36:42.093000",
#       "comment_length": 100,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041074381,
#           "parent_id": 1041074204,
#           "user_id": 689440,
#           "user_name": "1f43fc7e-3faa-407f-8280-b806a873b96e",
#           "user_gender": "m",
#           "user_created_at": "2012-12-05T01:47:43.317000",
#           "comment_headline": "No Headline",
#           "comment_text": "No Comment",
#           "comment_created_at": "2019-05-01T18:41:14.713000",
#           "comment_length": 10,
#           "depth": 1,
#           "replies": []
#         },
#         {
#           "id": 1041074608,
#           "parent_id": 1041074204,
#           "user_id": 551526,
#           "user_name": "die handbremse",
#           "user_gender": "m",
#           "user_created_at": "2014-10-26T19:15:02.553000",
#           "comment_headline": "No Headline",
#           "comment_text": "... und vollgas in die wand",
#           "comment_created_at": "2019-05-01T18:48:32.863000",
#           "comment_length": 27,
#           "depth": 1,
#           "replies": []
#         },
#         {
#           "id": 1041074919,
#           "parent_id": 1041074204,
#           "user_id": 105234,
#           "user_name": "Ivan Boesky",
#           "user_gender": "m",
#           "user_created_at": "2003-06-23T16:13:51.663000",
#           "comment_headline": "No Headline",
#           "comment_text": "mein Gott, liab war sie, gut eher weniger ... so angestrengt hat sie die Kampfparolen rausgepresst ... authentisch schaut anders aus ...",
#           "comment_created_at": "2019-05-01T18:58:09.080000",
#           "comment_length": 136,
#           "depth": 1,
#           "replies": []
#         }
#       ]
#     },
#     {
#       "id": 1041061188,
#       "parent_id": null,
#       "user_id": 505849,
#       "user_name": "florus silentius",
#       "user_gender": "m",
#       "user_created_at": "2013-01-21T23:10:07.773000",
#       "comment_headline": "Kritik An der Regierung",
#       "comment_text": "Kritik der Regierung w\u00fcrde bedeuten, die Regierung kritisiert",
#       "comment_created_at": "2019-05-01T10:46:11.293000",
#       "comment_length": 61,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041061302,
#           "parent_id": 1041061188,
#           "user_id": 559906,
#           "user_name": "Picodella",
#           "user_gender": "m",
#           "user_created_at": "2015-04-09T12:50:15.370000",
#           "comment_headline": "No Headline",
#           "comment_text": "Es gibt verschiedene Genitive, bitte nachsitzen.",
#           "comment_created_at": "2019-05-01T10:51:13.677000",
#           "comment_length": 48,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041061905,
#               "parent_id": 1041061302,
#               "user_id": 589777,
#               "user_name": "metee",
#               "user_gender": "m",
#               "user_created_at": "2016-08-23T08:24:39.030000",
#               "comment_headline": "No Headline",
#               "comment_text": "Hei\u00dft der Plural von \"Genitiv\" nicht \"Genitalien\" ?",
#               "comment_created_at": "2019-05-01T11:16:27.323000",
#               "comment_length": 51,
#               "depth": 2,
#               "replies": []
#             },
#             {
#               "id": 1041061396,
#               "parent_id": 1041061302,
#               "user_id": 686446,
#               "user_name": "drachenf\u00fcrst",
#               "user_gender": "Unknown",
#               "user_created_at": "2019-01-21T08:50:24.457000",
#               "comment_headline": "No Headline",
#               "comment_text": "In diesem Fall muss es aber durch eine weitere Pr\u00e4position verifiziert werden, da es sonst nicht klar ist, wr wen kritisiert. Also selbst nachsitzen.",
#               "comment_created_at": "2019-05-01T10:55:53.487000",
#               "comment_length": 149,
#               "depth": 2,
#               "replies": []
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": 1041061467,
#       "parent_id": null,
#       "user_id": 690140,
#       "user_name": "teddyx",
#       "user_gender": "Unknown",
#       "user_created_at": "2019-03-30T10:00:41.103000",
#       "comment_headline": "No Headline",
#       "comment_text": "Die sp\u00f6 marschiert gemeinsam mit einer verbotenen terrororganisation. Was f\u00fcr eine Schande.   https://www.oe24.at/oesterreich/chronik/wien/Terror-Organisation-PKK-marschiert-bei-1-Mai-Aufmarsch-mit/378242250",
#       "comment_created_at": "2019-05-01T10:59:00.413000",
#       "comment_length": 207,
#       "depth": 0,
#       "replies": []
#     },
#     {
#       "id": 1041062001,
#       "parent_id": null,
#       "user_id": 632931,
#       "user_name": "SerienChiller",
#       "user_gender": "Unknown",
#       "user_created_at": "2017-05-15T00:07:04.820000",
#       "comment_headline": "Warum sollte man zu einer SP\u00d6-Parteiveranstaltung kommen?",
#       "comment_text": "Gibt's dort Goodies?",
#       "comment_created_at": "2019-05-01T11:19:50.117000",
#       "comment_length": 20,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041062229,
#           "parent_id": 1041062001,
#           "user_id": 509546,
#           "user_name": "chiliwuki",
#           "user_gender": "m",
#           "user_created_at": "2013-03-01T00:25:00.093000",
#           "comment_headline": "No Headline",
#           "comment_text": "Wegen H\u00e4upl, der gleich reden wird.",
#           "comment_created_at": "2019-05-01T11:29:32.543000",
#           "comment_length": 35,
#           "depth": 1,
#           "replies": []
#         }
#       ]
#     },
#     {
#       "id": 1041062031,
#       "parent_id": null,
#       "user_id": 666961,
#       "user_name": "Albert Beinstein",
#       "user_gender": "Unknown",
#       "user_created_at": "2018-01-27T10:13:27.317000",
#       "comment_headline": "Typisch \u201eArbeitsideologen\u201c",
#       "comment_text": "Um 11:00 schon Abschlusskundgebung. Dann wird, logisch auf Kosten der Allgemeinheit, abgefeiert.  Die reale Versorgung der Gesellschaft interessiert die gar nicht. L\u00f6sungen f\u00fcr die schweren gesellschaftlichen und wirtschaftlichen Dysbalancen interessieren die gar nicht. Die wollen nur das Geld der anderen solange die anderen noch was haben. Wenn die fertig sind, dann sind alle, au\u00dfer deren Bonzen, arm. Aktuell Beispiel Venezuela.   Die gierigen B\u00fcndlerlobbyisten mit T\u00fcrkiser Fassade sind besch\u00e4ftig die \u00d6sterreicher noch mehr auszurauben und das als Erfolg zu verkaufen. Von 2016 bis 2019 schon knapp 20 Mrd. mehr kassiert, bis 2022 min weitere 10 Mrd. 6,5 Mrd. sollen zur\u00fcckkommen. Auch nur R\u00e4uber.  Ein Albtraum f\u00fcr \u00d6sterreich.",
#       "comment_created_at": "2019-05-01T11:20:59.560000",
#       "comment_length": 734,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041062705,
#           "parent_id": 1041062031,
#           "user_id": 499906,
#           "user_name": "IMGP1492.PEF",
#           "user_gender": "m",
#           "user_created_at": "2003-07-03T12:41:06.453000",
#           "comment_headline": "No Headline",
#           "comment_text": "Albert, ja du bist arm. Aber du solltest an deinem Problem arbeiten.",
#           "comment_created_at": "2019-05-01T11:46:32.753000",
#           "comment_length": 68,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041062824,
#               "parent_id": 1041062705,
#               "user_id": 666961,
#               "user_name": "Albert Beinstein",
#               "user_gender": "Unknown",
#               "user_created_at": "2018-01-27T10:13:27.317000",
#               "comment_headline": "No Headline",
#               "comment_text": "Es geht nicht um mich. Weder im Artikel noch in meinem Kommentar.  Dein Kommentar ist also zu 100% pers\u00f6nlich und emotionell. Da ist kein Verstand mehr.  Bussi Albert",
#               "comment_created_at": "2019-05-01T11:50:39.420000",
#               "comment_length": 166,
#               "depth": 2,
#               "replies": [
#                 {
#                   "id": 1041063439,
#                   "parent_id": 1041062824,
#                   "user_id": 499906,
#                   "user_name": "IMGP1492.PEF",
#                   "user_gender": "m",
#                   "user_created_at": "2003-07-03T12:41:06.453000",
#                   "comment_headline": "No Headline",
#                   "comment_text": "Und du bist zu 100% wertneutral und sachlich, ich wei\u00df. Wie oben schon gesagt und auch nur als Tip gemeint, arbeite an deinem Problem.",
#                   "comment_created_at": "2019-05-01T12:15:02.163000",
#                   "comment_length": 134,
#                   "depth": 3,
#                   "replies": [
#                     {
#                       "id": 1041075319,
#                       "parent_id": 1041063439,
#                       "user_id": 666961,
#                       "user_name": "Albert Beinstein",
#                       "user_gender": "Unknown",
#                       "user_created_at": "2018-01-27T10:13:27.317000",
#                       "comment_headline": "No Headline",
#                       "comment_text": "Ich bin nicht werteneutral, vertrete die Menschenrechte. Das allerdings von Parteigeschm\u00e4ckern v\u00f6llig unbefangem.  Und nein, nicht die anderen haben ein Problem. Das kommt nur Dir so vor, empfindest Du so. Reine Emotion.",
#                       "comment_created_at": "2019-05-01T19:12:34.527000",
#                       "comment_length": 220,
#                       "depth": 4,
#                       "replies": []
#                     }
#                   ]
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": 1041080782,
#       "parent_id": null,
#       "user_id": 678196,
#       "user_name": "Problemelch, liebesbed\u00fcrftig am Durchzug",
#       "user_gender": "Unknown",
#       "user_created_at": "2018-08-10T12:24:08.853000",
#       "comment_headline": "TIME TO SAY GOODBYE (f\u00fcr die EFFEN hier die \u00fcbersetzung ZEIT ZU SAGEN AUF WIEDERSEHEN) - warum?",
#       "comment_text": "Wegen der permanenten Einzelf\u00e4lle, wegen der Angriffe auf Demokratie und Rechtsstaat, die Versuche Grund-, Menschen- und Freiheitsrechte zu schw\u00e4chen/auszuhebeln, wegen der \"Darstellung einer Regierung\" statt konkreter Arbeit, wegen lust'ger Beziehungen und sch\u00f6ner Auslandsreisen nach Russland/Kambodscha, wegen dem Sch\u00fcren vor Vorurteilen, Hass, Neid, wegen dem Ausschweigen Kurz's von eh allem, wegen dem inhaltlichen Gleichstand zwischen IB\u00d6, FP\u00d6 und TBSK, wegen der kompletten Ignoranz aller \u00f6kologischer Herausforderungen.  Kurz und MitarbeiterInnen, Strache und Konsorten - tretet zur\u00fcck!",
#       "comment_created_at": "2019-05-01T22:39:48.383000",
#       "comment_length": 595,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041080938,
#           "parent_id": 1041080782,
#           "user_id": 671476,
#           "user_name": "Ravenspower",
#           "user_gender": "Unknown",
#           "user_created_at": "2018-04-14T13:42:28.470000",
#           "comment_headline": "Wer sollte die \u00d6VP bzw. FP\u00d6 ersetzen?",
#           "comment_text": "die SP\u00d6 ist derzeit weder regierungsf\u00e4hig, noch h\u00e4tte sie ein programm anzubieten. auch sind ihre \"internen fl\u00fcgelk\u00e4mpfe\" immer noch aktuell (doskozil / schieder). linke gegen rechte. wollen sie die SP\u00d6 so in eine regierung schicken (mit wem als partner?) wenn die SP\u00d6 dann ohne programm, ohne gesicht regiert (\"stillsteht\") f\u00e4llt sie unter 20%.",
#           "comment_created_at": "2019-05-01T22:46:05.570000",
#           "comment_length": 345,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041081719,
#               "parent_id": 1041080938,
#               "user_id": 690645,
#               "user_name": "Atalante",
#               "user_gender": "Unknown",
#               "user_created_at": "2019-04-08T20:06:13.143000",
#               "comment_headline": "FP\u00d6VP sind keine Regierung, die sind eine Abrissbirne, die unser Land demoliert. Die SP\u00d6 kann die Regierung sofort \u00fcbernehmen, Rendi ist Kurz um Wolkenkratzer \u00fcberlegen und kann den Irrsinn der Abrissbirne r\u00fcckg\u00e4ngig machen und den Ruf unseres Landes",
#               "comment_text": "wiederherstellen. Sie kann eine vern\u00fcnftige Steuerreform mit Abschaffung der kalten Prog durchziehen und vieles mehr.",
#               "comment_created_at": "2019-05-01T23:26:42.527000",
#               "comment_length": 117,
#               "depth": 2,
#               "replies": [
#                 {
#                   "id": 1041082051,
#                   "parent_id": 1041081719,
#                   "user_id": 671476,
#                   "user_name": "Ravenspower",
#                   "user_gender": "Unknown",
#                   "user_created_at": "2018-04-14T13:42:28.470000",
#                   "comment_headline": "Wer sollte ihr \"Koalitionspartner\" sein?",
#                   "comment_text": "welches programm bietet die SP\u00d6 an? kann sie es umsetzen? die SP\u00d6 w\u00e4re derzeit, falls \u00fcberhaupt, nur Juniorpartner. ihr habt 50% eurer w\u00e4hler vergrault seit 1989'.",
#                   "comment_created_at": "2019-05-01T23:53:48.433000",
#                   "comment_length": 163,
#                   "depth": 3,
#                   "replies": []
#                 }
#               ]
#             },
#             {
#               "id": 1041082016,
#               "parent_id": 1041080938,
#               "user_id": 554200,
#               "user_name": "pur",
#               "user_gender": "w",
#               "user_created_at": "2014-12-19T23:17:04.410000",
#               "comment_headline": "No Headline",
#               "comment_text": "Das stimmt doch nicht, warum ist die SP\u00d6 nicht regierungsf\u00e4hig - und sicher hat sie ein Programm, das hatte sie ja auch vor der Wahl - wer wirklich kein Programm hat ist die FP\u00d6.",
#               "comment_created_at": "2019-05-01T23:50:41.840000",
#               "comment_length": 178,
#               "depth": 2,
#               "replies": [
#                 {
#                   "id": 1041082334,
#                   "parent_id": 1041082016,
#                   "user_id": 671476,
#                   "user_name": "Ravenspower",
#                   "user_gender": "Unknown",
#                   "user_created_at": "2018-04-14T13:42:28.470000",
#                   "comment_headline": "Die SP\u00d6 hat jedoch keinen Partner mehr!",
#                   "comment_text": "FP\u00d6 schliesst sie aus, T\u00fcrkis (Kurz) ist ihnen ebenfalls zu rechts.",
#                   "comment_created_at": "2019-05-02T00:19:05.160000",
#                   "comment_length": 67,
#                   "depth": 3,
#                   "replies": []
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": 1041060877,
#       "parent_id": null,
#       "user_id": 161062,
#       "user_name": "Olivier Merle",
#       "user_gender": "m",
#       "user_created_at": "2000-02-03T11:12:46.973000",
#       "comment_headline": "No Headline",
#       "comment_text": "Bei dem Foto wird mir ganz warm ums Herz.",
#       "comment_created_at": "2019-05-01T10:32:27.723000",
#       "comment_length": 41,
#       "depth": 0,
#       "replies": []
#     },
#     {
#       "id": 1041061307,
#       "parent_id": null,
#       "user_id": 176874,
#       "user_name": "Petra \u00d6sterreicher",
#       "user_gender": "m",
#       "user_created_at": "2000-08-29T15:08:50",
#       "comment_headline": "No Headline",
#       "comment_text": "No Comment",
#       "comment_created_at": "2019-05-01T10:51:24.073000",
#       "comment_length": 10,
#       "depth": 0,
#       "replies": []
#     },
#     {
#       "id": 1041061516,
#       "parent_id": null,
#       "user_id": 600283,
#       "user_name": "Incubus",
#       "user_gender": "m",
#       "user_created_at": "2016-09-02T09:09:43.523000",
#       "comment_headline": "No Headline",
#       "comment_text": "Dort marschieren die auf, denen Job, Wohnung was auch immer durch die SP\u00d6 zugeschanzt wurde...dieser Missbrauch ist bei den meisten anderen Parteien, wo m\u00f6glich, auch \u00fcblich. Sonst muss man ja einen ziemlichen Knall haben dort hinzugehen...oder werden da manche bei den wiennahen Unternehmen gen\u00f6tigt?",
#       "comment_created_at": "2019-05-01T11:01:33.140000",
#       "comment_length": 301,
#       "depth": 0,
#       "replies": []
#     },
#     {
#       "id": 1041061316,
#       "parent_id": null,
#       "user_id": 207112,
#       "user_name": "stndrd",
#       "user_gender": "m",
#       "user_created_at": "2000-09-25T12:02:30",
#       "comment_headline": "No Headline",
#       "comment_text": "@Eine Premiere ist es f\u00fcr ihn nur indirekt: Als designierter Stadtchef ...  Dejavu im letzten Absatz. Die haben in der Matrix was ge\u00e4ndert und ich bin jetzt im Zimmer eingemauert. ;-)",
#       "comment_created_at": "2019-05-01T10:51:42.050000",
#       "comment_length": 183,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041061479,
#           "parent_id": 1041061316,
#           "user_id": 177299,
#           "user_name": "re flexion",
#           "user_gender": "m",
#           "user_created_at": "2002-05-14T14:29:22",
#           "comment_headline": "No Headline",
#           "comment_text": "Anscheinend sind sie eingemauert!  Denn h\u00e4tten sie die Mauer durchbrochen und weitergelesen, dann h\u00e4tten sie erkannt - ..  durfte Michael Ludwig zwar schon im Vorjahr  -  dass nachher noch ein Absatz kommt.",
#           "comment_created_at": "2019-05-01T10:59:34.460000",
#           "comment_length": 206,
#           "depth": 1,
#           "replies": []
#         },
#         {
#           "id": 1041061711,
#           "parent_id": 1041061316,
#           "user_id": 177299,
#           "user_name": "re flexion",
#           "user_gender": "m",
#           "user_created_at": "2002-05-14T14:29:22",
#           "comment_headline": "No Headline",
#           "comment_text": "Sorry f\u00fcr mein Posting unten. Ich habe ihres falsch interpretiert. Es geht aber nicht nur um den letzten Absatz sondern um den letzten Abschnitt!",
#           "comment_created_at": "2019-05-01T11:09:13.173000",
#           "comment_length": 145,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041063443,
#               "parent_id": 1041061711,
#               "user_id": 207112,
#               "user_name": "stndrd",
#               "user_gender": "m",
#               "user_created_at": "2000-09-25T12:02:30",
#               "comment_headline": "No Headline",
#               "comment_text": "Kein Problem. Ich irre mich auch manchmal. ;-)  Es ist eh der ganze Abschnitt.",
#               "comment_created_at": "2019-05-01T12:15:17.160000",
#               "comment_length": 78,
#               "depth": 2,
#               "replies": []
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": 1041061732,
#       "parent_id": null,
#       "user_id": 574550,
#       "user_name": "gespr\u00e4chsbereit",
#       "user_gender": "m",
#       "user_created_at": "2008-10-11T11:02:16.250000",
#       "comment_headline": "Das eine Partei die offiziell die Arbeiter aufgegeben hat und nur mehr eine elit\u00e4re intellektuelle st\u00e4dtische Bev\u00f6lkerung vertritt,",
#       "comment_text": "sich am 1 Mai, den Tag der Arbeiter feiern l\u00e4sst. Ist gelinde gesagt eine Dem\u00fctigung aller Arbeiter.",
#       "comment_created_at": "2019-05-01T11:09:55.417000",
#       "comment_length": 100,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041061935,
#           "parent_id": 1041061732,
#           "user_id": 164631,
#           "user_name": "norgas1",
#           "user_gender": "m",
#           "user_created_at": "2012-07-20T12:39:19.170000",
#           "comment_headline": "Hat sie das?",
#           "comment_text": "No Comment",
#           "comment_created_at": "2019-05-01T11:17:19.563000",
#           "comment_length": 10,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041062782,
#               "parent_id": 1041061935,
#               "user_id": 574550,
#               "user_name": "gespr\u00e4chsbereit",
#               "user_gender": "m",
#               "user_created_at": "2008-10-11T11:02:16.250000",
#               "comment_headline": "No Headline",
#               "comment_text": "Lesen Sie sich ein paar Rauscher Artikel durch. Der hat die SP\u00d6 explizit dazu aufgerufen, nicht mehr die Arbeiter zu vertreten. Nach dem Motto \"die Stimmen bekommt man eh nicht mehr zur\u00fcck\"",
#               "comment_created_at": "2019-05-01T11:49:03.443000",
#               "comment_length": 189,
#               "depth": 2,
#               "replies": []
#             }
#           ]
#         },
#         {
#           "id": 1041061854,
#           "parent_id": 1041061732,
#           "user_id": 130964,
#           "user_name": "LT81",
#           "user_gender": "m",
#           "user_created_at": "2008-09-14T17:04:13.660000",
#           "comment_headline": "No Headline",
#           "comment_text": "Sehen viele anscheinend anders. Akzeptieren sie es, sie d\u00fcrfen ja auch wie ein Lemming dem Herrn Kurz nachlaufen.",
#           "comment_created_at": "2019-05-01T11:14:39.440000",
#           "comment_length": 113,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041062697,
#               "parent_id": 1041061854,
#               "user_id": 574550,
#               "user_name": "gespr\u00e4chsbereit",
#               "user_gender": "m",
#               "user_created_at": "2008-10-11T11:02:16.250000",
#               "comment_headline": "No Headline",
#               "comment_text": "Aber nur weil viele Bobos am liebsten Arbeiter w\u00e4ren.... (dann ist man ja so....)  Gibt aber nichts das weiter entfernt w\u00e4re von einem Arbeiter, als ein Bobo.",
#               "comment_created_at": "2019-05-01T11:46:21.230000",
#               "comment_length": 158,
# ...
#           "user_gender": "m",
#           "user_created_at": "2016-05-31T18:32:02.093000",
#           "comment_headline": "No Headline",
#           "comment_text": "Dieser Logik folgend sind Sellner und seine Identit\u00e4ren also Linke, die die Blauen diskreditieren sollen, oder?",
#           "comment_created_at": "2019-05-01T18:29:10.893000",
#           "comment_length": 111,
#           "depth": 1,
#           "replies": []
#         },
#         {
#           "id": 1041074552,
#           "parent_id": 1041073507,
#           "user_id": 633859,
#           "user_name": "r.b.diff",
#           "user_gender": "Unknown",
#           "user_created_at": "2017-06-03T14:11:29.477000",
#           "comment_headline": "No Headline",
#           "comment_text": "Bild von Aufmarsch  https://pbs.twimg.com/media/D5eJpfIWkAEWyOc?format=jpg&name=small  Verbotenes Zeichen  https://www.ris.bka.gv.at/Dokumente/Begut/BEGUT_COO_2026_100_2_1611984/COO_2026_100_2_1612005.html  Sie haben nur die Hintergrundfarbe rund um den Stern in rot weggelassen. Wegsehen ist nicht die beste Option.",
#           "comment_created_at": "2019-05-01T18:46:52.180000",
#           "comment_length": 316,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041075769,
#               "parent_id": 1041074552,
#               "user_id": 1493,
#               "user_name": "Alexander75",
#               "user_gender": "m",
#               "user_created_at": "2005-02-07T12:25:26.077000",
#               "comment_headline": "No Headline",
#               "comment_text": "Es gibt auch andere Kundgebungen am Ring am 1. Mai und v.a. nach der KP\u00d6, die bis zum Parlament zieht, auch den Aufmarsch diverser sogenannte anti-imperialistischer Splittergruppen und Sekten...",
#               "comment_created_at": "2019-05-01T19:28:21.920000",
#               "comment_length": 194,
#               "depth": 2,
#               "replies": []
#             }
#           ]
#         },
#         {
#           "id": 1041074727,
#           "parent_id": 1041073507,
#           "user_id": 551526,
#           "user_name": "die handbremse",
#           "user_gender": "m",
#           "user_created_at": "2014-10-26T19:15:02.553000",
#           "comment_headline": "um Lenins willen",
#           "comment_text": "wie paranoid sind sie schon?",
#           "comment_created_at": "2019-05-01T18:52:31.027000",
#           "comment_length": 28,
#           "depth": 1,
#           "replies": []
#         }
#       ]
#     },
#     {
#       "id": 1041073379,
#       "parent_id": null,
#       "user_id": 689440,
#       "user_name": "1f43fc7e-3faa-407f-8280-b806a873b96e",
#       "user_gender": "m",
#       "user_created_at": "2012-12-05T01:47:43.317000",
#       "comment_headline": "No Headline",
#       "comment_text": "No Comment",
#       "comment_created_at": "2019-05-01T18:16:11.317000",
#       "comment_length": 10,
#       "depth": 0,
#       "replies": []
#     },
#     {
#       "id": 1041073412,
#       "parent_id": null,
#       "user_id": 10581,
#       "user_name": "alterdepp",
#       "user_gender": "m",
#       "user_created_at": "2008-07-04T18:25:05.367000",
#       "comment_headline": "No Headline",
#       "comment_text": "Strache begreift noch immer nicht, dass die gute Konjunktur nicht durch die Arbeit der jetzigen Regierung zustandegekommen ist, sondern, falls Regierungspolitik dabei eine Rolle spielt, es die Leistung der vorigen Regierung war. Der T\u00fcrkisblaue Anteil ist der, dass die Arbeitsbedingungen sich durch die 12/60 Regelung verchlechtert haben.",
#       "comment_created_at": "2019-05-01T18:17:03.827000",
#       "comment_length": 339,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041073564,
#           "parent_id": 1041073412,
#           "user_id": 523527,
#           "user_name": "icecold_lips",
#           "user_gender": "m",
#           "user_created_at": "2013-09-04T12:37:09.603000",
#           "comment_headline": "Ja, als die Genossen in der Regierung war w\u00fcrde da ja immer vorbildlich differenziert.",
#           "comment_text": "Und: eine schwarze Null haben rotbeteiligte Regierungen trotz guter Konjunktur nie zustande gebracht!",
#           "comment_created_at": "2019-05-01T18:20:52.583000",
#           "comment_length": 101,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041074359,
#               "parent_id": 1041073564,
#               "user_id": 673904,
#               "user_name": "Pfade",
#               "user_gender": "Unknown",
#               "user_created_at": "2018-05-12T17:56:49.567000",
#               "comment_headline": "No Headline",
#               "comment_text": "man muss sich ja nicht am Grasser orientieren.",
#               "comment_created_at": "2019-05-01T18:40:39.903000",
#               "comment_length": 46,
#               "depth": 2,
#               "replies": []
#             },
#             {
#               "id": 1041079501,
#               "parent_id": 1041073564,
#               "user_id": 10581,
#               "user_name": "alterdepp",
#               "user_gender": "m",
#               "user_created_at": "2008-07-04T18:25:05.367000",
#               "comment_headline": "No Headline",
#               "comment_text": "Erstens: was genau haben wir von einer schwarzen Null? Zweitens: Bisher alles nur Rechenkunstst\u00fccke und Ank\u00fcndigungen. Die Rechnung zahlen auf jeden Fall die Lohnabh\u00e4ngigen. Drittens: Nat\u00fcrlich schreibt sich jede Regierung die guten Wirtschaftsdaten auf ihre Fahnen, wahrer wird es dadurch trotzdem nicht. Ich bin nicht der Anwalt der SP\u00d6, da geht ihre Replik ins Leere.",
#               "comment_created_at": "2019-05-01T21:52:13.793000",
#               "comment_length": 370,
#               "depth": 2,
#               "replies": []
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": 1041073523,
#       "parent_id": null,
#       "user_id": 665911,
#       "user_name": "Never ending story",
#       "user_gender": "Unknown",
#       "user_created_at": "2018-01-10T22:10:43.650000",
#       "comment_headline": "Im Westen neues zur SP\u00d6.",
#       "comment_text": "Neue Regionale Gruppe der SP\u00d6 gegr\u00fcndet, mit regen Zuspruch aus der Bev\u00f6lkerung und neuen Mitgliedern.",
#       "comment_created_at": "2019-05-01T18:19:38.370000",
#       "comment_length": 102,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041073766,
#           "parent_id": 1041073523,
#           "user_id": 74674,
#           "user_name": "GuteNachtSchaukel",
#           "user_gender": "Unknown",
#           "user_created_at": "2007-04-02T20:34:49.397000",
#           "comment_headline": "No Headline",
#           "comment_text": "Wo?",
#           "comment_created_at": "2019-05-01T18:26:02.700000",
#           "comment_length": 3,
#           "depth": 1,
#           "replies": []
#         },
#         {
#           "id": 1041075772,
#           "parent_id": 1041073523,
#           "user_id": 563778,
#           "user_name": "Glumanda",
#           "user_gender": "m",
#           "user_created_at": "2015-06-26T07:21:53.540000",
#           "comment_headline": "No Headline",
#           "comment_text": "Regionale Gruppe -> W\u00f6lflinge?",
#           "comment_created_at": "2019-05-01T19:28:26.547000",
#           "comment_length": 30,
#           "depth": 1,
#           "replies": []
#         },
#         {
#           "id": 1041075378,
#           "parent_id": 1041073523,
#           "user_id": 607127,
#           "user_name": "at1234567",
#           "user_gender": "w",
#           "user_created_at": "2017-01-23T14:30:49.173000",
#           "comment_headline": "No Headline",
#           "comment_text": "Das sind ja erfreuliche Nachrichten! Haben Sie bitte Details?",
#           "comment_created_at": "2019-05-01T19:14:57.563000",
#           "comment_length": 61,
#           "depth": 1,
#           "replies": []
#         }
#       ]
#     },
#     {
#       "id": 1041080546,
#       "parent_id": null,
#       "user_id": 179502,
#       "user_name": "nosferatus3",
#       "user_gender": "m",
#       "user_created_at": "2007-12-29T11:24:59.210000",
#       "comment_headline": "wundere mich eigentlich",
#       "comment_text": "dass die \u00d6vp den 85.Jahrestag des Konkordats mit der katholischen Kirche, die dieser weitgehenden Einfluss auf das Schul- und Ehe Wesen einr\u00e4umte, nicht feierlich begeht.. War doch bis vor kurzem Dollfu\u00df eine der Heroen?",
#       "comment_created_at": "2019-05-01T22:30:21.040000",
#       "comment_length": 220,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041080641,
#           "parent_id": 1041080546,
#           "user_id": 687628,
#           "user_name": "Missy Super",
#           "user_gender": "Unknown",
#           "user_created_at": "2019-02-11T13:54:04.403000",
#           "comment_headline": "No Headline",
#           "comment_text": "Dank des Konkordats haben wir keine saubere Trennung zwischen Religion und Staat. Da war uns Atat\u00fcrk weit voraus.",
#           "comment_created_at": "2019-05-01T22:34:14.253000",
#           "comment_length": 113,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041082068,
#               "parent_id": 1041080641,
#               "user_id": 502216,
#               "user_name": "Filippos Bzahlnixos",
#               "user_gender": "m",
#               "user_created_at": "2006-08-02T10:34:20.413000",
#               "comment_headline": "No Headline",
#               "comment_text": "Das Ergebnis heute ist beeindruckend, Kopft\u00fccher wohin man schaut ;-)",
#               "comment_created_at": "2019-05-01T23:55:35.320000",
#               "comment_length": 69,
#               "depth": 2,
#               "replies": []
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": 1041080588,
#       "parent_id": null,
#       "user_id": 189074,
#       "user_name": "nathan calcio",
#       "user_gender": "m",
#       "user_created_at": "2002-01-18T11:28:06",
#       "comment_headline": "No Headline",
#       "comment_text": "Ach die Pam. Erschreckend schwach! Wer hat ihr diese laue und platte Rede geschrieben? Der Mugabe? Der Prozda?! Nur  blabla. Warum tut sie sich das an??",
#       "comment_created_at": "2019-05-01T22:32:12.877000",
#       "comment_length": 152,
#       "depth": 0,
#       "replies": [
#         {
#           "id": 1041082048,
#           "parent_id": 1041080588,
#           "user_id": 502216,
#           "user_name": "Filippos Bzahlnixos",
#           "user_gender": "m",
#           "user_created_at": "2006-08-02T10:34:20.413000",
#           "comment_headline": "No Headline",
#           "comment_text": "Silberstein, als Ghostwriter  ;-)",
#           "comment_created_at": "2019-05-01T23:53:34.490000",
#           "comment_length": 33,
#           "depth": 1,
#           "replies": []
#         },
#         {
#           "id": 1041082266,
#           "parent_id": 1041080588,
#           "user_id": 608398,
#           "user_name": "wederlechtsnochrinks",
#           "user_gender": "m",
#           "user_created_at": "2017-02-18T16:05:32.167000",
#           "comment_headline": "No Headline",
#           "comment_text": "Spielen Sie bitte nicht den entt\u00e4uschten und ver\u00e4rgerten Sozi - Jeder wei\u00df wo Ihre politische Heimat liegt",
#           "comment_created_at": "2019-05-02T00:12:56.797000",
#           "comment_length": 106,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041135688,
#               "parent_id": 1041082266,
#               "user_id": 189074,
#               "user_name": "nathan calcio",
#               "user_gender": "m",
#               "user_created_at": "2002-01-18T11:28:06",
#               "comment_headline": "No Headline",
#               "comment_text": "Ich habe keine politische Heimat auch wenn ihnen das nicht passt! Ihre liegt anscheinend in rot/blau nach Linzer und Burgenland Vorbild.",
#               "comment_created_at": "2019-05-03T20:51:20.567000",
#               "comment_length": 136,
#               "depth": 2,
#               "replies": []
#             }
#           ]
#         },
#         {
#           "id": 1041081081,
#           "parent_id": 1041080588,
#           "user_id": 687628,
#           "user_name": "Missy Super",
#           "user_gender": "Unknown",
#           "user_created_at": "2019-02-11T13:54:04.403000",
#           "comment_headline": "No Headline",
#           "comment_text": "Wieso Mugabe? Glaubens, sie hat das getrommelt und vorgetanzt? Wieso Drozda? Glaubens, der hat es getrommelt und vorgetanzt? Das Einzig Laue und Platte sind Sie.",
#           "comment_created_at": "2019-05-01T22:51:29.093000",
#           "comment_length": 161,
#           "depth": 1,
#           "replies": []
#         },
#         {
#           "id": 1041082036,
#           "parent_id": 1041080588,
#           "user_id": 554200,
#           "user_name": "pur",
#           "user_gender": "w",
#           "user_created_at": "2014-12-19T23:17:04.410000",
#           "comment_headline": "No Headline",
#           "comment_text": "Warum r\u00fccken sie die SP\u00d6 in den Kreis von Mugabe - geht's eigentlich noch ???",
#           "comment_created_at": "2019-05-01T23:52:44.520000",
#           "comment_length": 77,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041135767,
#               "parent_id": 1041082036,
#               "user_id": 189074,
#               "user_name": "nathan calcio",
#               "user_gender": "m",
#               "user_created_at": "2002-01-18T11:28:06",
#               "comment_headline": "No Headline",
#               "comment_text": "Kennen sie den Plan A nicht von Kern mit seinen Enteignungsphantasien. H\u00f6ren sie sich doch Ruth Becher oder  Pam an - und dann Mugabe. Da werden sie merken......",
#               "comment_created_at": "2019-05-03T20:54:15.060000",
#               "comment_length": 161,
#               "depth": 2,
#               "replies": []
#             }
#           ]
#         },
#         {
#           "id": 1041080952,
#           "parent_id": 1041080588,
#           "user_id": 81444,
#           "user_name": "Hausverstand55",
#           "user_gender": "m",
#           "user_created_at": "2011-01-02T21:33:17.030000",
#           "comment_headline": "No Headline",
#           "comment_text": "Die Rede hat der Drozda geschrieben. Und jetzt muss er auf die Uhr schauen, denn deine Zeit ist bald abgelaufen.",
#           "comment_created_at": "2019-05-01T22:46:35.463000",
#           "comment_length": 112,
#           "depth": 1,
#           "replies": [
#             {
#               "id": 1041081217,
#               "parent_id": 1041080952,
#               "user_id": 687628,
#               "user_name": "Missy Super",
#               "user_gender": "Unknown",
#               "user_created_at": "2019-02-11T13:54:04.403000",
#               "comment_headline": "No Headline",
#               "comment_text": "Achso, der Drozda schreibt f\u00fcr eine Akademikerin. Tr\u00e4umens ruhig weiter.",
#               "comment_created_at": "2019-05-01T22:57:54.197000",
#               "comment_length": 72,
#               "depth": 2,
#               "replies": [
#                 {
#                   "id": 1041082079,
#                   "parent_id": 1041081217,
#                   "user_id": 670118,
#                   "user_name": "Pomfinebra",
#                   "user_gender": "Unknown",
#                   "user_created_at": "2018-03-20T13:26:09.680000",
#                   "comment_headline": "No Headline",
#                   "comment_text": "Egal wer was schreibt. F\u00fcr mich klingt die Frau Pamela \"Joy\" Rendi-Wagner wie CK auf weiblich.",
#                   "comment_created_at": "2019-05-01T23:56:59.683000",
#                   "comment_length": 94,
#                   "depth": 3,
#                   "replies": []
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": 1041873390,
#       "parent_id": null,
#       "user_id": 560940,
#       "user_name": "a comment",
#       "user_gender": "w",
#       "user_created_at": "2015-05-01T06:38:06.480000",
#       "comment_headline": "No Headline",
#       "comment_text": "Und dem blauen Doskozil halten sie weiter die Stange!",
#       "comment_created_at": "2019-05-22T15:33:34.550000",
#       "comment_length": 53,
#       "depth": 0,
#       "replies": []
#     }
#   ]
# }

# %% [markdown]
# # Now lets start building the context sphere
# I understand your point. You're looking to create a more comprehensive view of a user's activity and interactions within the comment threads. Instead of just seeing isolated comments made by a user, you want to see the full context of their engagement. This includes:
#
# 1. All comments made by the user across different articles.
# 2. For each comment, you want to see the entire thread it belongs to, not just the user's comment in isolation.
# 3. This will show what the user was responding to and how their comment fits into the larger conversation.
# 4. It will also reveal any subsequent responses to the user's comments.
#
# The goal is to build a "context sphere" around each user, showing their complete interaction history within the comment ecosystem. This approach will provide a more nuanced understanding of the user's behavior, opinions, and how they engage with others in discussions.
#
# Is this interpretation correct? If so, I can suggest how to modify your existing code to achieve this goal.

# %%
class UserContextSphere:
    def __init__(self, df, thread_manager):
        self.df = df
        self.thread_manager = thread_manager
        self.user_comments = {user_id: group for user_id, group in df.groupby('ID_CommunityIdentity')}

    def get_user_context(self, user_id):
        if user_id not in self.user_comments:
            return None

        user_df = self.user_comments[user_id]
        user_context = {
            'user_id': int(user_id),
            'user_name': user_df['UserCommunityName'].iloc[0],
            'user_gender': user_df['UserGender'].iloc[0],
            'user_created_at': user_df['UserCreatedAt'].iloc[0].isoformat(),
            'total_comments': len(user_df),
            'comment_threads': []
        }

        for _, comment in user_df.iterrows():
            article_id = int(comment['ID_Article'])
            article_thread = self.thread_manager.get_article_threads(article_id)

            if article_thread:
                user_comment = self.find_user_comment(article_thread['comment_threads'], int(comment['ID_Posting']))
                if user_comment:
                    user_context['comment_threads'].append({
                        'article_id': article_id,
                        'article_title': article_thread['article_title'],
                        'article_publish_date': article_thread['article_publish_date'],
                        'thread': user_comment
                    })

        return user_context

    def find_user_comment(self, threads, comment_id):
        for thread in threads:
            if thread['id'] == comment_id:
                return thread
            if thread['replies']:
                result = self.find_user_comment(thread['replies'], comment_id)
                if result:
                    return result
        return None

# %%
if __name__ == "__main__":
    # Initialize and preprocess data
    preprocessor = DataPreprocessor('./data/raw_csv/Postings_01052019_31052019.csv')
    preprocessor.load_data()
    preprocessor.preprocess()

    # Create CommentThreadManager
    thread_manager = CommentThreadManager(preprocessor.df)

    # Create UserContextSphere
    user_context_sphere = UserContextSphere(preprocessor.df, thread_manager)

    # Example: Get context sphere for a specific user
    user_id = 671476  # Replace with the desired user ID
    user_context = user_context_sphere.get_user_context(user_id)

    if user_context:
        print(f"User ID: {user_context['user_id']}")
        print(f"User Name: {user_context['user_name']}")
        print(f"Total Comments: {user_context['total_comments']}")
        print("\nComment Threads:")
        for thread in user_context['comment_threads']:
            print(f"  Article: {thread['article_title']}")
            print(f"  User's Comment: {thread['thread']['comment_text']}")
            print(f"  Replies: {len(thread['thread']['replies'])}")
            print("  ---")
    else:
        print(f"No context found for user ID {user_id}")
