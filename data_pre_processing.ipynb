# %%
# Merge csv Posting and Votes
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
df = pd.read_csv(r'./data/raw_csv/Postings_01052019_31052019.csv')

# Display the first 10 rows
print(df.head(10).to_string())

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import json
import pickle
import tiktoken

class DataPreprocessor:
    """
    A class to preprocess the raw comment data.
    """

    def __init__(self, file_path):
        """
        Initialize the DataPreprocessor with the path to the raw data file.
        
        :param file_path: str, path to the raw CSV file
        """
        self.file_path = file_path
        self.df = None

    def load_data(self):
        """Load the raw data from CSV file."""
        self.df = pd.read_csv(self.file_path)

    def preprocess(self):
        """Apply all preprocessing steps to the data."""
        self._convert_dates()
        self._handle_missing_values()
        self._convert_id_columns()
        self._create_new_features()

    def _convert_dates(self):
        """Convert date columns to datetime format."""
        date_columns = ['PostingCreatedAt', 'ArticlePublishingDate', 'UserCreatedAt']
        for col in date_columns:
            self.df[col] = pd.to_datetime(self.df[col])

    def _handle_missing_values(self):
        """Handle missing values in the dataset."""
        self.df['PostingHeadline'] = self.df['PostingHeadline'].fillna('No Headline')
        self.df['PostingComment'] = self.df['PostingComment'].fillna('No Comment')
        self.df['UserGender'] = self.df['UserGender'].fillna('Unknown')
        self.df['UserCommunityName'] = self.df['UserCommunityName'].fillna('Unknown')

    def _convert_id_columns(self):
        """Convert ID columns to integers."""
        id_columns = ['ID_Posting', 'ID_Posting_Parent', 'ID_CommunityIdentity', 'ID_Article']
        for col in id_columns:
            self.df[col] = self.df[col].fillna(0).astype(int)

    def _create_new_features(self):
        """Create new features from existing data."""
        self.df['CommentLength'] = self.df['PostingComment'].str.len()
        self.df['DaysSinceUserCreation'] = (self.df['PostingCreatedAt'] - self.df['UserCreatedAt']).dt.days
        self.df['IsReply'] = self.df['ID_Posting_Parent'] != 0
        self.df['PostingHour'] = self.df['PostingCreatedAt'].dt.hour
        self.df['PostingDayOfWeek'] = self.df['PostingCreatedAt'].dt.dayofweek

    def save_preprocessed_data(self, output_path):
        """
        Save the preprocessed data to a CSV file.
        
        :param output_path: str, path to save the preprocessed CSV file
        """
        self.df.to_csv(output_path, index=False)

        def save_preprocessed_data(self, output_path):
            """
            Save the preprocessed data to a pickle file.
            
            :param output_path: str, path to save the preprocessed pickle file
            """
        with open(output_path, 'wb') as f:
            pickle.dump(self.df, f)
        print(f"Preprocessed data saved to {output_path}")

    @classmethod
    def load_preprocessed_data(cls, input_path):
        """
        Load preprocessed data from a pickle file.
        
        :param input_path: str, path to the preprocessed pickle file
        :return: DataPreprocessor instance with loaded data
        """
        with open(input_path, 'rb') as f:
            df = pickle.load(f)

        preprocessor = cls(None)  # Create instance without file path
        preprocessor.df = df
        print(f"Preprocessed data loaded from {input_path}")
        return preprocessor

class CommentThreadManager:
    """
    A class to manage and structure comment threads for articles.
    """

    def __init__(self, df):
        """
        Initialize the CommentThreadManager with a preprocessed DataFrame.
        
        :param df: pandas DataFrame, preprocessed comment data
        """
        self.article_comments = {article_id: group for article_id, group in df.groupby('ID_Article')}

    def build_comment_thread(self, comments, parent_id, depth=0):
        thread = []
        replies = comments[comments['ID_Posting_Parent'] == parent_id]
        for _, reply in replies.iterrows():
            sub_thread = self.build_comment_thread(comments, int(reply['ID_Posting']), depth + 1)
            thread_item = {
                'id': int(reply['ID_Posting']),
                'parent_id': int(reply['ID_Posting_Parent']) if pd.notnull(reply['ID_Posting_Parent']) else None,
                'user_id': int(reply['ID_CommunityIdentity']),
                'user_name': reply['UserCommunityName'],
                'user_gender': reply['UserGender'],
                'user_created_at': reply['UserCreatedAt'].isoformat() if pd.notnull(reply['UserCreatedAt']) else None,
                'comment_headline': reply['PostingHeadline'],
                'comment_text': reply['PostingComment'],
                'comment_created_at': reply['PostingCreatedAt'].isoformat() if pd.notnull(reply['PostingCreatedAt']) else None,
                'comment_length': int(reply['CommentLength']),
                'depth': depth,
                'replies': sub_thread,
                'thread_stats': {
                    'total_comments': 1 + sum(r['thread_stats']['total_comments'] for r in sub_thread),
                    'max_depth': depth + max([r['thread_stats']['max_depth'] for r in sub_thread] + [0]),
                }
            }
            thread.append(thread_item)
        return thread

    def get_article_threads(self, article_id):
        """
        Get the structured comment threads for a specific article.
        
        :param article_id: int, ID of the article
        :return: dict, structured article data with comment threads
        """
        if article_id not in self.article_comments:
            return None

        article_df = self.article_comments[article_id]
        root_comments = article_df[article_df['ID_Posting_Parent'].isnull() | (article_df['ID_Posting_Parent'] == 0)]

        threads = []
        for _, comment in root_comments.iterrows():
            thread = {
                'id': int(comment['ID_Posting']),
                'parent_id': None,
                'user_id': int(comment['ID_CommunityIdentity']),
                'user_name': comment['UserCommunityName'],
                'user_gender': comment['UserGender'],
                'user_created_at': comment['UserCreatedAt'].isoformat() if pd.notnull(comment['UserCreatedAt']) else None,
                'comment_headline': comment['PostingHeadline'],
                'comment_text': comment['PostingComment'],
                'comment_created_at': comment['PostingCreatedAt'].isoformat() if pd.notnull(comment['PostingCreatedAt']) else None,
                'comment_length': int(comment['CommentLength']),
                'depth': 0,
                'replies': self.build_comment_thread(article_df, int(comment['ID_Posting']), 1)
            }
            threads.append(thread)

        article_meta = article_df.iloc[0]

        return {
            'article_id': int(article_id),
            'article_title': article_meta['ArticleTitle'],
            'article_publish_date': article_meta['ArticlePublishingDate'].isoformat() if pd.notnull(article_meta['ArticlePublishingDate']) else None,
            'article_channel': article_meta['ArticleChannel'],
            'article_ressort_name': article_meta['ArticleRessortName'],
            'total_comments': len(article_df),
            'root_comments': len(root_comments),
            'comment_threads': threads
        }

    def get_article_ids(self):
        """
        Get a list of all article IDs in the dataset.
        
        :return: list of int, article IDs
        """
        return list(self.article_comments.keys())
    
    def get_user_ids(self):
        """
        Get a list of all user IDs in the dataset.
        
        :return: list of int, user IDs
        """
        return self.df['ID_CommunityIdentity'].unique().tolist()

# %%
# Usage example
if __name__ == "__main__":
    # Preprocess the data
    preprocessor = DataPreprocessor('./data/raw_csv/Postings_01052019_31052019.csv')
    preprocessor.load_data()
    preprocessor.preprocess()
    preprocessor.save_preprocessed_data('preprocessed_data.csv')

    # Create comment thread manager
    manager = CommentThreadManager(preprocessor.df)

    # Get threads for a specific article
    article_id = 2000102330973  # Example article ID
    result = manager.get_article_threads(article_id)

    # Pretty print the result
    print(json.dumps(result, indent=2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 5
#       2 if __name__ == "__main__":
#       3     # Preprocess the data
#       4     preprocessor = DataPreprocessor('./data/raw_csv/Postings_01052019_31052019.csv')
# ----> 5     preprocessor.load_data()
#       6     preprocessor.preprocess()
#       7     preprocessor.save_preprocessed_data('preprocessed_data.csv')
#
# Cell In[24], line 23, in DataPreprocessor.load_data(self)
#      21 def load_data(self):
#      22     """Load the raw data from CSV file."""
# ---> 23     self.df = pd.read_csv(self.file_path)
#
# File ~/Documents/GitHub/Emotion-Classification-Langgraph/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/GitHub/Emotion-Classification-Langgraph/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/Documents/GitHub/Emotion-Classification-Langgraph/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/Documents/GitHub/Emotion-Classification-Langgraph/venv/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:331, in getstate(self)
#
# KeyboardInterrupt:

# %% [markdown]
# # Now lets start building the context sphere
# I understand your point. You're looking to create a more comprehensive view of a user's activity and interactions within the comment threads. Instead of just seeing isolated comments made by a user, you want to see the full context of their engagement. This includes:
#
# 1. All comments made by the user across different articles.
# 2. For each comment, you want to see the entire thread it belongs to, not just the user's comment in isolation.
# 3. This will show what the user was responding to and how their comment fits into the larger conversation.
# 4. It will also reveal any subsequent responses to the user's comments.
#
# The goal is to build a "context sphere" around each user, showing their complete interaction history within the comment ecosystem. This approach will provide a more nuanced understanding of the user's behavior, opinions, and how they engage with others in discussions.
#
# Is this interpretation correct? If so, I can suggest how to modify your existing code to achieve this goal.

# %%
class UserContextSphere:
    def __init__(self, df, thread_manager):
        self.df = df
        self.thread_manager = thread_manager
        self.user_comments = {user_id: group for user_id, group in df.groupby('ID_CommunityIdentity')}

    def get_user_context(self, user_id):
        if user_id not in self.user_comments:
            return None

        user_df = self.user_comments[user_id]

        # Calculate user statistics
        total_comments = len(user_df)
        total_replies = len(user_df[user_df['ID_Posting_Parent'].notnull()])

        user_context = {
            'user_id': int(user_id),
            'user_name': user_df['UserCommunityName'].iloc[0],
            'user_gender': user_df['UserGender'].iloc[0],
            'user_created_at': user_df['UserCreatedAt'].iloc[0].isoformat(),
            'total_comments': total_comments,
            'total_replies': total_replies,
            'articles': {}
        }

        # Group comments by article
        for article_id, article_comments in user_df.groupby('ID_Article'):
            article_id = int(article_id)
            article_thread = self.thread_manager.get_article_threads(article_id)

            if article_thread:
                user_context['articles'][article_id] = {
                    'article_title': article_thread['article_title'],
                    'article_publish_date': article_thread['article_publish_date'],
                    'user_comments_count': len(article_comments),
                    'user_replies_count': len(article_comments[article_comments['ID_Posting_Parent'].notnull()]),
                    'threads': []
                }

                for _, comment in article_comments.iterrows():
                    thread = self.find_thread_for_comment(article_thread['comment_threads'], int(comment['ID_Posting']))
                    if thread:
                        user_context['articles'][article_id]['threads'].append(thread)

        return user_context

    def find_thread_for_comment(self, threads, comment_id):
        for thread in threads:
            if thread['id'] == comment_id:
                return thread
            if thread['replies']:
                result = self.find_thread_for_comment(thread['replies'], comment_id)
                if result:
                    return thread  # Return the whole thread, not just the subthread
        return None

    def generate_user_report(self, user_id):
        user_context = self.get_user_context(user_id)
        if not user_context:
            return f"No data found for user ID {user_id}"
    
        report = f"User Report for ID: {user_context['user_id']}\n"
        report += f"Name: {user_context['user_name']}\n"
        report += f"Gender: {user_context['user_gender']}\n"
        report += f"Created At: {user_context['user_created_at']}\n"
        report += f"Total Comments: {user_context['total_comments']}\n"
        report += f"Total Replies: {user_context['total_replies']}\n\n"
    
        for article_id, article_data in user_context['articles'].items():
            report += f"Article: {article_data['article_title']}\n"
            report += f"Published: {article_data['article_publish_date']}\n"
            report += f"User Comments on this Article: {article_data['user_comments_count']}\n"
            report += f"User Replies on this Article: {article_data['user_replies_count']}\n\n"
    
            for thread in article_data['threads']:
                report += self.format_thread(thread, user_id, 0)
                report += "\n"
    
        return report

    def format_thread(self, thread, user_id, depth):
        indent = "  " * depth
        is_user = thread['user_id'] == user_id
        user_indicator = " (USER)" if is_user else ""
    
        formatted = f"{indent}[{thread['user_name']}]{user_indicator}: {thread['comment_text']}\n"
    
        for reply in thread['replies']:
            formatted += self.format_thread(reply, user_id, depth + 1)
    
        return formatted

    def count_tokens(self, text):
        encoding = tiktoken.get_encoding("cl100k_base")
        tokens_lst = encoding.encode(text)
        return len(tokens_lst)

    def generate_user_report_with_token_count(self, user_id):
        report = self.generate_user_report(user_id)
        token_count = self.count_tokens(report)
        report += f"\nTotal token count: {token_count}"
        return report, token_count

# %%
import os

if __name__ == "__main__":
    preprocessed_file = "data/preprocessed/preprocessed_data.pkl"

    if not os.path.exists(preprocessed_file):
        print("Preprocessed data not found. Preprocessing...")
        preprocessor = DataPreprocessor('./data/raw_csv/Postings_01052019_31052019.csv')
        preprocessor.load_data()
        preprocessor.preprocess()
        preprocessor.save_preprocessed_data(preprocessed_file)
    else:
        print("Loading preprocessed data...")
        preprocessor = DataPreprocessor.load_preprocessed_data(preprocessed_file)

    # Create CommentThreadManager
    thread_manager = CommentThreadManager(preprocessor.df)

    # Create UserContextSphere
    user_context_sphere = UserContextSphere(preprocessor.df, thread_manager)

    # Example: Generate report for a specific user
    user_id = 74674  # Replace with the desired user ID
    user_report, token_count = user_context_sphere.generate_user_report_with_token_count(user_id)


print(user_report)
# Out:
# Loading preprocessed data...
# Preprocessed data loaded from data/preprocessed/preprocessed_data.pkl
# User Report for ID: 74674
# Name: GuteNachtSchaukel
# Gender: Unknown
# Created At: 2007-04-02T20:34:49.397000
# Total Comments: 340
# Total Replies: 340
#
# Article: Pool, Kino, Fitnessraum: Londons Superreiche gehen in den Keller
# Published: 2019-05-07T07:00:00
# User Comments on this Article: 1
# User Replies on this Article: 1
#
# [GuteNachtSchaukel] (USER): Schätze das ist die persönliche Vorbereitung auf die Apokalypse, die sie gerade vorbereiten
#
# Article: Nur Tanken und Heizen teurer zu machen wird das Klima nicht retten
# Published: 2019-05-05T14:00:00
# User Comments on this Article: 3
# User Replies on this Article: 3
#
# [GuteNachtSchaukel] (USER): Macron hat die CO2 Steuern erhöht und damit die Benzinpreise, Heizkosten für alle in die Höhe getrieben - das trifft massiv die ärmeren Leute und den Mittelstand, hätte er diese Menschen leichzeitig entlastet z.b. mit Gratis-öffis, wären ihm die Proteste erspart geblieben und er hätte einen wertvollen Beitrag zur Umverteilung getan  Es kommt halt darauf an, was man ZUSÄTZLICH zu den CO2 Steuern an Maßnahmen und Investitionen tätigt:  Eine substantielle Erhöhung und Einführung der CO2-Steuern, auch im Sinne der Kostenwahrheit und gezielter Investition in den gleichzeitigem Ausbau der Öffis, und ökologischer Verkehrskonzepte Einführung von am besten GratisÖFFIS -  verhindert Gelbwestenproteste, weil die Menschen finanziell entlastet werden.
#
# [GuteNachtSchaukel] (USER): ALLES, was auch nur ein bisserl dazu beitragen kann, dass die Erde belebbar bleibt/wieder belebbar wird, ist es wert umgesetzt zu werden.
#
# [carimali]: solange fossile brennstoffe gefördert (produziert) werden, werden sie auch verbraucht. die meisten maßnahmen regeln nicht den globalen gesamtverbrauch, sondern nur die globale verteilung des fossilen co2. solange auf der welt kein konsens über klimaregulierende mechanismen besteht, seh ich schwarz......
#   [-_never_ change_ a_ running_ system]: Während man in Deutschland die Kohlekraftwerke bis 2030 verringern will und bis 2038 gänzlich anschaffen, werden weltweit zur Zeit über 1000 neue gebaut oder sind in Planung. Was bringt es, wenn ich statt eines sehr sparsamen Eur5 Diesel ein E-auto fahre, dass  an einer öffentlichen Tanksäule Strom aus einem Kohlekraftwerk bezieht wie das der Fall sein kann. Erst kürzlich hat die Deutsche Bundesnetzagentur bekannt gegeben, dass durch den steigenden Strombedarf für die Netzstabilität der Strom von 10 Atomkraftwerken als Reserve benötigt wird. Da ist aber die Abschaltung der Kohlekraftwerke noch nicht inbegriffen.  Wäre die Lösung  zurück zum Bauernhof des 19. Jh
#     [KRW_Leaf]: Der steigende Strombedarf hat herzlich wenig mit E-Autos zu tun. Der weltweite Strombedarf verdoppelt sich alle 4 Jahre.  Und, wer sich hier ein E-Auto kauft tut dies aus Überzeugung, deshalb hat der-/diejenige auch Öko-Strom. Eine Wall-box bekommen Sie anders gar nicht gefördert.  Es gibt allerdings schon seit 5 Jahren eine belgische Studie, die besagt, das selbst im dreckigsten Kohle-Mix (Polen) ein E-Auto immer noch mindestens 25 % CO2 einspart.  Aber immer weiter raus mit den alten Kamellen. Das hilft bei der Eigenen Bequemlichkeit. Was kann einer schon ausrichten? Gehen Sie wählen? Hat keinen Sinn, ist ja nur Eine Stimme.
#       [-_never_ change_ a_ running_ system]: Abgesehen davon, dass es zig diametrale  Studien gibt,  glaub ich ja, dass ein E- Auto CO2 einspart, am besten durch Strom der eigenen Photovoltaikanlage am Dach. Aber die Industrie kann es nicht.  Und wenn ein Großteil der Autos durch E-Autos ersetzt werden soll, müsste zuerst in die Infrastruktur investiert werden.  Was soll das mit Bequemlichkeit zu tun haben? Eher damit, dass es bisher für viele noch nicht leistbar ist.  Ich persönlich fahre in der Stadt ausschließlich mit dem Rad oder geh zu Fuß.
#         [KRW_Leaf]: Radfahren in Wien? Mutig!
#           [-_never_ change_ a_ running_ system]: Ich sag ja nicht, dass das überall geht und dass das jeder kann, sei es gesundheitlich oder auch  wenn man am Land lebt und in der Stadt arbeitet.
#   [GuteNachtSchaukel] (USER): Eines der wenigen Dinge, wo ich dafür bin NICHT auf Konsens zu warten.
#
# Article: Bleiburg-Treffen: Faschisten dürfen aufmarschieren
# Published: 2019-05-02T06:00:00
# User Comments on this Article: 1
# User Replies on this Article: 1
#
# [GuteNachtSchaukel] (USER): Vor einem Jahr sah er "keine Handhabe, weil es eine Kirchen veranstaltung war" - https://orf.at/v2/stories/2435409/2435410/  Dann hat die Regierung im September lautstark und mit PR (es war ja schließlich das Gedenkjahr) ein Gesetzesvorhaben auf den Weg gebracht, das angeblich auch die Ustaschasymbole verbietet https://www.wienerzeitung.at/nachrichten/politik/oesterreich/992923-Regierung-will-mehr-extremistische-Symbole-verbieten.html https://kurier.at/politik/inland/verbot-von-wolfsgruss-und-kroatischen-nazi-symbolen-geplant/400132247  Und jetzt ist es keine Kirchenveranstaltung mehr - und es stellt sich heraus, dass das von Kurz und Strache so pompös beworbene Gesetz erst recht keine Handhabe bietet!  DAS ist widerlich
#   [j.h.k.]: "DAS" ist ein bissi grob. ist er doch unser aller geliebter bundesstudent....
#   [wemo19]: Man wird doch im christlichen Abendland nichts gegen KLERIKALfaschisten unternehmen ...
#
# Article: 1. Mai in Wien: SPÖ fordert von Strache Rücktritt
# Published: 2019-05-01T10:28:57.490000
# User Comments on this Article: 11
# User Replies on this Article: 11
#
# [kim_]: Die SPÖ spricht von 120.000 Teilnehmern. Die Polizei von 12.000.
#   [GuteNachtSchaukel] (USER): Woher haben Sie diese angeblichen Zahlen der Polizei? - weder im obigen Artikel, noch auf den Seiten der LPD wien sind welche zu finden.  Der Rathausplatz war jedenfalls bumvoll - was erfahrungsgemäß den 100 000 entspricht.
#     [kim_]: Ich wünschte, die Qualitätszeitung hätte hierzu bei der Polizei nachgefragt. In dem Fall war's jedoch die Krone.
#       [kim_]: auch die APA berichtet von 12.000 Teilnehmern lt. Polizei aber das passt hier vermutlich nicht zur Blattlinie
#         [GuteNachtSchaukel] (USER): Der Link zur APAmeldung? Ich finde nur den hier: https://www.apa.at/Site/News.de.html?id=6248250788 und der enthält keine Angaben der Polizei  Und der Artikel der Krone fällt eher unter Propaganda als unter Berichterstattung ud strotzt generell vor Falschbehauptungen
#           [kim_]: siehe tt.com, nachrichten.at, krone.at, wiener zeitung usw.
#             [GuteNachtSchaukel] (USER): https://www.nachrichten.at/nachrichten/politik/innenpolitik/die-regierung-macht-spoe-am-1-mai-konkurrenz;art385,3125281  Schauen Sie sich das Photo im Artikel an - der Rathausplatz ist zum Bersten voll, das entspricht eindeutig 100 000 Menschen
#   [Bummerl reloaded]: Aber über das kann man doch hinweg sehen. Sind halt Sozialisten, die haben's nicht so mit der Mathematik.... ;-)
#   [viess]: Die 12000 stimmen sicher, das sah man in der Webcam sehr gut
#   [kim_]: rot = ich akzeptiere keine fakten
#   [viess]: Auf 8000 Quadratmeter haben maximal 12000. locker herumstehende platz das ist eine einfache Rechnung!
#     [viess]: Der rotstrichler kann offensichtlich nicht rechnen....
#   [Never ending story]: No Comment
#   [laertes1]: ...die kommen aus bildungsfernen schichten - die polizisten...wie sollen sie da so weit zählen können ?
#     [wasnixsognix]: No Comment
#     [Missy Super]: Sry, aber dafür gabs auch von mir rot.
#     [unsinkable sam (oskar)]: selten dummer sager .....
#       [laertes1]: ...........:.jemandes einschätzung, der den test nicht bestanden hat.....
#         [unsinkable sam (oskar)]: wenns ironie war, dann sollten Sie diese kennzeichnen .....
#           [laertes1]: was käme denn für Sie als motivation meinerseits  noch in frage , außer einer ironischen empfehlung an die SPÖ-führung, auf diese weise "den menschen draußen) (!)  die eklatante  diskrepanz   zwischen ihrer  eigenen "unverdächtigen und selbstverständlich zutreffenden" (!) teilnehmerzählung und jener der  (kickl)poilizei  zu erklären ?
#             [unsinkable sam (oskar)]: nundenn.... hier muss man ironie bei solchen posts dazuschreiben. es gibt genügend poster, die das tatsächlich so meinen wie geschrieben. ohne ironie :(
#
# [Never ending story]: Neue Regionale Gruppe der SPÖ gegründet, mit regen Zuspruch aus der Bevölkerung und neuen Mitgliedern.
#   [GuteNachtSchaukel] (USER): Wo?
#   [Glumanda]: Regionale Gruppe -> Wölflinge?
#   [at1234567]: Das sind ja erfreuliche Nachrichten! Haben Sie bitte Details?
#
# [Horst_Jackson]: Welche Farbe hat der Feuerlöscher !   WELCHE FARBE HAT DER FEUERLÖSCHER !    .............Grundgütiger ! ! !
#   [GuteNachtSchaukel] (USER): Andreas Schieder hat eine geniale Rede gehalten, und ebenso Marina Hanke
#     [Horst_Jackson]: Hat er über die Salvinis, die Le Pens und die Orbans gesprochen und Nazis, die der SPÖ Heuchelei vorwerfen ?   Bei Schieder schwingt immer so viel Glaubwürdigkeit mit, wenn er was sagt. Ein sehr authentischer Mensch halt!  Andreas Schieder und Andreas Babler - Leitwölfe des politischen Idealismus.
#       [anton anton]: immer an seine partnerin bei siemens denken, wie die bei den abzockfirmen untergekrochen is
#     [PAS]: Ja? Wie oft hat er denn nach der Farbe des Feuerlöscherstraße gefragt, dass das bei den Roten schon als genial aufgefasst wurde.
#   [CEEIT]: Verkäuferin: Welchen Dildo hätten Sie den gerne? Kundin: Den Roten Verkäuferin: Das ist der Feuerlöscher....
#   [Hortensia die Erste]: Ist die rote Antwort auf "wer schafft die Arbeitsplätze???"  ;-) Die beiden schenken sich gegenseitig nichts.
#
# [Dampf Hans]: Wenn sich die SPÖ einmal mehr mit eigenen Visionen und deren Verwirklichung auseinandersetzen würde, statt ständig die Grauslichkeiten anderer als bestes Wahlmotiv vor sich her zu tragen wäre sie interessanter.
#   [GuteNachtSchaukel] (USER): Ich habe heute am Maiaufmarsch viele gute Ideen für eine menschenwürdige Zukunft gehört - die Analyse des Ist-Zustandes gehört auch dazu.
#     [Nutcracker]: Der Ist-Zustand ist zu einem großen Teil auf den roten Mist gewachsen, so lange ist Schwarz-Blau noch nicht in der Regierung.
#       [GuteNachtSchaukel] (USER): Der Ist-Zustand ist die Spaltung der Gesellschaft durch die Regierungsparteien
#       [GuteNachtSchaukel] (USER): Der Ist-Zustand ist die Umverteilung von unten nach oben durch die Regierungsparteien Der ist-Zustand ist der Abbau des Sozialstaates durch die Regierungsparteien
#           [laertes1]: was käme denn für Sie als motivation meinerseits  noch in frage , außer einer ironischen empfehlung an die SPÖ-führung, auf diese weise "den menschen draußen) (!)  die eklatante  diskrepanz   zwischen ihrer  eigenen "unverdächtigen und selbstverständlich zutreffenden" (!) teilnehmerzählung und jener der  (kickl)poilizei  zu erklären ?
#             [unsinkable sam (oskar)]: nundenn.... hier muss man ironie bei solchen posts dazuschreiben. es gibt genügend poster, die das tatsächlich so meinen wie geschrieben. ohne ironie :(
#
# [kim_]: Die SPÖ spricht von 120.000 Teilnehmern. Die Polizei von 12.000.
#   [GuteNachtSchaukel] (USER): Woher haben Sie diese angeblichen Zahlen der Polizei? - weder im obigen Artikel, noch auf den Seiten der LPD wien sind welche zu finden.  Der Rathausplatz war jedenfalls bumvoll - was erfahrungsgemäß den 100 000 entspricht.
#     [kim_]: Ich wünschte, die Qualitätszeitung hätte hierzu bei der Polizei nachgefragt. In dem Fall war's jedoch die Krone.
#       [kim_]: auch die APA berichtet von 12.000 Teilnehmern lt. Polizei aber das passt hier vermutlich nicht zur Blattlinie
#         [GuteNachtSchaukel] (USER): Der Link zur APAmeldung? Ich finde nur den hier: https://www.apa.at/Site/News.de.html?id=6248250788 und der enthält keine Angaben der Polizei  Und der Artikel der Krone fällt eher unter Propaganda als unter Berichterstattung ud strotzt generell vor Falschbehauptungen
#           [kim_]: siehe tt.com, nachrichten.at, krone.at, wiener zeitung usw.
#             [GuteNachtSchaukel] (USER): https://www.nachrichten.at/nachrichten/politik/innenpolitik/die-regierung-macht-spoe-am-1-mai-konkurrenz;art385,3125281  Schauen Sie sich das Photo im Artikel an - der Rathausplatz ist zum Bersten voll, das entspricht eindeutig 100 000 Menschen
#   [Bummerl reloaded]: Aber über das kann man doch hinweg sehen. Sind halt Sozialisten, die haben's nicht so mit der Mathematik.... ;-)
#   [viess]: Die 12000 stimmen sicher, das sah man in der Webcam sehr gut
#   [kim_]: rot = ich akzeptiere keine fakten
#   [viess]: Auf 8000 Quadratmeter haben maximal 12000. locker herumstehende platz das ist eine einfache Rechnung!
#     [viess]: Der rotstrichler kann offensichtlich nicht rechnen....
#   [Never ending story]: No Comment
#   [laertes1]: ...die kommen aus bildungsfernen schichten - die polizisten...wie sollen sie da so weit zählen können ?
#     [wasnixsognix]: No Comment
#     [Missy Super]: Sry, aber dafür gabs auch von mir rot.
#     [unsinkable sam (oskar)]: selten dummer sager .....
#       [laertes1]: ...........:.jemandes einschätzung, der den test nicht bestanden hat.....
#         [unsinkable sam (oskar)]: wenns ironie war, dann sollten Sie diese kennzeichnen .....
#           [laertes1]: was käme denn für Sie als motivation meinerseits  noch in frage , außer einer ironischen empfehlung an die SPÖ-führung, auf diese weise "den menschen draußen) (!)  die eklatante  diskrepanz   zwischen ihrer  eigenen "unverdächtigen und selbstverständlich zutreffenden" (!) teilnehmerzählung und jener der  (kickl)poilizei  zu erklären ?
#             [unsinkable sam (oskar)]: nundenn.... hier muss man ironie bei solchen posts dazuschreiben. es gibt genügend poster, die das tatsächlich so meinen wie geschrieben. ohne ironie :(
#
#
# [Dampf Hans]: Wenn sich die SPÖ einmal mehr mit eigenen Visionen und deren Verwirklichung auseinandersetzen würde, statt ständig die Grauslichkeiten anderer als bestes Wahlmotiv vor sich her zu tragen wäre sie interessanter.
#   [GuteNachtSchaukel] (USER): Ich habe heute am Maiaufmarsch viele gute Ideen für eine menschenwürdige Zukunft gehört - die Analyse des Ist-Zustandes gehört auch dazu.
#     [Nutcracker]: Der Ist-Zustand ist zu einem großen Teil auf den roten Mist gewachsen, so lange ist Schwarz-Blau noch nicht in der Regierung.
#       [GuteNachtSchaukel] (USER): Der Ist-Zustand ist die Spaltung der Gesellschaft durch die Regierungsparteien
#       [GuteNachtSchaukel] (USER): Der Ist-Zustand ist die Umverteilung von unten nach oben durch die Regierungsparteien Der ist-Zustand ist der Abbau des Sozialstaates durch die Regierungsparteien
#
# [Dampf Hans]: Wenn sich die SPÖ einmal mehr mit eigenen Visionen und deren Verwirklichung auseinandersetzen würde, statt ständig die Grauslichkeiten anderer als bestes Wahlmotiv vor sich her zu tragen wäre sie interessanter.
#   [GuteNachtSchaukel] (USER): Ich habe heute am Maiaufmarsch viele gute Ideen für eine menschenwürdige Zukunft gehört - die Analyse des Ist-Zustandes gehört auch dazu.
#     [Nutcracker]: Der Ist-Zustand ist zu einem großen Teil auf den roten Mist gewachsen, so lange ist Schwarz-Blau noch nicht in der Regierung.
#       [GuteNachtSchaukel] (USER): Der Ist-Zustand ist die Spaltung der Gesellschaft durch die Regierungsparteien
#       [GuteNachtSchaukel] (USER): Der Ist-Zustand ist die Umverteilung von unten nach oben durch die Regierungsparteien Der ist-Zustand ist der Abbau des Sozialstaates durch die Regierungsparteien
#
# Article: Steuerreform: Regierung der kleinen Leute
# Published: 2019-05-01T16:15:29
# User Comments on this Article: 1
# User Replies on this Article: 1
#
# [Zebra]: Aber mit der Steuerreform zufrieden. Sie ist sozial gerecht.
#   [GuteNachtSchaukel] (USER): Findest Du? https://mosaik-blog.at/schwarz-blau-umverteilung-bundesregierung/
#     [AlterHase]: Bei dieser Seite fällt als Erstes ein großer "Spenden"-Button rechts oben ins Auge, gefolgt von einem "Spenden"-Popup beim Scrollen. Liefern Sie seriösere Quellen, abgesehen von den lächerlichen, wild zusammengeschusterten Berechnungsbeispielen fern jeder Realität.
#     [Rimpelpimpelpumpelpauz]: Regierungsdiffamirungs Website Nr 0123ß12i3
#   [eremit47]: Wenn sie denn wirklich kommt. Bis jetzt sind es nur Ankündigungen.
#
# Article: Wann ein "Putsch" kein Putsch ist, und was US-Söldner mit Venezuela zu tun haben
# Published: 2019-05-01T18:13:56.770000
# User Comments on this Article: 1
# User Replies on this Article: 1
#
# [GuteNachtSchaukel] (USER): Vielen Dank für diesen Artikel und die sachliche, differenzierte Darstellung!
#   [Girgl Galgenstein]: Ist das nicht die Altersvorsorge von der Sie schon immer geträumt haben?
#
# Article: Sauer wegen Reklamation: Gastwirt verprügelte vier Gäste
# Published: 2019-05-02T08:48:42.480000
# User Comments on this Article: 2
# User Replies on this Article: 2
#
# [kobuk_dems_haas_is]: Wären seine Vorfahren (siehe Speisekarte Seite 2) schon damals so renitent gegen Deutsche vorgegangen und hätten sie rausgeschmissen, hätte sich Österreich viel erspart.
#   [GuteNachtSchaukel] (USER): Stellt sich eher die Frage, was mit den Vorbesitzern passiert ist - laut Speisekarte pdf und NS-Stempel wurde das Gasthaus 1939 erworben
#     [vorsichtsrataufsitzender]: Die wurden wahrscheinlich auch so einer Behandlung unterzogen, wie die 4 Gaeste diese Woche....eine lokale Spezialitaet, aehnlich der Kaerntner Haustetschn......
#       [GuteNachtSchaukel] (USER): Es könnte ihnen zu dieser Zeit auch weitaus schlimmeres angetan worden sein.
#
# [kobuk_dems_haas_is]: Wären seine Vorfahren (siehe Speisekarte Seite 2) schon damals so renitent gegen Deutsche vorgegangen und hätten sie rausgeschmissen, hätte sich Österreich viel erspart.
#   [GuteNachtSchaukel] (USER): Stellt sich eher die Frage, was mit den Vorbesitzern passiert ist - laut Speisekarte pdf und NS-Stempel wurde das Gasthaus 1939 erworben
#     [vorsichtsrataufsitzender]: Die wurden wahrscheinlich auch so einer Behandlung unterzogen, wie die 4 Gaeste diese Woche....eine lokale Spezialitaet, aehnlich der Kaerntner Haustetschn......
#       [GuteNachtSchaukel] (USER): Es könnte ihnen zu dieser Zeit auch weitaus schlimmeres angetan worden sein.
#
# Article: Haftbefehl gegen Oppositionsführer López in Venezuela erlassen
# Published: 2019-05-02T09:30:02.840000
# User Comments on this Article: 2
# User Replies on this Article: 2
#
# [Chetter Hummin]: Auch Kurz kann sich in die Reihe dazugesellen die Beihilfe zum Mord geleistet haben. Aber Gewissensbisse hat der eh keine da kein Gewissen vorhanden ist.
#   [bouncing balls]: "mitschuldig" ist jeder, der hinnimmt, dass waffen nach saudi arabien geliefert werden, die im jemen eingesetzt werden.  "mitschuldig" ist jeder, der einen folterstaat von assad unterstützt.  "mitschuldig" ist jeder, der erdogan unterstützt, die laizistische türkei umzubauen ...    wie "mitschuldig" ist man also, wenn man einen oppositionspolitiker in venezuela unterstützt, im kampf gegen eine unrechtsherrschaft?   wie sehr soll man mit unterschiedlichem maß messen??
#     [abaris]: Bisher versagen die Medien kläglich darin, seine politischen Ziele - abseits von, er ist gegen Maduro - darzulegen. Das allein ist aber ein bißchen weniig, um Sympathien zu enwickeln. Die venezolanische Opposition ist ziemlich gespalten, und das einzige, was ich bisher herausfinden konnte ist, dass Guaido der viertstärksten Partei angehört, deren Führer er nicht einmal ist.
#     [AntiEsoTante]: Offenbar interessiert der BVTUA selbst im Standard-Forum außerhalb des entsprechenden Tickers niemanden.
#       [GuteNachtSchaukel] (USER): Er wäre allerdings nötig um aufzudecken, was rund um Ibiza, Razzia, Netzwerke in dieser Republik wirlich vor sich geht
#
# [Alastair McKenzie]: Weiß jemand, welchen Vorteil sich Rot und Blau von einem 14 Tage späteren Wahltermin versprechen?
#   [Eisenburg]: Desto später desto schlechter für Kurz. Denn desto länger weg vom Amt ist, desto mehr vergessen die Leute ihn, desto langweiliger wird sein NLP-Gequatsche. Wäre die Sommerpause nicht gewesen, Kurz hätte wohl so schnell wie möglich wählen lassen.
#     [Lincoln73]: Die Sozen machen sich Sorgen um ihre Pensionisten, die liegen im September nämlich am Strand in Kroatien herum. Darum drängen die auf den späten September.
#       [Kampfmuffin]: Laut Wählergruppenanalyse ist die ÖVP die Pensionistenpartei.
#   [amber103]: derzeit schlechte Umfragewerte
#   [Dr Döblinger]: Dürfte irgendwie mit den Schulferien zu tun haben.
#     [Alastair McKenzie]: Nein, die enden am 8.September.
#     [green job78]: nein, da gehts um einen längeren wahlkampf.  die schulferien enden am 8. september.  rot/blau erwartet sich ein besseres ergebnis, wenn der wahlkampf länger dauert.  auf der anderen seite hätte vanderbellen eine rasche wahl lieber, was ich auch verstehen kann.
#   [(sc)]: das wissen nicht einmal die
#   [Pfandbrief]: FPÖ: 14 Tage mehr um Ibiza aus den Hirnen zu verdrängen SPÖ: 14 Tage mehr um aus dem Tief irgendwie per Wunder rauszukommen
#   [GuteNachtSchaukel] (USER): ICH erwarte mir, dass der BVT-Ausschuss länger arbeiten kann - ab jetzt mit den VOLLSTÄNDIGEN Unterlagen aus den Ministerien
#     [AntiEsoTante]: Offenbar interessiert der BVTUA selbst im Standard-Forum außerhalb des entsprechenden Tickers niemanden.
#       [GuteNachtSchaukel] (USER): Er wäre allerdings nötig um aufzudecken, was rund um Ibiza, Razzia, Netzwerke in dieser Republik wirlich vor sich geht
#
# Article: Die kleine Welt, in der die große ihre Probe hält
# Published: 2019-05-31T20:33:42
# User Comments on this Article: 3
# User Replies on this Article: 3
#
# [easyliving]: Der Hauptfehler von Kurz war sein katastrophaler Umgang mit den Vetretern der Oppositionsparteien. Er hat sie ignoriert, monatelang nicht mit ihnen gesprochen, Gesetzesvorhaben ohne Anhörung durchgedrückt, Schlüsselpositionen umgefärbt, sich vor Parlamentssitzungen gedrückt. Und dafür zahlt er jetzt die Rechnung. Zurecht, denn so ein abgehobenes Denken passt gar nicht mehr in unsere Zeit. Wir sollten uns alle auf Augenhöhe begegnen, auch Politiker unterschiedlicher Couleurs.
#   [Hausverstand55]: ...braucht sich um eine schwache Opposition nicht zu kümmern. Das tun nur Schwächlinge.
#     [grro]: ...und Kurz war nur „stark“ übertrieben...
#       [Hausverstand55]: Beim Regieren geht's nicht ums Menschenbild, da geht es darum das Land nach vorne zu bringen und zukunftsfit zu machen. Wer mitzieht ist willkommen, wer wegen dem Verlust des Kanzlers auf Rache aus ist, soll bleiben wo er/sie will.
#       [Hausverstand55]: Kurz 38% (+6,5%) gegenüber der NR-Wahl 2017 PRW 23% (-3,9%) gegenüber der NR-Wahl 2017 (aktuelle Umfrage von Research Affairs)
#     [pomum terrestre]: Man sollte Hinterlist nicht mit Stärke verwechseln.  Herzlichst, da Baua.
#       [Hausverstand55]: Meinen Sie damit die SPÖ?
#     [Atreides1975]: Ob Sie's wahr haben wollen oder nicht - Kurz ist die Gallionsfigur einer Partei, die um die 20 % der Wähler hinter sich sieht. Klar, im Augenblick strahlt er und hat fabelhafte Werte. Aber das tat/hatte Schüssel 2002 auch, und wie es gerade mal 4 Jahre später endete, wissen wir.
#       [Hausverstand55]: Warum liegt die SPÖ so schlecht? Weil sie keine Gallionsfigur hat, sondern nur ein sogar innerhalb der Partei umstrittenes Mäderl.
#         [Atreides1975]: Ihnen kann man leider nicht helfen.
#         [grro]: ...haben Sie das notwendig?
#           [Hausverstand55]: Ein Mäderl ist ein liebes, nettes Wesen...nur leider ein bisschen naiv, leichtgläubig und mit schwach ausgeprägter Persönlichkeit. Meist sind sie blond, es gibt aber auch dunkle Typen.
#             [easyliving]: Frau Rendi-Wagner hat ein Doktorat in Medizin, ist also akademisch gebildet, während bei Kurz als höchster Bildungsabschluss die mittlere Reife steht, also Maturant.
#               [Hausverstand55]: ...Akademiker haben oft keinen Realitätsbezug mehr, oft mangelt es auch an Hausverstand! Der Rendi Wagner fehlt es auch noch an Managementerfahrung und an Durchsetzungsvermögen.
#     [Sneef]: Haha! Haben Sie vielleicht die letzten Tage wo anders verbracht? Kurz hat aufgrund seiner Schwäche die Mehrheit in Nationalrat verloren und ihm wurde das Misstrauen ausgesprochen.   Nur zur Info falls sie es versäumt haben.
#       [Hausverstand55]: Das drückt sich in aktuellen Umfragen so aus: Kurz +6% PRW -5% FPÖ -5% Alles klar!?
#         [Sneef]: Was ändert das daran, dass er im NR keine Mehrheit für sich, ja sogar eine Mehrheit gegen sich hat?  Demokratie und so...
#           [Hausverstand55]: ...und nach der Wahl ist dann alles anders. Dann gibt es andere Verhandlungspartner und schon geht wieder was.
#
# Article: Schottland: Missbrauch von tausenden Kindern in Ordensheimen
# Published: 2019-05-31T17:02:57
# User Comments on this Article: 1
# User Replies on this Article: 1
#
# [starship]: man will sich gar nicht vorstellen, in welchem zustand die zivilisation wäre, könnten wir nicht auf fundamentalistische religiöse normen und werte aufbauen.  ein purer segen gottes und seiner stellvertreter auf erden. vergelts gott.
#   [Claidheamh Mòr]: vergessen ?
#   [GuteNachtSchaukel] (USER): War das eh ironisch gemeint? Ich hab's jedenfalls als Ironie verstanden - daher gab's ein spontantes grün  Also, falls das nicht ironisch gedacht war - bitte mein grün unbedingt wegdenken
#
#
# Total token count: 365275

# %%
import tiktoken
encoding = tiktoken.get_encoding("cl100k_base")
tokens_lst = encoding.encode("tiktoken is great!")
print(len(tokens_lst))
# Out:
# 6

# %%
import os
import pandas as pd
import tiktoken
from collections import defaultdict
import pickle

class UserAnalyzer:
    def __init__(self, df):
        self.df = df
        self.encoding = tiktoken.get_encoding("cl100k_base")

    def count_users(self):
        return self.df['ID_CommunityIdentity'].nunique()

    def count_tokens(self, text):
        tokens_lst = self.encoding.encode(text)
        return len(tokens_lst)

    def get_token_distribution(self):
        user_token_counts = defaultdict(int)

        for _, row in self.df.iterrows():
            user_id = row['ID_CommunityIdentity']
            comment = row['PostingComment']
            if isinstance(comment, str):
                user_token_counts[user_id] += self.count_tokens(comment)

        return dict(user_token_counts)

    def analyze_token_distribution(self):
        token_distribution = self.get_token_distribution()

        total_users = len(token_distribution)
        total_tokens = sum(token_distribution.values())
        avg_tokens = total_tokens / total_users if total_users > 0 else 0

        sorted_distribution = sorted(token_distribution.items(), key=lambda x: x[1], reverse=True)

        return {
            'total_users': total_users,
            'total_tokens': total_tokens,
            'avg_tokens_per_user': avg_tokens,
            'top_10_users': sorted_distribution[:10],
            'bottom_10_users': sorted_distribution[-10:],
        }

def main_analysis():
    preprocessed_file = "data/preprocessed/preprocessed_data.pkl"

    if not os.path.exists(preprocessed_file):
        print("Preprocessed data not found. Preprocessing...")
        preprocessor = DataPreprocessor('./data/raw_csv/Postings_01052019_31052019.csv')
        preprocessor.load_data()
        preprocessor.preprocess()

        # Save preprocessed data
        os.makedirs(os.path.dirname(preprocessed_file), exist_ok=True)
        with open(preprocessed_file, 'wb') as f:
            pickle.dump(preprocessor.df, f)

        df = preprocessor.df
    else:
        print("Loading preprocessed data...")
        with open(preprocessed_file, 'rb') as f:
            df = pickle.load(f)

    # Create UserAnalyzer
    user_analyzer = UserAnalyzer(df)

    # Count total users
    total_users = user_analyzer.count_users()
    print(f"Total number of unique users: {total_users}")

    # Analyze token distribution
    print("Analyzing token distribution...")
    analysis_results = user_analyzer.analyze_token_distribution()

    print(f"Total users analyzed: {analysis_results['total_users']}")
    print(f"Total tokens across all users: {analysis_results['total_tokens']}")
    print(f"Average tokens per user: {analysis_results['avg_tokens_per_user']:.2f}")

    print("\nTop 10 users by token count:")
    for user_id, token_count in analysis_results['top_10_users']:
        print(f"User ID: {user_id}, Token count: {token_count}")

    print("\nBottom 10 users by token count:")
    for user_id, token_count in analysis_results['bottom_10_users']:
        print(f"User ID: {user_id}, Token count: {token_count}")

if __name__ == "__main__":
    main_analysis()
# Out:
# Loading preprocessed data...
# Total number of unique users: 23925
# Analyzing token distribution...
# Total users analyzed: 23925
# Total tokens across all users: 38282469
# Average tokens per user: 1600.10
#
# Top 10 users by token count:
# User ID: 499749, Token count: 104725
# User ID: 518647, Token count: 91048
# User ID: 601254, Token count: 79884
# User ID: 521362, Token count: 75729
# User ID: 678541, Token count: 72960
# User ID: 1782, Token count: 70133
# User ID: 59327, Token count: 69724
# User ID: 665847, Token count: 67760
# User ID: 686372, Token count: 66608
# User ID: 633859, Token count: 65870
#
# Bottom 10 users by token count:
# User ID: 512297, Token count: 1
# User ID: 565387, Token count: 1
# User ID: 188861, Token count: 1
# User ID: 669059, Token count: 1
# User ID: 173522, Token count: 1
# User ID: 537330, Token count: 1
# User ID: 499935, Token count: 1
# User ID: 694186, Token count: 1
# User ID: 539016, Token count: 1
# User ID: 670012, Token count: 1
