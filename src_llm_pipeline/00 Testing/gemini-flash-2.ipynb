# %%
schema_ = {
    "properties": {
            "reasoning_2": {
            "description": "Gie a rating between 500 and 10000!",
            "title": "Score",
            "type": "integer",
        },
        "zeasoning": {
            "description": "Why did you give this rating?",
            "title": "Reasoning",
            "type": "string",
        },

        "school_yourself": {
            "description": "Shool yourself. Why is your answer bad?",
            "title": "School Yourself",
            "type": "string",
        },
    },
    "required": ["reasoning_2", "zeasoning", "school_yourself"],
    "propertyOrdering": ["reasoning_2", "zeasoning", "school_yourself"],
    "title": "Test",
    "type": "object",
    "strict": True,
}

# %%
from google import genai
from google.genai import types
import base64
from pydantic import BaseModel, Field
from icecream import ic
from pathlib import Path
from langchain_core.utils.json_schema import dereference_refs
from inputs.prompts.v11.data_models import (
    HolisticEmotionAnalysis,
    add_property_ordering_single_class,
    add_specific_property_ordering,
)
from langsmith import traceable
from dotenv import load_dotenv

load_dotenv()


class Test(BaseModel):
    reasoning: str = Field(description="Why did you give this rating?")
    score: int = Field(
        description="Write a rating of REWE from 500-1000!",
    )
    school_yourself: str = Field(description="Shool yourself. Why is your answer bad?")
#ic(Test.model_json_schema())

# %%
prompts_version = "v11"

def read_prompt(filename: str) -> str:
    """Load system prompt from file."""
    folder = Path(f"./inputs/prompts/{prompts_version}")
    return (folder / filename).read_text()

def read_context_sphere(filename: str) -> str:
    """Load system prompt from file."""
    folder = Path(f"./inputs/sp0/")
    return (folder / filename).read_text()


client = genai.Client(
    vertexai=True,
    project="rd-ri-genai-dev-2352",
    #project="rd-smrk-prod518-dev",
    location="us-central1",
)

role_setting_prompt = read_prompt("LFB_role_setting_prompt.md")
role_feedback_prompt = read_prompt("LFB_role_feedback_prompt.md")
user_task_prompt = read_prompt("user_task_prompt.md")

context = read_context_sphere("user_177819_comments_9275_tokens.md")

user_task_prompt_with_context = user_task_prompt.format(
        context_sphere=context
    )



messages = [
    types.Content(role="user", parts = [types.Part.from_text(role_setting_prompt)]),
    types.Content(role="model", parts = [types.Part.from_text(role_feedback_prompt)]),
    types.Content(role="user", parts = [types.Part.from_text(user_task_prompt_with_context)]),

    ]

def generate():


    
    response_schema = dereference_refs(HolisticEmotionAnalysis.model_json_schema())
    response_schema.pop("$defs", None)
    response_schema_properties_ordered = add_specific_property_ordering(response_schema)
    
    print(response_schema)
    

    model = "gemini-2.0-flash-exp"
    contents = messages
    generate_content_config = types.GenerateContentConfig(
        temperature=1,
        top_p=0.95,
        max_output_tokens=8192,
        response_mime_type="application/json",
        response_schema=response_schema_properties_ordered,
        response_modalities=["TEXT"],
        safety_settings=[
            types.SafetySetting(category="HARM_CATEGORY_HATE_SPEECH", threshold="OFF"),
            types.SafetySetting(
                category="HARM_CATEGORY_DANGEROUS_CONTENT", threshold="OFF"
            ),
            types.SafetySetting(
                category="HARM_CATEGORY_SEXUALLY_EXPLICIT", threshold="OFF"
            ),
            types.SafetySetting(category="HARM_CATEGORY_HARASSMENT", threshold="OFF"),
        ],
    )

    response = client.models.generate_content(
        model=model,
        contents=contents,
        config=generate_content_config,
    )
    return response

# %%
response = generate()
print(response.text)
# Out:
# {'properties': {'core_affect_analysis': {'description': 'Do not be lazy while working on your tasks!', 'properties': {'thought_process': {'description': "Provide a detailed step-by-step thought process of how you intend to analyze the core affect, *including specific quotes and examples from the user's comments to illustrate your points*, considering both valence (pleasantness) and arousal (activation), and noting any emotional dynamics or changes over time. Reference specific expressions, language, and contextual factors. **Consider how insights from other disciplines like sociology or neuroscience might inform your analysis.**", 'title': 'Thought Process', 'type': 'string'}, 'valence': {'description': "Classify the valence of the user's emotional state, noting any fluctuations. *Cite specific comments or phrases that indicate the valence.*", 'title': 'Valence', 'type': 'string'}, 'arousal': {'description': "Classify the arousal level of the user's emotional state, indicating activation or energy levels, and any changes over time. *Cite specific comments or phrases that indicate the arousal level.*", 'title': 'Arousal', 'type': 'string'}, 'patterns_observed': {'description': "Document any recurring patterns in the user's core affect across comments, linking them to specific instances.", 'title': 'Patterns Observed', 'type': 'string'}, 'anomalous_observations': {'description': "Highlight any comments where the user's core affect deviates from expected patterns based on the context.", 'title': 'Anomalous Observations', 'type': 'string'}, 'rationale': {'description': '**Include a clear short rationale explaining how you arrived at your conclusions, *supported by specific examples from the text and your research.* Consider how **external contextual factors** like news events or broader societal trends might contribute to the observed emotional state.**', 'title': 'Rationale', 'type': 'string'}}, 'required': ['thought_process', 'valence', 'arousal', 'patterns_observed', 'anomalous_observations', 'rationale'], 'title': 'CoreAffectAnalysis', 'type': 'object', 'propertyOrdering': ['thought_process', 'valence', 'arousal', 'patterns_observed', 'anomalous_observations', 'rationale']}, 'cognitive_appraisal_and_conceptualization': {'description': 'Do not be lazy while working on your tasks!', 'properties': {'thought_process': {'description': "Provide a detailed step-by-step thought process of how you intend to analyze the user's cognitive appraisals and conceptualizations. Refer to specific interpretations, judgments, language use, and conceptual knowledge. *Include specific comments and phrases from the user to illustrate these points.* **Consider how insights from other disciplines like psychology or cognitive science might inform your analysis.**", 'title': 'Thought Process', 'type': 'string'}, 'analysis': {'description': "Analyze how the user's interpretations and conceptual knowledge contribute to the construction of their emotions. *Support your analysis by illustrating how these cognitive processes shape the user's emotional experiences, citing specific examples from the user's comments.*", 'title': 'Analysis', 'type': 'string'}, 'patterns_observed': {'description': "Document any recurring patterns in the user's cognitive appraisals and conceptualizations across comments, linking them to specific instances.", 'title': 'Patterns Observed', 'type': 'string'}, 'anomalous_observations': {'description': "Highlight any comments where the user's cognitive appraisals or conceptualizations deviate from expected patterns based on the context.", 'title': 'Anomalous Observations', 'type': 'string'}, 'rationale': {'description': '**Include a clear short rationale explaining how you arrived at your conclusions, *supported by specific examples from the text and your research.* Consider how **external contextual factors** like cultural norms or social trends might contribute to the observed cognitive processes.**', 'title': 'Rationale', 'type': 's ...
# {
#   "cognitive_appraisal_and_conceptualization": {
#     "thought_process": "First, I will examine each of Pezibua's comments for indications of their cognitive appraisals – how they evaluate situations and interpret information. This will involve looking for judgments, opinions, and any framing they use to understand the world. For example, are they critical, supportive, or neutral? Second, I will identify the conceptual knowledge that underlies their comments. Do they demonstrate a grasp of technical concepts, cultural norms, or social dynamics? I will then synthesize these appraisals and conceptual understanding to form a picture of their cognitive framework.",
#     "analysis": "Pezibua demonstrates strong critical thinking and conceptual knowledge across multiple domains. In the drone article, their comment is satirical, demonstrating an understanding of commercial trends. In the Semenya article, Pezibua shows a deep comprehension of biological nuances and their implications for sports competition, rejecting strawman arguments and suggesting category-based solutions. In the medical article, their cognitive appraisal is very negative about the anti-vaccination movement, describing such people as 'kriminell', 'intelligenzallergischen Helikoptermütter' and so forth, showing strong judgment and conceptual links to a broader pattern of harmful behavior. When discussing women in racing, Pezibua highlights many factors around the complexities of gender, showing a nuanced understanding of the topic, but using a negative comparison with a 'Puff zur Förderung der weiblichen Sexualität'. In the article about the SPÖ, Pezibua appraises the event as overblown, stating: 'zwischen \"ungestüm formuliert\" und \"dreckigster Sexismus\" sind aber noch gefühlt 1000 Grauschattierungen'. Pezibua also shows a strong grasp of software development details, with examples regarding Windows containers and Adobe product licensing, correcting other users when needed. Pezibua also shows good insight into the public service and it's problems. Finally, Pezibua demonstrates good understanding of academic research standards, criticizing the university and its rector for approving a racist thesis. These comments demonstrate a rich conceptual knowledge base.",
#     "patterns_observed": "A recurring pattern is Pezibua's tendency to engage in critical analysis, questioning assumptions, and pointing out logical flaws or inconsistencies. This is evident across diverse topics, from sports classifications and political commentary to tech-related discussions. They often use a rational, evidence-based approach when addressing issues, showing a preference for detailed analysis over emotional appeals, as well as a tendency to be sarcastic.",
#     "anomalous_observations": "There are no significant deviations from the patterns of critical thinking. While they often express negative appraisals (particularly towards people they perceive as being misinformed or harmful), their commentary consistently shows a conceptual understanding, and logic. It does, however, tend to be sharp and somewhat confrontational at times.",
#     "rationale": "Pezibua's cognitive appraisals and conceptualizations are highly consistent across diverse topics. They use a reasoned, logic-driven approach, drawing on expertise in multiple fields. The user doesn't usually make appeals to emotion, instead choosing to focus on specific arguments with conceptual weight. This reveals a pattern of rational thought and engagement with information. Contextually, Pezibua engages in a German language forum which emphasizes debate, and where sarcasm is often used."
#   },
#   "core_affect_analysis": {
#     "thought_process": "I will analyze Pezibua's comments to identify indicators of their core affect. This involves assessing the valence (pleasantness or unpleasantness) and arousal (activation or deactivation) expressed through their language and the context of their responses. I will look for emotional language, intensity markers, and the overall tone of each comment. I will also note any shifts in their emotional expression across different topics or discussions.",
#      "valence": "Pezibua generally displays negative valence in their comments. This is evident in their critical and often sarcastic tone. For example, when discussing the Gabalier incident, they call it 'geistiger Durchfall', which clearly indicates an unpleasant emotional experience. They frequently use negative framing, expressing annoyance with what they perceive as illogical statements or unfair practices, like in the Magic card example: 'Es ist halt ein gewaltiger Schlag ins Gesicht'. Their response to the software licenses ('Das Gesudere wg. der Preise ist eh komplett jenseitig') shows a strong negative valence too. While some comments seem neutral, they are often framed by an underlying criticality.",
#     "arousal": "Pezibua's arousal level varies, but is often moderate to high. While they rarely display extreme emotional reactions, they show an active and engaged response style, often with a hint of annoyance or frustration. The use of terms like 'Dünnpfiff' and 'peinliche Farce', while not aggressive, does show a certain level of agitation. In their response to MamaPolasz, their tone escalates from sarcastic to slightly hostile in the last message, displaying a high level of arousal ('Bitte Ruhe, wenn die Erwachsenen reden.'). Some comments also show curiosity, which is a sign of arousal, but the negative valence tends to dominate.",
#     "patterns_observed": "A consistent pattern is the combination of negative valence with moderate to high arousal. Pezibua tends to respond with critical analysis and argumentative commentary, with sarcasm as a regular tool. This pattern is evident across various topics and discussions, displaying a consistent emotional stance.",
#     "anomalous_observations": "There are very few comments that deviate from this pattern. Even seemingly neutral questions or observations tend to be tinged with critical or sarcastic undertones. Even in comments that are not inherently aggressive, like their response to 'Fuuuck' ('Wenns den mit der deutschen Synchronstimme von Claptrap gibt, dann würd ich dafür tief ins Börserl greifen.'), the overall emotional tone is not generally positive, but more of an expression of interest.",
#     "rationale": "Pezibua's core affect is consistently characterized by negative valence and moderate to high arousal. Their comments often express disagreement, frustration, or annoyance towards what they perceive as illogical or unfair situations or viewpoints. This consistent emotional state is likely influenced by their role as a commenter engaging in online discussions, where critical analysis and debate are common. The German cultural context, known for directness, might amplify this expression. Contextually, Pezibua seems to be someone who reacts to statements with reasoned counterarguments instead of reacting in a neutral manner."
#   },
#   "cultural_and_social_context": {
#     "thought_process": "I will explore the cultural and social influences impacting Pezibua's emotions. This involves examining their use of language, their reactions to certain social topics, and their alignment with German/Austrian cultural norms. Additionally, I will look at how their online interactions shape their emotions, considering the norms and expectations of the Der Standard forum.",
#     "analysis": "Pezibua’s commentary aligns with German/Austrian cultural norms, particularly with their directness, emphasis on rationality, and their tendency towards sarcasm and satire. Their critical engagement with various topics, including politics, sports, and technology, reflects a culture where debate and skepticism are common. Their responses also suggest an understanding of the typical communication patterns in an online forum like Der Standard. The discussions are often polarized, and sarcasm is often used as a form of engagement. Pezibua participates actively in these debates, positioning themselves as a critical and knowledgeable voice, often correcting others. Their technical expertise and detailed responses show a cultural value placed on knowledge and accuracy, especially in technical fields. There is also a sense of accountability displayed when they call out 'intelligenzallergischen Helikoptermütter' as a negative group. The user also appears to be familiar with the 'Dunning-Kruger' effect and its use in public discussions.",
#     "patterns_observed": "A recurring pattern is Pezibua’s active participation in debates, driven by a need for accuracy and logical consistency. They consistently respond with critical analysis and sarcasm, often correcting perceived misinformation or logical flaws. The pattern of being direct and skeptical fits well into the assumed german language culture.",
#      "anomalous_observations": "There are no instances of Pezibua deviating from the general expectations of the forum's culture. They engage in debates in line with the norms, and their technical discussions align with the presumed cultural emphasis on expertise and accuracy.",
#     "rationale": "Pezibua's emotions are shaped by their participation in an online forum culture, where debate, logic and skepticism are expected. Their tendency to directly address and correct other participants is a norm in that space. The usage of sarcasm and satire is another example that is common in this online community. Their overall attitude and engagement style fit well within this social setting. This all strongly aligns with German/Austrian cultural norms of directness, rationality, and skepticism. This combination of online culture and broader cultural norms contribute to the construction of Pezibua's emotional expressions."
#   },
#   "emotion_construction_analysis": {
#     "thought_process": "I will analyze how Pezibua's emotions are constructed through the interaction of core affect (negative valence and high arousal), cognitive appraisals (critical and logical analysis), conceptual knowledge (technical proficiency and cultural awareness), and the specific context of the online forum discussions. I will integrate the insights from the previous sections to see how all these components interplay to create Pezibua’s emotional experiences.",
#     "analysis": "Pezibua’s emotions are consistently constructed through the interplay of a negative core affect, which arises from their critical appraisals of the topics and other users, a conceptual understanding of the subject, and the contextual background of online debate forums. Their negative core affect, marked by frustration and annoyance, is often triggered by perceptions of misinformation, logical inconsistencies, and unfair practices, all shaped by their cognitive appraisals. The conceptual knowledge, seen in their tech-related comments and awareness of social issues, frames these appraisals, providing a basis for their critical analyses. The online context of the forum allows for more confrontational and direct forms of engagement. They display a conceptual understanding of the technical fields, which enables them to feel frustrated when the debate in a discussion doesn't align with their knowledge base. For example, their responses to MamaPolasz are a clear demonstration of how Pezibua's cognitive appraisal (identifying misinformation), combined with the arousal of their disagreement, leads to strong negative comments. The user appears to expect arguments to be supported by facts, and that those facts should be accurate. Their understanding of the world, therefore, has strong elements of the rational and the logical. This gives rise to the combination of high arousal and negative valence, which are central to the core affect of Pezibua.",
#      "patterns_observed": "A consistent pattern is how Pezibua's cognitive appraisals, always with a basis in conceptual knowledge and logical reasoning, generate their core affect (negative valence and moderate to high arousal). The online debate format then facilitates a confrontational communication, resulting in a cycle of critical analyses and negative emotional expression.",
#     "anomalous_observations": "There are no substantial deviations from the established patterns in emotion construction. The user demonstrates an understanding of online etiquette, but will frequently respond with sarcasm and critical responses. Their approach is consistently analytical, conceptual, and negative-toned, showing how consistent and reliable their emotional construction is.",
#     "rationale": "Pezibua's emotion construction is marked by the consistent interaction of cognitive appraisals and a negative core affect. The critical and logical assessments, combined with conceptual understanding, give rise to negative emotional expressions in an online debate format. The online community where these interactions take place serves as a key factor in creating Pezibua's emotional stance. Pezibua consistently uses the platform to engage in critical analysis, using a tone that is consistently negative and sarcastic. This overall combination of factors provides the framework for Pezibua's emotional construction."
#   },
#   "emotional_dynamics_and_changes": {
#     "thought_process": "I will examine the user's comments to identify any shifts or changes in their emotional expression over time. This will involve comparing their responses across different articles, noticing whether there are variations in the intensity of their comments, and whether the valence or arousal levels change over time, or in response to different topics or other user interactions. I will also investigate the consistency or variability of their emotional responses to specific stimuli.",
#     "analysis": "There are no significant shifts in Pezibua's emotionality over time. Their core affect, characterized by negative valence and moderate to high arousal, remains consistent. While their responses vary in tone and sharpness depending on the topic and their interaction partners, the underlying pattern of critical analysis and sarcastic commentary remains. In the comments regarding the race series, the user is very critical of the premise, as in their comments regarding the Gabalier incident. In the comments regarding the Adobe licenses, the user is again using their intellectual background to critique and challenge other users. In all of these, the same pattern of negative valence and high arousal is used. Their interactions with other users, such as their debate with MamaPolasz or the discussions about Windows containers, further demonstrate the consistent nature of their responses. The tone changes slightly with each new discussion and interaction, but the core pattern remains consistent.",
#     "patterns_observed": "The consistency in Pezibua's emotional patterns is the most obvious observation. There are no substantial changes in their negative valence or moderate to high arousal. They continue to critique, engage, and challenge other users in the same style and with the same emotional response. This suggests a stable emotional style, which is not noticeably altered by the topics discussed or other users' comments.",
#     "anomalous_observations": "There are no deviations from the expected patterns of emotional dynamics. Despite the varying topics and their specific context, the user's consistent expression of negative valence and moderate to high arousal, combined with a high degree of criticism and logic, remains constant. This suggests a stable way of responding to information, which is consistent with their core emotional pattern.",
#     "rationale": "Pezibua's emotional dynamics are characterized by a high degree of consistency. The lack of substantial shifts in valence or arousal indicates a stable emotional pattern. The consistent interplay of core affect and conceptual appraisals demonstrates the user's firm emotional stance. This pattern of criticism, logic, and negativity remains consistent, revealing a predictable and stable emotional dynamic within this online forum."
#   }
# }

# %%
prompt = read_prompt("step_2_summary_prompt.md")
prompt = prompt.format(classificaton=response.text)

messages_2 = [
    types.Content(role="user", parts = [types.Part.from_text(role_setting_prompt)]),
    types.Content(role="model", parts = [types.Part.from_text(role_feedback_prompt)]),
    types.Content(role="user", parts = [types.Part.from_text(user_task_prompt_with_context)]),
    types.Content(role="model", parts = [types.Part.from_text(response.text)]),
    types.Content(role="user", parts = [types.Part.from_text(prompt)]),
    ]

# %%
@traceable(name="Step2:Flash2.0", run_type="llm")
def generate_step2(messages):
    model = "gemini-2.0-flash-exp"
    generate_content_config = types.GenerateContentConfig(
        temperature=1,
        top_p=0.95,
        max_output_tokens=8192,
        response_modalities=["TEXT"],
        safety_settings=[
            types.SafetySetting(category="HARM_CATEGORY_HATE_SPEECH", threshold="OFF"),
            types.SafetySetting(
                category="HARM_CATEGORY_DANGEROUS_CONTENT", threshold="OFF"
            ),
            types.SafetySetting(
                category="HARM_CATEGORY_SEXUALLY_EXPLICIT", threshold="OFF"
            ),
            types.SafetySetting(category="HARM_CATEGORY_HARASSMENT", threshold="OFF"),
        ],
    )

    response = client.models.generate_content(
        model=model,
        contents=messages,
        config=generate_content_config,
    )
    return response

# %%
response_2 = generate_step2(messages_2)

# %%
ic(response_2.text)


with open("response_2.md", "w") as f:
    f.write(response_2.text)
# Out:
# ic| response_2.text: ('**Inner Monologue**:
#                      '
#                       'Okay, the user wants a synthesis of the previous analysis. I need to pull '
#                       'the key elements from each section and present them in a concise but '
#                       'detailed way, making sure to use psychological terminology correctly and '
#                       'linking it back to my theory of constructed emotions. The user is requesting '
#                       'a summary, but also a level of detail that is not too abstract, so specific '
#                       "examples from Pezibua's comments are required. Let's go.
#                      "
#                       '
#                      '
#                       '**Synthesized Report**:
#                      '
#                       '
#                      '
#                       '**I. Identifying Information:**
#                      '
#                       '
#                      '
#                       '*   **Username:** Pezibua
#                      '
#                       '*   **Source of Data:** Der Standard comment section, covering a period from '
#                       'May 1, 2019 to May 31, 2019.
#                      '
#                       '
#                      '
#                       '**II. Reason for Assessment:**
#                      '
#                       '
#                      '
#                       '*   This analysis was conducted to examine the emotional expression and '
#                       'online behavior of Pezibua within the Der Standard forum, using Lisa Feldman '
#                       "Barrett's theory of constructed emotions as a framework.
#                      "
#                       '
#                      '
#                       '**III. Data Sources and Methods:**
#                      '
#                       '
#                      '
#                       '*   Data collected includes forum comments and replies across multiple '
#                       'articles (n= 42).
#                      '
#                       '*   Method: Qualitative analysis of text-based communication, focusing on '
#                       'emotional language, core affect (valence and arousal), cognitive appraisals, '
#                       'conceptual knowledge, and the social and cultural context.
#                      '
#                       '*   Limitations: This analysis is based solely on text-based communication, '
#                       'lacking nonverbal cues and relying on interpretation of textual context. '
#                       'Emotional inferences are limited and should be interpreted with caution.
#                      '
#                       '
#                      '
#                       '**IV. Behavioral Observations:**
#                      '
#                       '
#                      '
#                       '*   **Core Affect:** Pezibua consistently exhibited negative valence, '
#                       'frequently expressing annoyance, disapproval, and frustration. Arousal '
#                       'levels were generally moderate to high, with significant spikes during '
#                       'disagreements and rebuttals.
#                      '
#                       '*   **Emotional Language:** Pezibua employed strong, critical, and often '
#                       'sarcastic language (e.g., "geistiger Durchfall," "Dünnpfiff," "peinliche '
#                       'Farce").  They frequently used judgmental terms (e.g., "kriminell," '
#                       '"intelligenzallergischen Helikoptermütter"). Sarcasm was a primary tool for '
#                       'expressing negativity, often used to dismiss opposing viewpoints. In debates '
#                       'with other users, the language sometimes escalated to outright hostility '
#                       '("Bitte Ruhe, wenn die Erwachsenen reden").
#                      '
#                       '*   **Interaction Patterns:** Pezibua actively engaged in debates, often '
#                       'correcting or challenging other users. Their interactions typically began '
#                       'with critical analysis and evolved into more direct rebukes or sarcasm. A '
#                       'common pattern was initially sarcasm, that then turns into a strong response '
#                       'when other users disagreed. They also used their conceptual knowledge as a '
#                       "way to dismiss other user's arguments by framing the user as ignorant on the "
#                       'topic.
#                      '
#                       '
#                      '
#                       '**V. Contextual and Cultural Considerations:**
#                      '
#                       '
#                      '
#                       '*   The Der Standard forum, known for its debates and polarized discussions, '
#                       "shaped Pezibua's emotional expression. The forum's left-leaning political "
#                       "climate likely influenced Pezibua's negative comments towards right-wing "
#                       'figures or policies. The expectation of intellectual debate within the forum '
#                       "also played a significant role in shaping the user's interactions. The "
#                       'german/austrian cultural tendency for direct communication and expression, '
#                       'combined with the norms of the online community, likely resulted in the '
#                       'frequency of sarcasm in the users comments.
#                      '
#                       '
#                      '
#                       '**VI. Interpretation and Conceptualization:**
#                      '
#                       '
#                      '
#                       '*   Pezibua’s emotional expressions are constructed through a dynamic '
#                       'interplay of core affect, cognitive appraisals, conceptual knowledge, and '
#                       'the social context, all as described in my theory of constructed emotions. '
#                       'Negative core affect, evident as annoyance and frustration, intensified when '
#                       'the user perceived logical inconsistencies, factual inaccuracies, or '
#                       'unfairness, based on their cognitive appraisals. These appraisals were '
#                       'informed by the user’s rich conceptual knowledge across multiple fields '
#                       '(technology, sports, social issues).  For instance, their criticism of the '
#                       'racist bachelor thesis stemmed from their appraisal of it as '
#                       '“wissenschaftlich unhaltbar”, which then led to a response that was critical '
#                       'of the institute and its leadership. Their strong reaction to the '
#                       '"Laufmasche" comment, was based on their appraisal of the comment as '
#                       '“dreckigster Sexismus”, even though they also recognized that the situation '
#                       'was not completely clear-cut.
#                      '
#                       "*   A recurring pattern was Pezibua's critical appraisal, supported by their "
#                       'conceptual knowledge, that triggered a negative emotional response, which '
#                       'was expressed through the use of direct, and at times sarcastic, rebuttals. '
#                       'However, their focus on logic and accuracy suggested a drive for '
#                       'intellectual honesty, which is often a sign of negative valence because it '
#                       "is easier to find 'flaws' than it is to make something 'good'. The user "
#                       'showed remarkable consistency in their emotional construction, where their '
#                       'core affect (negative valence) was almost always combined with a moderate to '
#                       'high level of arousal, with minor changes depending on the context of the '
#                       'debate.
#                      '
#                       '
#                      '
#                       '**VII. Limitations:**
#                      '
#                       '
#                      '
#                       '*   This analysis is based solely on text and cannot definitively determine '
#                       "Pezibua's internal emotional state. Nonverbal cues are missing, and "
#                       'individual differences in communication styles might influence the '
#                       'interpretation of comments. The analysis is a good representation, but not a '
#                       "perfect representation, of Pezibua's internal emotional state.
#                      "
#                       '
#                      '
#                       '**VIII. Summary:**
#                      '
#                       '
#                      '
#                       '*   Pezibua’s online behavior is characterized by consistent negative '
#                       'valence and moderate to high arousal, stemming from critical appraisals and '
#                       'a rich conceptual understanding, all expressed within a highly interactive '
#                       'online community. This analysis supports the theory that emotions are '
#                       'constructed dynamically by core affect, cognitive appraisals, conceptual '
#                       'knowledge, the social and cultural setting, and the dynamics of interactions '
#                       'with other users, rather than being fixed or pre-defined.
#                      ')
