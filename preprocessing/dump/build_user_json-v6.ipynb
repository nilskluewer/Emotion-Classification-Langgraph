# %%
import json

def load_json(file_path):
    """
    Load the JSON file containing articles and comments.

    Args:
        file_path (str): The path to the JSON file.

    Returns:
        dict: The loaded JSON data.
    """
    with open(file_path, 'r', encoding='utf-8') as f:
        return json.load(f)

def find_articles_with_user_comments(articles, user_id):
    """
    Find all articles where the user has written a comment.

    Args:
        articles (dict): The dictionary containing articles and comments.
        user_id (int): The ID of the user.

    Returns:
        dict: A dictionary of articles where the user has written a comment.
    """
    user_articles = {}
    for article_id, article_data in articles.items():
        for thread in article_data['comment_threads']:
            if user_has_comment_in_thread(thread, user_id):
                user_articles[article_id] = article_data
                break
    return user_articles

def user_has_comment_in_thread(thread, user_id):
    """
    Check if the user has a comment in the given thread or its replies.

    Args:
        thread (dict): The thread to check.
        user_id (int): The ID of the user.

    Returns:
        bool: True if the user has a comment in the thread, False otherwise.
    """
    if thread['user_id'] == user_id:
        return True
    for reply in thread['replies']:
        if user_has_comment_in_thread(reply, user_id):
            return True
    return False

def find_user_threads_in_articles(articles, user_id):
    """
    Find all threads in the given articles where the user has written a comment.

    Args:
        articles (dict): The dictionary containing articles and comments.
        user_id (int): The ID of the user.

    Returns:
        dict: A dictionary of articles with threads where the user has written a comment.
    """
    user_articles = {}
    for article_id, article_data in articles.items():
        user_threads = []
        for thread in article_data['comment_threads']:
            filtered_thread = filter_thread_for_user(thread, user_id)
            if filtered_thread:
                user_threads.append(filtered_thread)

        if user_threads:
            user_articles[article_id] = {
                'article_id': article_data['article_id'],
                'article_title': article_data['article_title'],
                'article_publish_date': article_data['article_publish_date'],
                'article_channel': article_data['article_channel'],
                'article_ressort_name': article_data['article_ressort_name'],
                'total_comments': article_data['total_comments'],
                'root_comments': article_data['root_comments'],
                'user_threads': user_threads
            }

    return user_articles

def filter_thread_for_user(thread, user_id):
    """
    Filter the thread to include only the parts where the user has written a comment.

    Args:
        thread (dict): The thread to filter.
        user_id (int): The ID of the user.

    Returns:
        dict: The filtered thread, or None if the user has not written a comment in the thread.
    """
    if thread['user_id'] == user_id:
        filtered_replies = [filter_thread_for_user(reply, user_id) for reply in thread['replies']]
        filtered_replies = [reply for reply in filtered_replies if reply]
        filtered_thread = thread.copy()
        filtered_thread['replies'] = filtered_replies
        return filtered_thread
    else:
        filtered_replies = [filter_thread_for_user(reply, user_id) for reply in thread['replies']]
        filtered_replies = [reply for reply in filtered_replies if reply]
        if filtered_replies:
            filtered_thread = thread.copy()
            filtered_thread['replies'] = filtered_replies
            return filtered_thread
    return None

# Beispiel für die Verwendung
file_path = 'articles_with_threads.json'
articles_with_threads = load_json(file_path)

user_id = 5002

# Schritt 1: Finde alle Artikel, in denen der Benutzer einen Kommentar geschrieben hat
user_articles = find_articles_with_user_comments(articles_with_threads, user_id)
print(f"Artikel, in denen der Benutzer {user_id} einen Kommentar geschrieben hat:")
# Out:
# Artikel, in denen der Benutzer 5002 einen Kommentar geschrieben hat:

# %%
# Schritt 2: Finde alle Threads in diesen Artikeln, in denen der Benutzer aktiv war
user_threads_in_articles = find_user_threads_in_articles(user_articles, user_id)
print(f"Threads, in denen der Benutzer {user_id} aktiv war:")
print(json.dumps(user_threads_in_articles, indent=2))
# Out:
# Threads, in denen der Benutzer 5002 aktiv war:
# {
#   "2000103217465": {
#     "article_id": 2000103217465,
#     "article_title": "Vierter Sieg f\u00fcr Deutschland, Russland, Schweiz bei WM",
#     "article_publish_date": "2019-05-15T23:45:24",
#     "article_channel": "Sport",
#     "article_ressort_name": "Eishockey-WM 2019",
#     "total_comments": 104,
#     "root_comments": 16,
#     "user_threads": [
#       {
#         "id": 1041527443,
#         "parent_id": 0,
#         "user_id": 521253,
#         "user_name": "k05sheen",
#         "user_gender": "m",
#         "user_created_at": "2013-08-04T19:32:46.153000",
#         "comment_headline": "AUT-SWE",
#         "comment_text": "0:3 nach 6 Min 0:4 nach 8 Min...  ...das ist jetzt schon ein Gemetzel :-(",
#         "comment_created_at": "2019-05-16T16:31:09.713000",
#         "comment_length": 73,
#         "article_id": 2000103217465,
#         "article_publish_date": "2019-05-15T23:45:24",
#         "article_title": "Vierter Sieg f\u00fcr Deutschland, Russland, Schweiz bei WM",
#         "article_channel": "Sport",
#         "article_ressort_name": "Eishockey-WM 2019",
#         "replies": [
#           {
#             "id": 1041528053,
#             "parent_id": 1041527443,
#             "user_id": 5002,
#             "user_name": ">t<",
#             "user_gender": "m",
#             "user_created_at": "2006-03-26T06:33:13.493000",
#             "comment_headline": "No Headline",
#             "comment_text": "gelinde gesagt",
#             "comment_created_at": "2019-05-16T16:50:16.200000",
#             "comment_length": 14,
#             "article_id": 2000103217465,
#             "article_publish_date": "2019-05-15T23:45:24",
#             "article_title": "Vierter Sieg f\u00fcr Deutschland, Russland, Schweiz bei WM",
#             "article_channel": "Sport",
#             "article_ressort_name": "Eishockey-WM 2019",
#             "replies": []
#           }
#         ]
#       }
#     ]
#   },
#   "2000103283552": {
#     "article_id": 2000103283552,
#     "article_title": "Heike G\u00f6schl: Es gibt ein Leben davor und ein Leben danach",
#     "article_publish_date": "2019-05-17T06:00:00",
#     "article_channel": "Sport",
#     "article_ressort_name": "Sportmonolog",
#     "total_comments": 309,
#     "root_comments": 98,
#     "user_threads": [
#       {
#         "id": 1041669412,
#         "parent_id": 0,
#         "user_id": 5002,
#         "user_name": ">t<",
#         "user_gender": "m",
#         "user_created_at": "2006-03-26T06:33:13.493000",
#         "comment_headline": "No Headline",
#         "comment_text": "ihr job als sonderp\u00e4dagogin ist zumindest genauso schwer wie aufn glockner raufzugehen. nur ist der glockner einfacher, weil da gehst nur einmal oder so wie ich dreimal rauf. der glockner ist einfach ein schaasberg. l\u00e4stig beim abstieg.",
#         "comment_created_at": "2019-05-19T10:53:54.323000",
#         "comment_length": 236,
#         "article_id": 2000103283552,
#         "article_publish_date": "2019-05-17T06:00:00",
#         "article_title": "Heike G\u00f6schl: Es gibt ein Leben davor und ein Leben danach",
#         "article_channel": "Sport",
#         "article_ressort_name": "Sportmonolog",
#         "replies": []
#       }
#     ]
#   },
#   "2000103294525": {
#     "article_id": 2000103294525,
#     "article_title": "K\u00fcssel \u00fcber Strache: \"Da gab es einige lustige Auftritte\"",
#     "article_publish_date": "2019-05-16T21:25:28",
#     "article_channel": "Inland",
#     "article_ressort_name": "FP\u00d6",
#     "total_comments": 1365,
#     "root_comments": 550,
#     "user_threads": [
#       {
#         "id": 1041537594,
#         "parent_id": 0,
#         "user_id": 53014,
#         "user_name": "Franky A",
#         "user_gender": "m",
#         "user_created_at": "2002-04-03T16:49:14",
#         "comment_headline": "No Headline",
#         "comment_text": "Diesen untragbaren rechten Sumpf hat die verantwortungslose \u00d6VP salonf\u00e4hig gemacht. Es ist zum Kotzen.",
#         "comment_created_at": "2019-05-16T21:27:52.850000",
#         "comment_length": 102,
#         "article_id": 2000103294525,
#         "article_publish_date": "2019-05-16T21:25:28",
#         "article_title": "K\u00fcssel \u00fcber Strache: \"Da gab es einige lustige Auftritte\"",
#         "article_channel": "Inland",
#         "article_ressort_name": "FP\u00d6",
#         "replies": [
#           {
#             "id": 1041538232,
#             "parent_id": 1041537594,
#             "user_id": 5002,
#             "user_name": ">t<",
#             "user_gender": "m",
#             "user_created_at": "2006-03-26T06:33:13.493000",
#             "comment_headline": "No Headline",
#             "comment_text": "viele wahlberechtigten haben die \u00f6vp gew\u00e4hlt. denen war es durchaus klar was diese damit verursacht haben. es war auch den \u00f6vp w\u00e4hlerinnen klar, dass sie damit die rechten salonf\u00e4hig gemacht hatten. die \u00f6vp w\u00e4hlerInnen wollten das bewusst. so einfach kann sich der \u00f6vp w\u00e4hler nicht aus der verantwortung ziehen.  na t\u00fcrkis ist ja fast blau wer das nicht gecheckt hat, den konnte man eh nicht helfen",
#             "comment_created_at": "2019-05-16T21:36:52.190000",
#             "comment_length": 398,
#             "article_id": 2000103294525,
#             "article_publish_date": "2019-05-16T21:25:28",
#             "article_title": "K\u00fcssel \u00fcber Strache: \"Da gab es einige lustige Auftritte\"",
#             "article_channel": "Inland",
#             "article_ressort_name": "FP\u00d6",
#             "replies": []
#           }
#         ]
#       }
#     ]
#   },
#   "2000103654632": {
#     "article_id": 2000103654632,
#     "article_title": "Aff\u00e4re um rassistische Bachelorarbeit an Grazer FH weitet sich aus",
#     "article_publish_date": "2019-05-23T08:45:35",
#     "article_channel": "Panorama",
#     "article_ressort_name": "\u00d6sterreich",
#     "total_comments": 942,
#     "root_comments": 163,
#     "user_threads": [
#       {
#         "id": 1041930414,
#         "parent_id": 0,
#         "user_id": 5002,
#         "user_name": ">t<",
#         "user_gender": "m",
#         "user_created_at": "2006-03-26T06:33:13.493000",
#         "comment_headline": "No Headline",
#         "comment_text": "Linz, Leoben, Graz... war schon in den 80er Jahren so wenn man richtige rechte Deppen finden wollte  fand man in diesen St\u00e4dten die besonders Besonderen.",
#         "comment_created_at": "2019-05-23T19:50:05.300000",
#         "comment_length": 153,
#         "article_id": 2000103654632,
#         "article_publish_date": "2019-05-23T08:45:35",
#         "article_title": "Aff\u00e4re um rassistische Bachelorarbeit an Grazer FH weitet sich aus",
#         "article_channel": "Panorama",
#         "article_ressort_name": "\u00d6sterreich",
#         "replies": []
#       }
#     ]
#   },
#   "2000103897780": {
#     "article_id": 2000103897780,
#     "article_title": "Abrissbirne Kurz: Die Zweite Republik ist Geschichte",
#     "article_publish_date": "2019-05-27T13:23:58.300000",
#     "article_channel": "Meinung",
#     "article_ressort_name": "Kommentare der anderen",
#     "total_comments": 649,
#     "root_comments": 239,
#     "user_threads": [
#       {
#         "id": 1042122394,
#         "parent_id": 0,
#         "user_id": 5002,
#         "user_name": ">t<",
#         "user_gender": "m",
#         "user_created_at": "2006-03-26T06:33:13.493000",
#         "comment_headline": "Die Zweite Republik ist Geschichte.",
#         "comment_text": "Habe ich das richtig gelesen ?? Also so wichtig ist der Kurz nicht.  Mit dieser Aussage wird die momentane Situation vollkommen \u00fcberzogen dargestellt. Die zwei Republiken wurden aus den furchtbaren Ereignissen heraus gegr\u00fcndet. Ich bin absolut dagegen einen meiner Meinung nach sehr unf\u00e4higen Kurzkanzler gleich eine neue Republik anzudeuten. Wa ! Das geht so absolut nicht. Da war ja der Kreisky noch pr\u00e4gender.",
#         "comment_created_at": "2019-05-27T23:18:04.377000",
#         "comment_length": 412,
#         "article_id": 2000103897780,
#         "article_publish_date": "2019-05-27T13:23:58.300000",
#         "article_title": "Abrissbirne Kurz: Die Zweite Republik ist Geschichte",
#         "article_channel": "Meinung",
#         "article_ressort_name": "Kommentare der anderen",
#         "replies": []
#       }
#     ]
#   }
# }
