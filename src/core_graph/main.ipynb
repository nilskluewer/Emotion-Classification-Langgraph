# %% [markdown]
# https://langchain-ai.github.io/langgraph/tutorials/rag/langgraph_adaptive_rag/

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
import os
from dotenv import load_dotenv
from typing import Literal

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_openai import ChatOpenAI
from chains.simple_chains import grade_emotionality

_ = load_dotenv()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
post =  """(USER): sie haben nur die regierung kritisiert. das die roten nicht in der lage zu guter oppositionspolitik sind und waren war schon damals bei schwarz/blau I und II ersichtlich. im ausland das eigene land anschwärzen wenn sie nicht mehr weiter wissen. oder penetrantes herumgeplärre. nichts davon ist brauchbar. wie man eine regierung "vor sich hertreibt" müssten sie mal von der FPÖ lernen und abschauen.
"""

# %%
grader = grade_emotionality()
grader.invoke({"context": post})
# Out:
# GradeEmotionality(reasoning='The context involves criticism towards the government and a comparison with the opposition party. The language used is quite strong and accusatory, suggesting a level of frustration and dissatisfaction. The mention of ', score='75')
